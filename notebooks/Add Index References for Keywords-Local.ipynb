# %% [markdown]
# # Add index references for keywords

# %% [markdown]
# Ideally we will run this once when the book is finished

# %%
from collections import Counter
p_text = open("../psychedelia/src/c64/psychedelia.asm",'r').read()
p_words = p_text.replace('\n', ' ').split()
p_wordcount = [a for a,b in Counter(p_words).most_common()
               if b > 2 and len(a) > 6]
p_wordcount
# Out:
# [';-------------------------------------------------------',
#  'currentVariableMode',
#  '$00,$00,$00,$00,$00,$00,$00,$00',
#  '$FF,$FF,$FF,$FF,$FF,$FF,$FF,$FF',
#  'pixelYPosition',
#  'pressed',
#  'pressed.',
#  'ClearLastLineOfScreen',
#  '(currentSequencePtrLo),Y',
#  '$00,$55',
#  'currentColorIndexArray,X',
#  'WriteLastLineBufferToScreen',
#  'cursorYPosition',
#  'pressed?',
#  'currentValueInColorIndexArray',
#  'lastKeyPressed',
#  'cursorXPosition',
#  'pixelXPosition',
#  'SCREEN_RAM',
#  'currentStepCount',
#  'statusLineBuffer,X',
#  '#NOT_ACTIVE',
#  'currentModeActive',
#  'Returns',
#  'shiftPressed',
#  '#DISPLAY_LINE_LENGTH',
#  '"petscii"',
#  'currentSequencePtrLo',
#  'currentSequencePtrHi',
#  '(customPatternLoPtr),Y',
#  'currentPatternElement',
#  'currentSymmetrySetting',
#  '#NUM_ROWS',
#  'pattern',
#  'MainPaintLoop',
#  'currentIndexToPixelBuffers',
#  'tapeSavingInProgress',
#  ';characters',
#  '#NUM_COLS',
#  'stepsRemainingInSequencerSequence',
#  'sequencerActive',
#  'playbackOrRecordActive',
#  'timerBetweenKeyStrokes',
#  'previousIndexToPixelBuffers',
#  'lastJoystickInput',
#  'dataFreeDigitThree',
#  'customPromptsActive',
#  'currentIndexToPresetValue',
#  'recordingStorageHiPtr',
#  '#NO_KEY_PRESSED',
#  '#SHIFT_PRESSED',
#  'dataFreeDigitTwo',
#  '#GENERIC_ACTIVE',
#  'presetValueArray,X',
#  '(presetSequenceDataLoPtr),Y',
#  '(recordingStorageLoPtr),Y',
#  'currentColorSet',
#  'recordingStorageLoPtr',
#  'PaintPixel',
#  'ReinitializeScreen',
#  'bufferLength',
#  'sequencer',
#  'displaySavePromptActive',
#  'patterns',
#  ';Returns',
#  'activate:',
#  'currentDataFree',
#  'currentColorToPaint',
#  'currentSymmetrySettingForStep',
#  'colorBarScreenRamHiPtr',
#  'initialBaseLevelForCustomPresets',
#  'COLOR_RAM',
#  'PaintPixelForCurrentSymmetry',
#  'positions',
#  'position',
#  'PutRandomByteInAccumulator',
#  'smoothingDelayArray,X',
#  'PaintCursorAtCurrentPosition',
#  'DrawCursorAndReturnFromInterrupt',
#  'current',
#  'trackingActivated',
#  'demoModeActive',
#  'offsetToColorBar',
#  'variable',
#  'skipPixel',
#  'colorRamHiPtr',
#  '.include',
#  'InitializeProgram',
#  'ReturnEarlyFromRoutine',
#  'structure',
#  'pattern.',
#  'pixelXPositionArray,X',
#  'pixelYPositionArray,X',
#  'initialSmoothingDelayArray,X',
#  'patternIndexArray,X',
#  'symmetrySettingForStepCount,X',
#  'screen.',
#  '$FF,$55',
#  '#COLOR_CHANGE',
#  'pressed,',
#  'SYMMETRY',
#  'ResetSelectedVariableAndReturn',
#  'DisplayVariableSelection',
#  'MaybeInColorMode',
#  'LoadSelectedPresetSequence',
#  'UpdateDataFreeDisplay',
#  'dataFreeForSequencer',
#  'recordingOffset',
#  'previousPixelXPosition',
#  'previousPixelYPosition',
#  'presetSequenceDataLoPtr',
#  'presetSequenceDataHiPtr',
#  'minIndexToColorValues',
#  'colorRamLoPtr',
#  'presetTempLoPtr',
#  'presetTempHiPtr',
#  'Register',
#  'InitializeScreenWithInitCharacter',
#  'ActuallyPaintPixel',
#  'presetColorValuesArray,X',
#  'PaintStructureAtCurrentPosition',
#  'countToMatchCurrentIndex',
#  'patternIndex',
#  'sequence',
#  'relative',
#  'buffers',
#  '#SAVE_PROMPT_MODE_ACTIVE',
#  'display',
#  'countStepsBeforeCheckingJoystickInput',
#  'CheckIfCursorMovedLeftOrRight',
#  'CheckIfPlayerPressedFire',
#  'stepsSincePressedFire',
#  'currentPulseWidth',
#  'lineModeActivated',
#  'baseLevel',
#  'smoothingDelay',
#  'Display',
#  'DisplayLoadOrAbort',
#  'DisplaySequencerState',
#  'dataFreeDigitOne',
#  'currentNodeInColorBar',
#  'currentCountInDrawingColorBar',
#  'maxToDrawOnColorBar',
#  '#PLAYING_BACK',
#  'enterWasPressed',
#  'GetPresetPointersUsingXRegister',
#  ';-------------------------------------------------------------------------',
#  'ReturnPressed',
#  'MoveToNextBurstPosition',
#  'MoveToNextPositionInSequencer',
#  'DisplayStoppedRecording',
#  'previousCursorXPosition',
#  'previousCursorYPosition',
#  'parameters',
#  'ResetSavingStateAndReturn',
#  'ReturnFromSave',
#  'joystickInputRandomizer',
#  'copyright',
#  'offsetForYPos',
#  'colorBarScreenRamLoPtr',
#  'presetLoPtr',
#  'presetHiPtr',
#  'shiftKey',
#  'indexOfCurrentColor',
#  'dynamicStorageHiPtr',
#  'copyFromHiPtr',
#  'copyToHiPtr',
#  ';Border',
#  'MovePresetDataIntoPosition',
#  'represents',
#  'colorRAMLineTableHiPtrArray,X',
#  'colorRAMLineTableLoPtrArray,X',
#  'InitializeDynamicStorage',
#  'LaunchPsychedelia',
#  '$00,$00,$00,$00,$00,$00',
#  '$0000,X',
#  '$0100,X',
#  '$0200,X',
#  '$02C0,X',
#  'LoadXAndYPosition',
#  'PixelPaintLoop',
#  'RestorePositionsAndReturn',
#  'symmetry',
#  'ReinitializeSequences',
#  'SetUpInterruptHandlers',
#  'interrupt',
#  'Left/Right',
#  'active.',
#  'HandleCustomPreset',
#  'DisplaySavePromptScreen',
#  'buffers.',
#  'through',
#  'PaintLineMode',
#  'SequencerNotActiveCheckJoystickInput',
#  'sequencerSpeed',
#  'LoadDataForSequencer',
#  'CheckKeyboardAndReturnFromInterrupt',
#  'GetJoystickInput',
#  '#JOYSTICK_RIGHT',
#  'DecrementPulseSpeedCounter',
#  'currentPulseSpeedCounter',
#  'CheckKeyboardInput',
#  'LoadXAndYOfCursorPosition',
#  'indexForColorBarDisplay',
#  'pointers',
#  'CheckKeyboardInputForActiveVariableMode',
#  'between',
#  'MaybeDisplayDemoModeMessage',
#  'GetCustomPatternElement',
#  'JustSPressed',
#  'PromptToSave',
#  'setting',
#  'JustLPressed',
#  '#BUFFER_LENGTH',
#  'Controls',
#  'DisplayPresetMessage',
#  'MaybeQPressed',
#  'functionKeyIndex',
#  'LoadOrProgramBurstGenerator',
#  'ActivateSequencer',
#  'StopOrStartRecording',
#  'pixelShapeIndex',
#  'statusLineBuffer',
#  '$03BF,X',
#  'DrawColorValueBar',
#  'currentColorBarOffset',
#  'CheckKeyboardWhilePromptActive',
#  'selected',
#  'CheckIfEnterPressed',
#  '#KEY_RETURN',
#  'ReachedLastColor',
#  "'SEQUENCER",
#  'SelectNewPreset',
#  'MaybeEditCustomPattern',
#  'UpdateCurrentActivePreset',
#  'WriteLastLineBufferAndReturn',
#  'RefreshPresetData',
#  'ResetCurrentActiveMode',
#  '#>presetSequenceData',
#  'LoadBurstData',
#  'CheckKeyboardInputForCustomPresets',
#  '#SAVING_ACTIVE',
#  'CheckKeyboardInputWhileSavePromptActive',
#  'CheckKeyboardInputWhileLoadAbortActive',
#  'UpdateDataFreeLoop',
#  'DecrementDataFreeCounterAndLoop',
#  'prevSequencePtrLo',
#  'prevSequencePtrHi',
#  'prevSymmetrySetting',
#  'burstSmoothingDelay',
#  '#>dynamicStorage',
#  '#<dynamicStorage',
#  'DynamicStorageInitLoop',
#  'RecordJoystickMovements',
#  'MaybePerformRandomJoystickMovement',
#  'NoMoreBytes',
#  'customPatternIndex',
#  'EnterPressed',
#  'ROM_SETLFS',
#  'ROM_SETNAM',
#  'CURRENT_CHAR_COLOR',
#  'SETLFS,SETNAM',
#  'ReturnFromPromptToSave',
#  'ResetStateAndClearPrompt',
#  'joystickInputDebounce',
#  'demoModeCountDownToChangePreset']

# %%
p_wordcount = [a for a,b in Counter(p_words).most_common()
               if "preset" in a]
p_wordcount
# Out:
# ['presetValueArray,X',
#  '(presetSequenceDataLoPtr),Y',
#  'preset',
#  'presetSequenceDataLoPtr',
#  'presetSequenceDataHiPtr',
#  'presetTempLoPtr',
#  'presetTempHiPtr',
#  'presetColorValuesArray,X',
#  'presetLoPtr',
#  'presetHiPtr',
#  '#>presetSequenceData',
#  'presets',
#  'presetKeyLoop',
#  '#<presetSequenceData',
#  'presetSequenceData',
#  'presetKeyCodes',
#  'presets.',
#  'presetValueArray',
#  'presetColorValuesArray',
#  'presetKeyCodes,X',
#  'presetColorValuesArray,Y',
#  'preset.',
#  '#len(presetColorValuesArray)',
#  'presetValueArray,Y',
#  '(presetTempLoPtr),Y',
#  'presets,',
#  '#>presetSequenceDataSource',
#  '"presets.asm"']

# %%
chapters = [
    "listing.tex",
    "listing_pattern.tex",
    "listing_commentary.tex",
    "fullgame_listing.tex",
    "patterns.tex",
    "symmetries.tex",
    "bursts.tex",
    "sequencer.tex",
    "presets.tex",
    "delay.tex",
    "tracking.tex",
    "pulsespeed.tex",
    "linewidth.tex",
    "aftereffects.tex",
    "listing_commentary/psychedelia_listing.tex",
    "listing_commentary/full_psychedelia_listing.tex",
    "after_effects/batalyx_listing.tex",
]
keywords = list(set([
    'currentVariableMode',
    'pixelYPosition',
    'ClearLastLineOfScreen',
    'currentColorIndexArray',
    'WriteLastLineBufferToScreen',
    'cursorYPosition',
    'currentValueInColorIndexArray',
    'lastKeyPressed',
    'cursorXPosition',
    'pixelXPosition',
    'currentStepCount',
    'statusLineBuffer',
    'currentModeActive',
    'shiftPressed',
    'currentSequencePtrLo',
    'currentSequencePtrHi',
    'customPatternLoPtr',
    'currentPatternElement',
    'currentSymmetrySetting',
    'MainPaintLoop',
    'currentIndexToPixelBuffers',
    'stepsRemainingInSequencerSequence',
    'sequencerActive',
    'playbackOrRecordActive',
    'timerBetweenKeyStrokes',
    'previousIndexToPixelBuffers',
    'lastJoystickInput',
    'dataFreeDigitThree',
    'customPromptsActive',
    'currentIndexToPresetValue',
    'recordingStorageHiPtr',
    'presetValueArray',
    'presetSequenceDataLoPtr',
    'recordingStorageLoPtr',
    'currentColorSet',
    'PaintPixel',
    'ReinitializeScreen',
    'bufferLength',
    'displaySavePromptActive',
    'currentDataFree',
    'currentColorToPaint',
    'currentSymmetrySettingForStep',
    'colorBarScreenRamHiPtr',
    'initialBaseLevelForCustomPresets',
    'PaintPixelForCurrentSymmetry',
    'PutRandomByteInAccumulator',
    'smoothingDelayArray,X',
    'PaintCursorAtCurrentPosition',
    'DrawCursorAndReturnFromInterrupt',
    'trackingActivated',
    'demoModeActive',
    'offsetToColorBar',
    'skipPixel',
    'colorRamHiPtr',
    'InitializeProgram',
    'ReturnEarlyFromRoutine',
    'pixelXPositionArray',
    'pixelYPositionArray',
    'initialSmoothingDelayArray',
    'patternIndexArray',
    'symmetrySettingForStepCount',
    'ResetSelectedVariableAndReturn',
    'DisplayVariableSelection',
    'MaybeInColorMode',
    'LoadSelectedPresetSequence',
    'UpdateDataFreeDisplay',
    'dataFreeForSequencer',
    'recordingOffset',
    'previousPixelXPosition',
    'previousPixelYPosition',
    'presetSequenceDataLoPtr',
    'presetSequenceDataHiPtr',
    'minIndexToColorValues',
    'colorRamLoPtr',
    'presetTempLoPtr',
    'presetTempHiPtr',
    'InitializeScreenWithInitCharacter',
    'ActuallyPaintPixel',
    'presetColorValuesArray',
    'PaintStructureAtCurrentPosition',
    'countToMatchCurrentIndex',
    'patternIndex',
    'countStepsBeforeCheckingJoystickInput',
    'CheckIfCursorMovedLeftOrRight',
    'CheckIfPlayerPressedFire',
    'stepsSincePressedFire',
    'currentPulseWidth',
    'lineModeActivated',
    'baseLevel',
    'smoothingDelay',
    'DisplayLoadOrAbort',
    'DisplaySequencerState',
    'dataFreeDigitOne',
    'currentNodeInColorBar',
    'currentCountInDrawingColorBar',
    'maxToDrawOnColorBar',
    'enterWasPressed',
    'GetPresetPointersUsingXRegister',
    'ReturnPressed',
    'MoveToNextBurstPosition',
    'MoveToNextPositionInSequencer',
    'DisplayStoppedRecording',
    'previousCursorXPosition',
    'previousCursorYPosition',
    'ResetSavingStateAndReturn',
    'ReturnFromSave',
    'joystickInputRandomizer',
    'offsetForYPos',
    'colorBarScreenRamLoPtr',
    'presetLoPtr',
    'presetHiPtr',
    'shiftKey',
    'indexOfCurrentColor',
    'dynamicStorageHiPtr',
    'MovePresetDataIntoPosition',
    'colorRAMLineTableHiPtrArray',
    'colorRAMLineTableLoPtrArray',
    'InitializeDynamicStorage',
    'LaunchPsychedelia',
    'LoadXAndYPosition',
    'PixelPaintLoop',
    'RestorePositionsAndReturn',
    'ReinitializeSequences',
    'SetUpInterruptHandlers',
    'HandleCustomPreset',
    'DisplaySavePromptScreen',
    'PaintLineMode',
    'SequencerNotActiveCheckJoystickInput',
    'sequencerSpeed',
    'LoadDataForSequencer',
    'CheckKeyboardAndReturnFromInterrupt',
    'GetJoystickInput',
    '#JOYSTICK_RIGHT',
    'DecrementPulseSpeedCounter',
    'currentPulseSpeedCounter',
    'CheckKeyboardInput',
    'LoadXAndYOfCursorPosition',
    'indexForColorBarDisplay',
    'CheckKeyboardInputForActiveVariableMode',
    'MaybeDisplayDemoModeMessage',
    'GetCustomPatternElement',
    'JustSPressed',
    'PromptToSave',
    'JustLPressed',
    'Controls',
    'DisplayPresetMessage',
    'MaybeQPressed',
    'functionKeyIndex',
    'LoadOrProgramBurstGenerator',
    'ActivateSequencer',
    'StopOrStartRecording',
    'pixelShapeIndex',
    'statusLineBuffer',
    'DrawColorValueBar',
    'currentColorBarOffset',
    'CheckKeyboardWhilePromptActive',
    'CheckIfEnterPressed',
    'ReachedLastColor',
    'SelectNewPreset',
    'MaybeEditCustomPattern',
    'UpdateCurrentActivePreset',
    'WriteLastLineBufferAndReturn',
    'RefreshPresetData',
    'ResetCurrentActiveMode',
    'presetSequenceData',
    'LoadBurstData',
    'CheckKeyboardInputForCustomPresets',
    'CheckKeyboardInputWhileSavePromptActive',
    'CheckKeyboardInputWhileLoadAbortActive',
    'UpdateDataFreeLoop',
    'DecrementDataFreeCounterAndLoop',
    'prevSequencePtrLo',
    'prevSequencePtrHi',
    'prevSymmetrySetting',
    'burstSmoothingDelay',
    'dynamicStorage',
    'DynamicStorageInitLoop',
    'RecordJoystickMovements',
    'MaybePerformRandomJoystickMovement',
    'NoMoreBytes',
    'customPatternIndex',
    'EnterPressed',
    'ReturnFromPromptToSave',
    'ResetStateAndClearPrompt',
    'joystickInputDebounce',
    'starOneXPosArray',
    'starOneYPosArray',
    'customPattern0XPosArray',
    'customPattern1XPosArray',
    'customPattern2XPosArray',
    'customPattern3XPosArray',
    'customPattern4XPosArray',
    'customPattern5XPosArray',
    'customPattern6XPosArray',
    'customPattern7XPosArray',
    'customPattern0YPosArray',
    'customPattern1YPosArray',
    'customPattern2YPosArray',
    'customPattern3YPosArray',
    'customPattern4YPosArray',
    'customPattern5YPosArray',
    'customPattern6YPosArray',
    'customPattern7YPosArray',
    'theTwistXPosArray',
    'theTwistYPosArray',
    'laLlamitaXPosArray',
    'laLlamitaYPosArray',
    'starTwoXPosArray',
    'starTwoYPosArray',
    'deltoidXPosArray',
    'deltoidYPosArray',
    'diffusedXPosArray',
    'diffusedYPosArray',
    'multicrossXPosArray',
    'multicrossYPosArray',
    'pulsarXPosArray',
    'pulsarYPosArray',
    'burstGeneratorF1',
    'burstGeneratorF2',
    'burstGeneratorF3',
    'burstGeneratorF4',
    'pubescent',
    'Minter',
    'Popular Computing Weekly',
    'VIC20',
    'C64',
    'Virtual Light Machine',
    'Batalyx',
    'Jeffrey Says',
]))

# %%
import os
import re
src_dir = "../src/"
for chapter in chapters:
    esc = ""
    lines_out = []
    fname = src_dir + os.sep + chapter
    lines = open(fname,'r').readlines()
    for l in lines:
        for k in keywords:
            n = k + esc + "\\\\index{" + k + "}" + esc
            l = re.sub("\\b"+k+"\\b",n,l)
            #l = l.replace(k, k + esc + "\\index{" + k + "}" + esc)

        if "begin{lstlisting}" in l:
            esc = "%"
            if "]" in l:
                l = l.replace("]",",escapechar=\%]")
            else:
                l = l.replace("}","}[escapechar=\%]")
        if "end{lstlisting}" in l:
            esc = ""
        lines_out += [l]
    open(fname,'w').writelines(lines_out)
