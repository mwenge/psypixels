# %% [markdown]
# # Colorspace - Screen RAM Table

# %% [markdown]
# Create png files based on the screen dump from the atari800 emulation of colourspace.

# %% [markdown]
# Download our modified version of the atari800 emulator. This will allow us to create dump files of screen memory at specified trace points while colourspace is running.

# %%
import os
! rm -rf atari800
! git clone https://github.com/mwenge/atari800.git
os.chdir('atari800')
! git checkout memwatch
! ./autogen.sh
! ./configure --enable-monitormemorywatch
! make -j5
os.chdir('..')
# Out:
# Cloning into 'atari800'...
# remote: Enumerating objects: 17549, done.
# remote: Counting objects: 100% (1510/1510), done.
# remote: Compressing objects: 100% (475/475), done.
# remote: Total 17549 (delta 1069), reused 1420 (delta 1032), pack-reused 16039
# Receiving objects: 100% (17549/17549), 5.75 MiB | 2.88 MiB/s, done.
# Resolving deltas: 100% (13512/13512), done.
# Branch 'memwatch' set up to track remote branch 'memwatch' from 'origin'.
# Switched to a new branch 'memwatch'
# configure.ac:26: warning: The macro `AC_CONFIG_HEADER' is obsolete.
# configure.ac:26: You should run autoupdate.
# ./lib/autoconf/status.m4:719: AC_CONFIG_HEADER is expanded from...
# configure.ac:26: the top level
# configure.ac:340: warning: The macro `AC_HEADER_STDC' is obsolete.
# configure.ac:340: You should run autoupdate.
# ./lib/autoconf/headers.m4:704: AC_HEADER_STDC is expanded from...
# configure.ac:340: the top level
# configure.ac:341: warning: The macro `AC_HEADER_TIME' is obsolete.
# configure.ac:341: You should run autoupdate.
# ./lib/autoconf/headers.m4:743: AC_HEADER_TIME is expanded from...
# configure.ac:341: the top level
# configure.ac:526: warning: The macro `AC_TYPE_SIGNAL' is obsolete.
# configure.ac:526: You should run autoupdate.
# ./lib/autoconf/types.m4:776: AC_TYPE_SIGNAL is expanded from...
# configure.ac:526: the top level
# configure.ac:532: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:532: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:532: the top level
# configure.ac:631: warning: The macro `AC_TRY_COMPILE' is obsolete.
# configure.ac:631: You should run autoupdate.
# ./lib/autoconf/general.m4:2847: AC_TRY_COMPILE is expanded from...
# lib/m4sugar/m4sh.m4:692: _AS_IF_ELSE is expanded from...
# lib/m4sugar/m4sh.m4:699: AS_IF is expanded from...
# ./lib/autoconf/general.m4:2249: AC_CACHE_VAL is expanded from...
# ./lib/autoconf/general.m4:2270: AC_CACHE_CHECK is expanded from...
# configure.ac:589: AX_FUNC_MKDIR is expanded from...
# configure.ac:631: the top level
# configure.ac:643: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:643: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# ./lib/autoconf/general.m4:1553: AC_ARG_WITH is expanded from...
# configure.ac:643: the top level
# configure.ac:673: warning: The macro `AC_TRY_RUN' is obsolete.
# configure.ac:673: You should run autoupdate.
# ./lib/autoconf/general.m4:2997: AC_TRY_RUN is expanded from...
# m4/sdl.m4:15: AM_PATH_SDL is expanded from...
# configure.ac:264: TRY_USE_SDL is expanded from...
# configure.ac:673: the top level
# configure.ac:673: warning: The macro `AC_TRY_LINK' is obsolete.
# configure.ac:673: You should run autoupdate.
# ./lib/autoconf/general.m4:2920: AC_TRY_LINK is expanded from...
# m4/sdl.m4:15: AM_PATH_SDL is expanded from...
# configure.ac:264: TRY_USE_SDL is expanded from...
# configure.ac:673: the top level
# configure.ac:787: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:787: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:787: the top level
# configure.ac:796: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:796: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:796: the top level
# configure.ac:804: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:804: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:804: the top level
# configure.ac:811: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:811: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:811: the top level
# configure.ac:822: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:822: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:822: the top level
# configure.ac:827: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:827: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:827: the top level
# configure.ac:836: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:836: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:836: the top level
# configure.ac:842: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:842: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:842: the top level
# configure.ac:859: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:859: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:859: the top level
# configure.ac:864: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:864: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:864: the top level
# configure.ac:872: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:872: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:872: the top level
# configure.ac:877: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:877: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:877: the top level
# configure.ac:882: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:882: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:882: the top level
# configure.ac:890: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:890: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:890: the top level
# configure.ac:895: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:895: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:895: the top level
# configure.ac:900: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:900: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:900: the top level
# configure.ac:905: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:905: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:905: the top level
# configure.ac:913: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:913: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# lib/m4sugar/m4sh.m4:699: AS_IF is expanded from...
# ./lib/autoconf/libs.m4:100: AC_CHECK_LIB is expanded from...
# configure.ac:913: the top level
# configure.ac:922: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:922: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:922: the top level
# configure.ac:928: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:928: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:928: the top level
# configure.ac:936: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:936: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# ./lib/autoconf/general.m4:1553: AC_ARG_WITH is expanded from...
# configure.ac:936: the top level
# configure.ac:998: warning: The macro `AC_TRY_RUN' is obsolete.
# configure.ac:998: You should run autoupdate.
# ./lib/autoconf/general.m4:2997: AC_TRY_RUN is expanded from...
# m4/sdl.m4:15: AM_PATH_SDL is expanded from...
# configure.ac:264: TRY_USE_SDL is expanded from...
# configure.ac:998: the top level
# configure.ac:998: warning: The macro `AC_TRY_LINK' is obsolete.
# configure.ac:998: You should run autoupdate.
# ./lib/autoconf/general.m4:2920: AC_TRY_LINK is expanded from...
# m4/sdl.m4:15: AM_PATH_SDL is expanded from...
# configure.ac:264: TRY_USE_SDL is expanded from...
# configure.ac:998: the top level
# configure.ac:1063: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:1063: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:1063: the top level
# configure.ac:1074: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:1074: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:1074: the top level
# configure.ac:1079: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:1079: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:1079: the top level
# configure.ac:1084: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:1084: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:1084: the top level
# configure.ac:1090: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:1090: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:1090: the top level
# configure.ac:1096: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:1096: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:1096: the top level
# configure.ac:1100: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:1100: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:1100: the top level
# configure.ac:1109: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:1109: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:1109: the top level
# configure.ac:1113: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:1113: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:1113: the top level
# configure.ac:1117: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:1117: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:1117: the top level
# configure.ac:1121: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:1121: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:1121: the top level
# configure.ac:1128: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:1128: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# ./lib/autoconf/general.m4:1553: AC_ARG_WITH is expanded from...
# configure.ac:1128: the top level
# configure.ac:1187: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:1187: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:1187: the top level
# configure.ac:1191: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:1191: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:1191: the top level
# configure.ac:1224: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:1224: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:1224: the top level
# configure.ac:1234: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:1234: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:1234: the top level
# configure.ac:1247: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:1247: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:1247: the top level
# configure.ac:1257: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:1257: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:1257: the top level
# configure.ac:1267: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:1267: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:1267: the top level
# configure.ac:1276: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:1276: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# ./lib/autoconf/general.m4:1553: AC_ARG_WITH is expanded from...
# configure.ac:1276: the top level
# configure.ac:1319: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:1319: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:1319: the top level
# configure.ac:1349: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:1349: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:1349: the top level
# configure.ac:1360: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:1360: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:1360: the top level
# configure.ac:1370: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:1370: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:1370: the top level
# configure.ac:1378: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:1378: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:1378: the top level
# configure.ac:1400: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:1400: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:1400: the top level
# configure.ac:1405: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:1405: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:1405: the top level
# configure.ac:1410: warning: The macro `AC_HELP_STRING' is obsolete.
# configure.ac:1410: You should run autoupdate.
# ./lib/autoconf/general.m4:204: AC_HELP_STRING is expanded from...
# configure.ac:771: A8_OPTION is expanded from...
# configure.ac:1410: the top level
# configure.ac:204: installing './compile'
# configure.ac:73: installing './install-sh'
# configure.ac:73: installing './missing'
# src/Makefile.am: installing './depcomp'
#
# Now you need to run the configure script.  The configure script may take the
# "--target=TARGET" option and various "--enable-FEATURE" and "--with-PACKAGE"
# options.
#
# Run "./configure --help" to see all available options.
# Run "./configure --help=short" just to see the Atari800 FEATURE options.
# Run "./configure --target=help" without a parameter to see the valid targets.
#
# checking build system type... x86_64-unknown-linux-gnu
# checking host system type... x86_64-unknown-linux-gnu
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a race-free mkdir -p... /usr/bin/mkdir -p
# checking for gawk... no
# checking for mawk... mawk
# checking whether make sets $(MAKE)... yes
# checking whether make supports nested variables... yes
# checking whether to enable maintainer-specific portions of Makefiles... yes
# checking whether make supports nested variables... (cached) yes
# checking for gcc... gcc
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether the compiler supports GNU C... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to enable C11 features... none needed
# checking whether gcc understands -c and -o together... yes
# checking whether make supports the include directive... yes (GNU style)
# checking dependency style of gcc... gcc3
# checking whether gcc and cc understand -c and -o together... yes
# checking for ranlib... ranlib
# checking for windres... no
# checking whether host is Java NestedVM... no
# checking how to run the C preprocessor... gcc -E
# checking for X... libraries , headers
# checking for dirent.h that defines DIR... yes
# checking for library containing opendir... none required
# checking for stdio.h... yes
# checking for stdlib.h... yes
# checking for string.h... yes
# checking for inttypes.h... yes
# checking for stdint.h... yes
# checking for strings.h... yes
# checking for sys/stat.h... yes
# checking for sys/types.h... yes
# checking for unistd.h... yes
# checking for sys/time.h... yes
# checking for sys/select.h... yes
# checking for sys/socket.h... yes
# checking for grep that handles long lines and -e... /usr/bin/grep
# checking for egrep... /usr/bin/grep -E
# checking for uintptr_t... yes
# checking for direct.h... no
# checking for errno.h... yes
# checking for file.h... no
# checking for signal.h... yes
# checking for sys/time.h... (cached) yes
# checking for time.h... yes
# checking for unistd.h... (cached) yes
# checking for unixio.h... no
# checking whether termios.h defines TIOCGWINSZ... no
# checking whether sys/ioctl.h defines TIOCGWINSZ... yes
# checking for fcntl.h... yes
# checking for sys/ioctl.h... yes
# checking for sys/soundcard.h... yes
# checking for arpa/inet.h... yes
# checking for netdb.h... yes
# checking for netinet/in.h... yes
# checking for sys/socket.h... (cached) yes
# checking for termios.h... yes
# checking for gzopen in -lz... yes
# checking for png_get_libpng_ver in -lpng... yes
# checking for cos in -lm... yes
# checking for _oss_ioctl in -lossaudio... no
# checking whether byte ordering is bigendian... no
# checking for an ANSI C-conforming const... yes
# checking for inline... __inline__
# checking for working volatile... yes
# checking whether gcc needs -traditional... no
# checking whether struct tm is in sys/time.h or time.h... time.h
# checking return type of signal handlers... void
# checking for size_t... yes
# checking for unaligned word access validity... yes
# checking whether closedir returns void... no
# checking for working memcmp... yes
# checking types of arguments for select... int,fd_set *,struct timeval *
# checking whether lstat correctly handles trailing slash... yes
# checking whether stat accepts an empty string... no
# checking for vprintf... yes
# checking for atexit... yes
# checking for chmod... yes
# checking for clock... yes
# checking for fdopen... yes
# checking for fflush... yes
# checking for floor... yes
# checking for fstat... yes
# checking for getcwd... yes
# checking for gettimeofday... yes
# checking for localtime... yes
# checking for memmove... yes
# checking for memset... yes
# checking for mkstemp... yes
# checking for mktemp... yes
# checking for modf... yes
# checking for nanosleep... yes
# checking for opendir... yes
# checking for rename... yes
# checking for rewind... yes
# checking for rmdir... yes
# checking for signal... yes
# checking for snprintf... yes
# checking for stat... yes
# checking for strcasecmp... yes
# checking for strchr... yes
# checking for strdup... yes
# checking for strerror... yes
# checking for strrchr... yes
# checking for strstr... yes
# checking for strtol... yes
# checking for system... yes
# checking for time... yes
# checking for tmpfile... yes
# checking for tmpnam... yes
# checking for uclock... no
# checking for unlink... yes
# checking for vsnprintf... yes
# checking for popen... yes
# checking for mkdir... yes
# checking for _mkdir... no
# checking whether mkdir takes one argument... no
# checking for select... yes
# checking for usleep... yes
# checking for strncpy... yes
# checking for gethostbyaddr... yes
# checking for gethostbyname... yes
# checking for inet_ntoa... yes
# checking for socket... yes
# checking for sdl-config... /usr/bin/sdl-config
# checking for SDL - version >= 1.2.0... yes
# checking for adler32 in -lz... yes
# checking for main in -lwinmm... no
# checking for lame_init in -lmp3lame... no
# checking for special C compiler options needed for large files... no
# checking for _FILE_OFFSET_BITS value needed for large files... no
# checking for _LARGEFILE_SOURCE value needed for large files... no
# checking for special C compiler options needed for large files... (cached) no
# checking for _FILE_OFFSET_BITS value needed for large files... (cached) no
# checking for library containing tgetent... -ltermcap
# checking for library containing readline... no
# checking for SDL_opengl.h... yes
# checking that generated files are newer than configure... done
# configure: creating ./config.status
# config.status: creating Makefile
# config.status: creating DOC/Makefile
# config.status: creating src/Makefile
# config.status: creating tools/Makefile
# config.status: creating src/config.h
# config.status: executing depfiles commands
# -------------------------------------------------------
#                  CONFIGURATION RESULTS:
# -------------------------------------------------------
# Host OS...............................: linux
# Target ...............................: default
#
# Interface for video...................: sdl
# Using screenshots?....................: yes
#     Supported screenshot formats......: pcx png
# Using cycle exact?....................: yes
# Using the very slow computer support?.: no
# Using the crash menu?.................: yes
# Using the paged attribute array?......: no
# Using per opcode cycles update?.......: no
# Using the buffered log?...............: no
# Using Altirra BIOS ROM?...............: yes
# Using the monitor assembler?..........: yes
# Using code breakpoints and history?...: yes
# Using user-defined breakpoints?.......: no
# Using monitor hints?..................: yes
# Using 6502 opcode profiling?..........: no
# Using TRACE monitor command?..........: no
# Using readline support in monitor?....: no
# Using UTF-8 support in monitor?.......: yes
# Using ANSI color support in monitor?..: yes
# Using event recording?................: yes
# Using MIO emulation?..................: yes
# Using Black Box emulation?............: yes
# Using IDE emulation?..................: yes
# Using Pokey registers recording?......: yes
# Interface for sound...................: sdl
#     Using nonlinear mixing?...........: yes
#     Using synchronized sound?.........: yes
#     Using sound interpolation?........: yes
#     Using stereo sound?...............: yes
#     Using volume only sound?..........:
#         (Volume only sound sub-options disabled)
#     Using 1400XL/1450XLD emulation?...: yes
#     Using sound clipping?.............: no
#     Using audio recording?............: yes
#         Supported audio codecs........: pcm adpcm mulaw
# Using video recording?................: yes
#     Supported video codecs............: rle png zmbv
# Using R: device?......................: yes
#     Using R: with the host serial port?...: yes
#     Using R: with IP network support......: yes
# Using on-screen keyboard?.............: no
# Using OpenGL?.........................: yes
#
# Main build variables:
#     CC......: "gcc"
#     ASFLAGS.: "-quiet -devpac -opt-allbra -Faout -DNEW_CYCLE_EXACT -DCRASH_MENU -DMONITOR_BREAK"
#     CFLAGS..: "-O2 -Wall -ansi -pedantic -Wmissing-declarations -Wmissing-prototypes -Wstrict-prototypes -Winline -Wredundant-decls"
#     CPPFLAGS: " -I/usr/include/SDL -D_GNU_SOURCE=1 -D_REENTRANT"
#     LDFLAGS.: ""
#     LIBS....: "-ltermcap -lm -lz  -L/usr/lib/x86_64-linux-gnu -lSDL -lpng"
# -------------------------------------------------------
#
# Now run "gmake" or "make".
# Making all in DOC
# make[1]: Entering directory '/home/robert/Dev/psypixels/notebooks/atari800/DOC'
# make[1]: Nothing to be done for 'all'.
# make[1]: Leaving directory '/home/robert/Dev/psypixels/notebooks/atari800/DOC'
# Making all in src
# make[1]: Entering directory '/home/robert/Dev/psypixels/notebooks/atari800/src'
# make  all-am
# make[2]: Entering directory '/home/robert/Dev/psypixels/notebooks/atari800/src'
#   CC       atari800-afile.o
#   CC       atari800-antic.o
#   CC       atari800-atari.o
#   CC       atari800-binload.o
#   CC       atari800-cartridge.o
#   CC       atari800-cartridge_info.o
#   CC       atari800-cassette.o
#   CC       atari800-compfile.o
#   CC       atari800-cfg.o
#   CC       atari800-cpu.o
#   CC       atari800-crc32.o
#   CC       atari800-devices.o
#   CC       atari800-esc.o
#   CC       atari800-gtia.o
# In file included from /usr/include/string.h:535,
#                  from devices.c:32:
# In function ‘memcpy’,
#     inlined from ‘Devices_RestoreHandler’ at devices.c:2148:2,
#     inlined from ‘Devices_RestoreEHWRIT’ at devices.c:2173:2,
#     inlined from ‘Devices_IgnoreReady’ at devices.c:2238:2:
# /usr/include/x86_64-linux-gnu/bits/string_fortified.h:29:10: warning: ‘__builtin_memcpy’ offset [0, 2] is out of the bounds [0, 0] [-Warray-bounds]
#    29 |   return __builtin___memcpy_chk (__dest, __src, __len,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    30 |                                  __glibc_objsize0 (__dest));
#       |                                  ~~~~~~~~~~~~~~~~~~~~~~~~~~
#   CC       atari800-img_tape.o
# In function ‘memcpy’,
#     inlined from ‘Devices_RestoreHandler’ at devices.c:2148:2,
#     inlined from ‘Devices_RestoreEHWRIT’ at devices.c:2173:2:
# /usr/include/x86_64-linux-gnu/bits/string_fortified.h:29:10: warning: ‘__builtin_memcpy’ offset [0, 2] is out of the bounds [0, 0] [-Warray-bounds]
#    29 |   return __builtin___memcpy_chk (__dest, __src, __len,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    30 |                                  __glibc_objsize0 (__dest));
#       |                                  ~~~~~~~~~~~~~~~~~~~~~~~~~~
# In function ‘memcpy’,
#     inlined from ‘Devices_RestoreHandler’ at devices.c:2148:2,
#     inlined from ‘Devices_RestoreEHCLOS’ at devices.c:2161:2:
# /usr/include/x86_64-linux-gnu/bits/string_fortified.h:29:10: warning: ‘__builtin_memcpy’ offset [0, 2] is out of the bounds [0, 0] [-Warray-bounds]
#    29 |   return __builtin___memcpy_chk (__dest, __src, __len,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    30 |                                  __glibc_objsize0 (__dest));
#       |                                  ~~~~~~~~~~~~~~~~~~~~~~~~~~
# In function ‘memcpy’,
#     inlined from ‘Devices_RestoreHandler’ at devices.c:2148:2,
#     inlined from ‘Devices_RestoreEHREAD’ at devices.c:2168:2:
# /usr/include/x86_64-linux-gnu/bits/string_fortified.h:29:10: warning: ‘__builtin_memcpy’ offset [0, 2] is out of the bounds [0, 0] [-Warray-bounds]
#    29 |   return __builtin___memcpy_chk (__dest, __src, __len,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    30 |                                  __glibc_objsize0 (__dest));
#       |                                  ~~~~~~~~~~~~~~~~~~~~~~~~~~
# In function ‘memcpy’,
#     inlined from ‘Devices_RestoreHandler’ at devices.c:2148:2,
#     inlined from ‘Devices_RestoreEHOPEN’ at devices.c:2156:2:
# /usr/include/x86_64-linux-gnu/bits/string_fortified.h:29:10: warning: ‘__builtin_memcpy’ offset [0, 2] is out of the bounds [0, 0] [-Warray-bounds]
#    29 |   return __builtin___memcpy_chk (__dest, __src, __len,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    30 |                                  __glibc_objsize0 (__dest));
#       |                                  ~~~~~~~~~~~~~~~~~~~~~~~~~~
# In function ‘memcpy’,
#     inlined from ‘Devices_RestoreHandler’ at devices.c:2148:2,
#     inlined from ‘Devices_RestoreEHREAD’ at devices.c:2168:2,
#     inlined from ‘Devices_CloseBasicFile’ at devices.c:2370:2:
# /usr/include/x86_64-linux-gnu/bits/string_fortified.h:29:10: warning: ‘__builtin_memcpy’ offset [0, 2] is out of the bounds [0, 0] [-Warray-bounds]
#    29 |   return __builtin___memcpy_chk (__dest, __src, __len,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    30 |                                  __glibc_objsize0 (__dest));
#       |                                  ~~~~~~~~~~~~~~~~~~~~~~~~~~
#   CC       atari800-log.o
#   CC       atari800-memory.o
#   CC       atari800-monitor.o
#   CC       atari800-pbi.o
#   CC       atari800-pia.o
#   CC       atari800-pokey.o
#   CC       atari800-rtime.o
#   CC       atari800-sio.o
#   CC       atari800-sysrom.o
#   CC       atari800-util.o
#   CC       atari800-pokeysnd.o
#   CC       atari800-mzpokeysnd.o
#   CC       atari800-remez.o
#   CC       atari800-sound.o
#   CC       sdl/atari800-sound.o
#   CC       atari800-pokeyrec.o
#   CC       atari800-file_export.o
#   CC       codecs/atari800-container.o
#   CC       codecs/atari800-container_wav.o
#   CC       codecs/atari800-audio.o
#   CC       codecs/atari800-audio_pcm.o
#   CC       codecs/atari800-audio_adpcm.o
#   CC       codecs/atari800-audio_mulaw.o
#   CC       codecs/atari800-container_avi.o
#   CC       codecs/atari800-video.o
#   CC       codecs/atari800-video_mrle.o
#   CC       codecs/atari800-video_mpng.o
#   CC       codecs/atari800-video_zmbv.o
#   CC       atari800-videomode.o
#   CC       sdl/atari800-main.o
#   CC       sdl/atari800-video.o
#   CC       sdl/atari800-video_sw.o
#   CC       sdl/atari800-input.o
#   CC       sdl/atari800-palette.o
#   CC       atari800-pbi_proto80.o
#   CC       atari800-af80.o
#   CC       atari800-bit3.o
#   CC       atari800-input.o
#   CC       atari800-statesav.o
#   CC       atari800-ui_basic.o
#   CC       atari800-ui.o
#   CC       atari800-artifact.o
#   CC       atari800-colours.o
#   CC       atari800-colours_ntsc.o
#   CC       atari800-colours_pal.o
#   CC       atari800-colours_external.o
#   CC       atari800-screen.o
#   CC       atari800-cycle_map.o
#   CC       roms/atari800-altirraos_800.o
#   CC       roms/atari800-altirraos_xl.o
#   CC       roms/atari800-altirra_basic.o
#   CC       atari800-pbi_mio.o
#   CC       atari800-pbi_bb.o
#   CC       atari800-pbi_scsi.o
#   CC       atari800-pbi_xld.o
#   CC       atari800-voicebox.o
#   CC       atari800-votrax.o
# ui.c: In function ‘DiskManagement’:
# ui.c:909:50: warning: array subscript -1 is outside array bounds of ‘char[4096]’ [-Warray-bounds]
#   909 |                                                 q[-1] = '\0';
#       |                                                 ~^~~~
# ui.c:881:38: note: while referencing ‘uncompr_filename’
#   881 |                                 char uncompr_filename[FILENAME_MAX];
#       |                                      ^~~~~~~~~~~~~~~~
#   CC       atari800-votraxsnd.o
#   CC       atari800-ide.o
#   CC       sdl/atari800-video_gl.o
#   CC       atari800-xep80.o
# In file included from sdl/video_gl.c:26:
# /usr/include/SDL/SDL_opengl.h:116: warning: "GL_GLEXT_VERSION" redefined
#   116 | #define GL_GLEXT_VERSION 29
#       |
# In file included from /usr/include/GL/gl.h:2050,
#                  from /usr/include/SDL/SDL_opengl.h:46,
#                  from sdl/video_gl.c:26:
# /usr/include/GL/glext.h:54: note: this is the location of the previous definition
#    54 | #define GL_GLEXT_VERSION 20190805
#       |
#   CC       atari800-xep80_fonts.o
#   CC       atari800-filter_ntsc.o
#   CC       atari800-pal_blending.o
#   CC       atari800-rdevice.o
#   CC       roms/atari800-altirra_5200_os.o
#   CC       roms/atari800-altirra_5200_charset.o
#   CC       sdl/atari800-init.o
#   CC       codecs/atari800-image.o
#   CC       codecs/atari800-image_pcx.o
#   CC       codecs/atari800-image_png.o
#   CC       atari_ntsc/atari800-atari_ntsc.o
#   CCLD     atari800
# make[2]: Leaving directory '/home/robert/Dev/psypixels/notebooks/atari800/src'
# make[1]: Leaving directory '/home/robert/Dev/psypixels/notebooks/atari800/src'
# Making all in tools
# make[1]: Entering directory '/home/robert/Dev/psypixels/notebooks/atari800/tools'
#   CC       cart.o
#   CC       ../src/cartridge_info.o
#   CCLD     cart
# make[1]: Leaving directory '/home/robert/Dev/psypixels/notebooks/atari800/tools'
# make[1]: Entering directory '/home/robert/Dev/psypixels/notebooks/atari800'
# make[1]: Nothing to be done for 'all-am'.
# make[1]: Leaving directory '/home/robert/Dev/psypixels/notebooks/atari800'

# %% [markdown]
# Run the atari800 emulator and write the screen memory dumps to a file.

# %%
! ./atari800/src/atari800 -memwatchbpc 44BF -memwatchfile foreground_screen_mode.txt ../psychedelia/bin/colourspace.xex
# Out:
# Using Atari800 config file: /home/robert/.atari800.cfg
# Created by Atari 800 Emulator, Version 5.0.0
#
# Memory Watch file open
# Keyboard mapped to emulated joystick 0
# Requested resolution 336x240 is not available, using 640x480 instead.
# Video Mode: 336x240x32 windowed without vsync

# %% [markdown]
# Read in the ram history from our dump file.

# %%
log_file = "foreground_screen_mode.txt"
input_file = open(log_file,'r')

flatten = lambda l: [e for sublist in l for e in sublist]

ram_history = []
lines = input_file.readlines()
for i in range(1, len(lines), 131):
    # Screen RAM (7000-8000)
    pixel_ram = [l[6:126].split() for l in lines[i:i+104]][:40]
    # Color Registers
    color_registers = [int(i,16) for i in lines[i+129].split()[1:10]]
    ram_history += [(pixel_ram, color_registers)]

# %%
ram_history[200]
# Out:
# ([['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '80',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '10',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '01',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '01',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '10',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '10',
#    '00',
#    '01',
#    '00',
#    '10',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '01',
#    '00',
#    '10',
#    '00',
#    '01',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '02',
#    '01',
#    '00',
#    '10',
#    '01',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '10',
#    '01',
#    '00',
#    '10',
#    '20',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '01',
#    '20',
#    '10',
#    '01',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '10',
#    '01',
#    '02',
#    '10',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '01',
#    '00',
#    '12',
#    '01',
#    '00',
#    '20',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '02',
#    '00',
#    '10',
#    '21',
#    '00',
#    '10',
#    '00',
#    '00'],
#   ['00',
#    '01',
#    '00',
#    '10',
#    '01',
#    '20',
#    '20',
#    '02',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '20',
#    '02',
#    '02',
#    '10',
#    '01',
#    '00',
#    '10',
#    '00'],
#   ['01',
#    '00',
#    '10',
#    '01',
#    '00',
#    '22',
#    '02',
#    '00',
#    '20',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '02',
#    '00',
#    '20',
#    '22',
#    '00',
#    '10',
#    '01',
#    '00',
#    '10'],
#   ['00',
#    '10',
#    '01',
#    '00',
#    '20',
#    '12',
#    '20',
#    '20',
#    '02',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '20',
#    '02',
#    '02',
#    '21',
#    '02',
#    '00',
#    '10',
#    '01',
#    '00'],
#   ['00',
#    '01',
#    '00',
#    '20',
#    '02',
#    '00',
#    '23',
#    '02',
#    '00',
#    '30',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '03',
#    '00',
#    '20',
#    '32',
#    '00',
#    '20',
#    '02',
#    '00',
#    '10',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '02',
#    '00',
#    '20',
#    '12',
#    '30',
#    '30',
#    '03',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '30',
#    '03',
#    '03',
#    '21',
#    '02',
#    '00',
#    '20',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '20',
#    '02',
#    '02',
#    '33',
#    '03',
#    '00',
#    '30',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '03',
#    '00',
#    '30',
#    '33',
#    '20',
#    '20',
#    '02',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '02',
#    '00',
#    '30',
#    '23',
#    '30',
#    '30',
#    '03',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '30',
#    '03',
#    '03',
#    '32',
#    '03',
#    '00',
#    '20',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '30',
#    '03',
#    '02',
#    '33',
#    '03',
#    '00',
#    '30',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '03',
#    '00',
#    '30',
#    '33',
#    '20',
#    '30',
#    '03',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '03',
#    '00',
#    '30',
#    '23',
#    '40',
#    '30',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '03',
#    '04',
#    '32',
#    '03',
#    '00',
#    '30',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '30',
#    '03',
#    '02',
#    '34',
#    '04',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '40',
#    '43',
#    '20',
#    '30',
#    '03',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '03',
#    '00',
#    '30',
#    '24',
#    '40',
#    '40',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '04',
#    '04',
#    '42',
#    '03',
#    '00',
#    '30',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '30',
#    '04',
#    '03',
#    '44',
#    '04',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '40',
#    '44',
#    '30',
#    '40',
#    '03',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '40',
#    '34',
#    '50',
#    '40',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '04',
#    '05',
#    '43',
#    '04',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '04',
#    '03',
#    '40',
#    '05',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '50',
#    '04',
#    '30',
#    '40',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '40',
#    '45',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '54',
#    '04',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '05',
#    '04',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '40',
#    '50',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '40',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '04',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '04',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '40',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00']],
#  [0, 24, 56, 88, 120, 152, 184, 216, 201])

# %% [markdown]
# Write a series of png files one for each stage of the evolution of the pattern

# %%
import colorspace_colors as cc
color_ram = ram_history[200]
def createLatexEntry(x):
    left_char = x[0]
    right_char = x[1]
    left_color = cc.color_value_to_html[col_register[int(left_char,16)]][1:]
    right_color = cc.color_value_to_html[col_register[int(right_char,16)]][1:]
    return (f"& \\cellcolor[HTML]{{{left_color}}}\\icode{{{left_char}}} & " + 
            f"\\cellcolor[HTML]{{{right_color}}}\\icode{{{right_char}}}") 

output_file = open("screen_ram.tex",'w')
for color_ram, col_register in ram_history[200:201]:
    ln = 0x7000
    for l in color_ram:
        entry = ''.join([createLatexEntry(x) for x in l]) + " \\\\"
        lx = hex(ln).upper()[2:]
        output_file.write(f"\\icode{{\${lx}:}} & &" + entry[2:].replace('000000','ffffff') 
                          + '\n')
        ln += 40

# %%
ram_history[100]
# Out:
# ([['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '01',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '10',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '10',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '01',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '01',
#    '00',
#    '01',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '10',
#    '00',
#    '10',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '10',
#    '00',
#    '10',
#    '00',
#    '00',
#    '00',
#    '00',
#    '10',
#    '00',
#    '00',
#    '00',
#    '00',
#    '01',
#    '00',
#    '00',
#    '00',
#    '00',
#    '01',
#    '00',
#    '01',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '01',
#    '00',
#    '01',
#    '00',
#    '00',
#    '11',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '11',
#    '00',
#    '00',
#    '10',
#    '00',
#    '10',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '10',
#    '00',
#    '10',
#    '00',
#    '11',
#    '10',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '01',
#    '11',
#    '00',
#    '01',
#    '00',
#    '01',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '01',
#    '00',
#    '11',
#    '11',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '11',
#    '11',
#    '00',
#    '10',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '10',
#    '11',
#    '11',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '11',
#    '11',
#    '01',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '11',
#    '11',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '11',
#    '11',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '01',
#    '11',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '11',
#    '10',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '11',
#    '00',
#    '00',
#    '00',
#    '01',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '10',
#    '00',
#    '00',
#    '00',
#    '11',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '01',
#    '00',
#    '00',
#    '00',
#    '00',
#    '10',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '01',
#    '00',
#    '00',
#    '00',
#    '00',
#    '10',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '01',
#    '00',
#    '01',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '10',
#    '00',
#    '10',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '10',
#    '00',
#    '10',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '01',
#    '00',
#    '01',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '01',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '10',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '10',
#    '00',
#    '00',
#    '56',
#    '66',
#    '66',
#    '65',
#    '00',
#    '00',
#    '01',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '05',
#    '05',
#    '00',
#    '06',
#    '60',
#    '00',
#    '50',
#    '50',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '50',
#    '55',
#    '66',
#    '60',
#    '06',
#    '66',
#    '55',
#    '05',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '05',
#    '05',
#    '50',
#    '06',
#    '06',
#    '60',
#    '60',
#    '05',
#    '50',
#    '50',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '50',
#    '05',
#    '56',
#    '56',
#    '06',
#    '60',
#    '65',
#    '65',
#    '50',
#    '05',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '50',
#    '55',
#    '05',
#    '40',
#    '60',
#    '06',
#    '04',
#    '50',
#    '55',
#    '05',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '50',
#    '54',
#    '50',
#    '00',
#    '76',
#    '67',
#    '00',
#    '05',
#    '45',
#    '05',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '45',
#    '50',
#    '40',
#    '00',
#    '76',
#    '67',
#    '00',
#    '04',
#    '05',
#    '54',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '04',
#    '40',
#    '50',
#    '00',
#    '70',
#    '07',
#    '00',
#    '05',
#    '04',
#    '40',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '05',
#    '04',
#    '40',
#    '00',
#    '07',
#    '70',
#    '00',
#    '04',
#    '40',
#    '50',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '04',
#    '00',
#    '84',
#    '00',
#    '07',
#    '70',
#    '00',
#    '40',
#    '00',
#    '40',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '40',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '04',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '04',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '40',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '40',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '04',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00'],
#   ['00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00',
#    '00']],
#  [0, 24, 56, 88, 120, 152, 184, 216, 101])

# %%
import colorspace_colors as cc

from PIL import Image, ImageColor

ROW_LINES = 5
def paintChar(origin, pixels, byte, col_register):
    c, r = origin
    x_o, y_o = c*8, r*ROW_LINES
    left_nibble = byte >> 4 & 0x0F 
    right_nibble = byte & 0x0F
    left_color = cc.color_value_to_html[col_register[left_nibble]]
    right_color = cc.color_value_to_html[col_register[right_nibble]]
    for n in range(0,4):
        for y in range(0,ROW_LINES):
            pixels[x_o+n, y_o+y] = ImageColor.getrgb(left_color)
    for n in range(0,4):
        for y in range(0,ROW_LINES):
            pixels[x_o+n+4, y_o+y] = ImageColor.getrgb(right_color)

for j, (scr, col_register) in enumerate(ram_history[100]):
    cols=len(scr[0])
    rows=len(scr)
    bits=8
    img = Image.new( 'RGB', (cols*bits,rows*ROW_LINES), "black")
    pixels = img.load()
    for y, l in enumerate(scr):
        for x, byte in enumerate(l):
            paintChar((x,y), pixels, byte, col_register)
    img = img.resize((img.width * 4, img.height * 4), Image.NEAREST)
    img.save(f"colorspace_foreground/pixel_pattern_{j}.png")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1363585/3777651949.py in <module>
#      18             pixels[x_o+n+4, y_o+y] = ImageColor.getrgb(right_color)
#      19
# ---> 20 for j, (scr, col_register) in enumerate(ram_history[100]):
#      21     cols=len(scr[0])
#      22     rows=len(scr)
#
# ValueError: too many values to unpack (expected 2)
