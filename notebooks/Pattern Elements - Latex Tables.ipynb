# %% [markdown]
# # Generate Ascii Diagrams of Patterns

# %%
patterns = [
    ("""
starOneXPosArray  .BYTE $00,$01,$01,$01,$00,$FF,$FF,$FF,$55
                  .BYTE $00,$02,$00,$FE,$55                
                  .BYTE $00,$03,$00,$FD,$55                
                  .BYTE $00,$04,$00,$FC,$55                
                  .BYTE $FF,$01,$05,$05,$01,$FF,$FB,$FB,$55
                  .BYTE $00,$07,$00,$F9,$55                
                  .BYTE $55                                
""".split('\n')[1:-1]
    ,"""
starOneYPosArray  .BYTE $FF,$FF,$00,$01,$01,$01,$00,$FF,$55
                  .BYTE $FE,$00,$02,$00,$55                
                  .BYTE $FD,$00,$03,$00,$55                
                  .BYTE $FC,$00,$04,$00,$55                
                  .BYTE $FB,$FB,$FF,$01,$05,$05,$01,$FF,$55
                  .BYTE $F9,$00,$07,$00,$55                
                  .BYTE $55                                
""".split('\n')[1:-1]
      ),
    ("""
theTwistXPosArray .BYTE $00,$55            
                  .BYTE $01,$02,$55        
                  .BYTE $01,$02,$03,$55    
                  .BYTE $01,$02,$03,$04,$55
                  .BYTE $00,$00,$00,$55    
                  .BYTE $FF,$FE,$55        
                  .BYTE $FF,$55            
                  .BYTE $55                
""".split('\n')[1:-1]
    ,"""
theTwistYPosArray .BYTE $FF,$55            
                  .BYTE $FF,$FE,$55        
                  .BYTE $00,$00,$00,$55    
                  .BYTE $01,$02,$03,$04,$55
                  .BYTE $01,$02,$03,$55    
                  .BYTE $01,$02,$55        
                  .BYTE $00,$55            
                  .BYTE $55                
""".split('\n')[1:-1]
      ),
    ("""
laLlamitaXPosArray  .BYTE $00,$FF,$00,$55                
                    .BYTE $00,$00,$55                    
                    .BYTE $01,$02,$03,$00,$01,$02,$03,$55
                    .BYTE $04,$05,$06,$04,$00,$01,$02,$55
                    .BYTE $04,$00,$04,$00,$04,$55        
                    .BYTE $FF,$03,$55                    
                    .BYTE $00,$55                        
""".split('\n')[1:-1]
    ,"""
laLlamitaYPosArray  .BYTE $FF,$00,$01,$55                
                    .BYTE $02,$03,$55                    
                    .BYTE $03,$03,$03,$04,$04,$04,$04,$55
                    .BYTE $03,$02,$03,$04,$05,$05,$05,$55
                    .BYTE $05,$06,$06,$07,$07,$55        
                    .BYTE $07,$07,$55                    
                    .BYTE $00,$55                        
""".split('\n')[1:-1]
      ),
    ("""
starTwoXPosArray  .BYTE $FF,$55                          
                  .BYTE $00,$55                          
                  .BYTE $02,$55                          
                  .BYTE $01,$55                          
                  .BYTE $FD,$55                          
                  .BYTE $FE,$55                          
                  .BYTE $00,$55                          
""".split('\n')[1:-1]
    ,"""
starTwoYPosArray  .BYTE $FF,$55                          
                  .BYTE $FE,$55                          
                  .BYTE $FF,$55                          
                  .BYTE $02,$55                          
                  .BYTE $01,$55                          
                  .BYTE $FC,$55                          
                  .BYTE $00,$55                          
""".split('\n')[1:-1]
      ),
    ("""
deltoidXPosArray  .BYTE $00,$01,$FF,$55                  
                  .BYTE $00,$55                          
                  .BYTE $00,$01,$02,$FE,$FF,$55          
                  .BYTE $00,$03,$FD,$55                  
                  .BYTE $00,$04,$FC,$55                  
                  .BYTE $00,$06,$FA,$55                  
                  .BYTE $00,$55                          
""".split('\n')[1:-1]
    ,"""
deltoidYPosArray  .BYTE $FF,$00,$00,$55                  
                  .BYTE $00,$55
                  .BYTE $FE,$FF,$00,$00,$FF,$55                  
                  .BYTE $FD,$01,$01,$55                  
                  .BYTE $FC,$02,$02,$55                  
                  .BYTE $FA,$04,$04,$55                  
                  .BYTE $00,$55                          
""".split('\n')[1:-1]
      ),
    ("""
diffusedXPosArray .BYTE $FF,$01,$55                      
                  .BYTE $FE,$02,$55                      
                  .BYTE $FD,$03,$55                      
                  .BYTE $FC,$04,$FC,$FC,$04,$04,$55      
                  .BYTE $FB,$05,$55                      
                  .BYTE $FA,$06,$FA,$FA,$06,$06,$55      
                  .BYTE $00,$55                          
""".split('\n')[1:-1]
    ,"""
diffusedYPosArray .BYTE $01,$FF,$55                      
                  .BYTE $FE,$02,$55                      
                  .BYTE $03,$FD,$55                      
                  .BYTE $FC,$04,$FF,$01,$FF,$01,$55      
                  .BYTE $05,$FB,$55
                  .BYTE $FA,$06,$FE,$02,$FE,$02,$55                          
                  .BYTE $00,$55                          
""".split('\n')[1:-1]
      ),
    ("""
multicrossXPosArray .BYTE $01,$01,$FF,$FF,$55                
                    .BYTE $02,$02,$FE,$FE,$55                
                    .BYTE $01,$03,$03,$01,$FF,$FD,$FD,$FF,$55
                    .BYTE $03,$03,$FD,$FD,$55                
                    .BYTE $04,$04,$FC,$FC,$55                
                    .BYTE $03,$05,$05,$03,$FD,$FB,$FB,$FD,$55
                    .BYTE $00,$55                            
""".split('\n')[1:-1]
    ,"""
multicrossYPosArray .BYTE $FF,$01,$01,$FF,$55                
                    .BYTE $FE,$02,$02,$FE,$55                
                    .BYTE $FD,$FF,$01,$03,$03,$01,$FF,$FD,$55
                    .BYTE $FD,$03,$03,$FD,$55                
                    .BYTE $FC,$04,$04,$FC,$55                
                    .BYTE $FB,$FD,$03,$05,$05,$03,$FD,$FB,$55
                    .BYTE $00,$55                            
""".split('\n')[1:-1]
      ),
    ("""
pulsarXPosArray .BYTE $00,$01,$00,$FF,$55
                .BYTE $00,$02,$00,$FE,$55
                .BYTE $00,$03,$00,$FD,$55
                .BYTE $00,$04,$00,$FC,$55
                .BYTE $00,$05,$00,$FB,$55
                .BYTE $00,$06,$00,$FA,$55
                .BYTE $00,$55            
""".split('\n')[1:-1]
    ,"""
pulsarYPosArray .BYTE $FF,$00,$01,$00,$55
                .BYTE $FE,$00,$02,$00,$55
                .BYTE $FD,$00,$03,$00,$55
                .BYTE $FC,$00,$04,$00,$55
                .BYTE $FB,$00,$05,$00,$55
                .BYTE $FA,$00,$06,$00,$55
                .BYTE $00,$55            
""".split('\n')[1:-1]
      ),
    ("""
       .BYTE $00,$00,$00,$FF,$FE,$FD,$01,$02,$55 
       .BYTE $00,$03,$55                         
       .BYTE $00,$00,$00,$00,$00,$55             
       .BYTE $00,$FF,$FE,$FC,$FB,$FC,$01,$02,$55 
       .BYTE $00,$04,$05,$04,$FF,$01,$55         
       .BYTE $00,$FD,$FB,$03,$05,$02,$FE,$55     
       .BYTE $00,$55                             
""".split('\n')[1:-1]
    ,"""
        .BYTE $00,$FF,$FE,$01,$02,$03,$01,$02,$55
        .BYTE $00,$03,$55                        
        .BYTE $00,$01,$02,$03,$04,$55            
        .BYTE $00,$FE,$FE,$FF,$01,$03,$FE,$FE,$55
        .BYTE $00,$FF,$01,$03,$04,$04,$55        
        .BYTE $00,$FF,$00,$FF,$00,$04,$04,$55    
        .BYTE $00,$55                            
""".split('\n')[1:-1]
      ),
    ("""
; customPattern1XPosArray .BYTE $00,$00,$FF,$01,$55            
        .BYTE $00,$FE,$02,$55                
        .BYTE $00,$00,$FA,$06,$03,$FD,$55    
        .BYTE $00,$FD,$03,$FB,$05,$55        
        .BYTE $00,$00,$00,$55                
        .BYTE $00,$00,$FC,$04,$03,$FD,$55    
        .BYTE $00,$55                        
""".split('\n')[1:-1]
    ,"""
; customPattern1YPosArray  .BYTE $00,$FF,$01,$01,$55            
        .BYTE $00,$01,$01,$55                
        .BYTE $00,$FC,$FF,$FF,$05,$05,$55    
        .BYTE $00,$FD,$FD,$02,$02,$55        
        .BYTE $00,$05,$FD,$55                
        .BYTE $00,$FE,$02,$02,$02,$02,$55    
        .BYTE $00,$55                        
""".split('\n')[1:-1]
      ),
    ("""
; customPattern2XPosArray  .BYTE $00,$55        
        .BYTE $00,$FD,$03,$55
        .BYTE $00,$F9,$07,$55
        .BYTE $00,$FB,$05,$55
        .BYTE $00,$00,$55    
        .BYTE $00,$00,$55    
        .BYTE $00,$55        
        .BYTE $FE,$02,$55    
        .BYTE $00,$55        
        .BYTE $55            
""".split('\n')[1:-1]
    ,"""
; customPattern2YPosArray  .BYTE $00,$55        
        .BYTE $00,$00,$00,$55
        .BYTE $00,$00,$00,$55
        .BYTE $00,$FD,$FD,$55
        .BYTE $00,$FB,$55    
        .BYTE $00,$04,$55    
        .BYTE $00,$55        
        .BYTE $FC,$FC,$55    
        .BYTE $00,$55        
        .BYTE $55            
""".split('\n')[1:-1]
      ),
    ("""
; customPattern3XPosArray .BYTE $00,$01,$01,$02,$55    
        .BYTE $00,$00,$01,$02,$02,$55
        .BYTE $00,$00,$00,$02,$55    
        .BYTE $00,$FF,$FE,$55        
        .BYTE $00,$FE,$FE,$55        
        .BYTE $00,$FD,$FE,$55        
        .BYTE $00,$55                
""".split('\n')[1:-1]
    ,"""
; customPattern3YPosArray .BYTE $00,$FF,$00,$00,$55    
        .BYTE $00,$01,$01,$01,$02,$55
        .BYTE $00,$02,$03,$03,$55    
        .BYTE $00,$01,$00,$55        
        .BYTE $00,$FF,$FE,$55        
        .BYTE $00,$FF,$FF,$55        
        .BYTE $00,$55                
""".split('\n')[1:-1]
      ),
    ("""
; customPattern4XPosArray .BYTE $00,$00,$00,$ED,$14,$55
        .BYTE $00,$F2,$0F,$55        
        .BYTE $00,$00,$55            
        .BYTE $00,$00,$55            
        .BYTE $00,$00,$55            
        .BYTE $00,$00,$FF,$01,$55    
        .BYTE $00,$55                
        .BYTE $02,$55                
        .BYTE $00,$FC,$FD,$03,$04,$55
        .BYTE $00,$55                
""".split('\n')[1:-1]
    ,"""
; customPattern4YPosArray .BYTE $00,$0B,$F4,$00,$00,$55
        .BYTE $00,$00,$00,$55        
        .BYTE $00,$F9,$55            
        .BYTE $00,$FC,$55            
        .BYTE $00,$FE,$55            
        .BYTE $00,$FF,$00,$00,$55    
        .BYTE $00,$55                
        .BYTE $00,$55                
        .BYTE $00,$00,$00,$00,$00,$55
        .BYTE $00,$55                
""".split('\n')[1:-1]
      ),
    ("""
; customPattern5XPosArray .BYTE $00,$00,$01,$01,$55
       .BYTE $00,$FF,$FF,$FE,$55
       .BYTE $00,$FD,$FC,$FB,$55
       .BYTE $00,$FD,$FE,$FF,$55
       .BYTE $00,$00,$01,$02,$55
       .BYTE $00,$03,$04,$55    
       .BYTE $00,$55            
""".split('\n')[1:-1]
    ,"""
; customPattern5YPosArray .BYTE $00,$FF,$FE,$FD,$55
       .BYTE $00,$01,$02,$03,$55
       .BYTE $00,$04,$04,$03,$55
       .BYTE $00,$FC,$FC,$FC,$55
       .BYTE $00,$FC,$FC,$FC,$55
       .BYTE $00,$FC,$FC,$55    
       .BYTE $00,$55            
""".split('\n')[1:-1]
      ),
    ("""
; customPattern6XPosArray  .BYTE $00,$01,$02,$55         
        .BYTE $00,$F6,$F6,$55         
        .BYTE $00,$FB,$FA,$FB,$FC,$55 
        .BYTE $00,$FD,$FD,$FE,$FE,$55 
        .BYTE $00,$05,$07,$55         
        .BYTE $00,$F9,$F7,$FB,$55     
        .BYTE $00,$55                 
        .BYTE $00,$55                 
""".split('\n')[1:-1]
    ,"""
; customPattern6YPosArray .BYTE $00,$FF,$FE,$55         
        .BYTE $00,$FC,$FD,$55         
        .BYTE $00,$FA,$FB,$FC,$FB,$55 
        .BYTE $00,$05,$06,$06,$05,$55 
        .BYTE $00,$03,$02,$55         
        .BYTE $00,$01,$03,$03,$55     
        .BYTE $00,$55                 
        .BYTE $00,$55                 
""".split('\n')[1:-1]
      ),
]

# %%
import re
theader = """
\\begin{figure}[H]
  {
    \setlength{\\tabcolsep}{3.0pt}
    \setlength\cmidrulewidth{\heavyrulewidth} % Make cmidrule = 
    \\begin{adjustbox}{height=5cm,center}
      \\footnotesize
      \\begin{tabular}{ll}
"""

trow1 = """
        \makecell[l]{
"""
trow2 = """} & \makecell[l]{
"""

trow3 = """} \\\\
        \midrule
"""
tfooter = """
      \end{tabular}
    \end{adjustbox}
  }\caption{The purpose of each of the oscillator values.}
\end{figure}
"""

# %%
import os
patterns[0]
trimmedPattern = lambda p: [l[l.find(".BYTE"):].strip() for l in p]
pngs = [(0,1),(1,2),(3,3),(6,4),(10,5),(15,5),(20,5),(25,5),(30,5),
       (35,5),(40,5),(45,5),]
for i,(x_p,y_p) in enumerate(patterns):
    output_file = open(f"../src/patterns/tables/pattern{i}.tex",'w')
    x_array, y_array =  trimmedPattern(x_p), trimmedPattern(y_p)
    output_file.write(theader)
    for j,x in enumerate(x_array):
        output_file.write(trow1)
        output_file.write(f"\icode{{{x[:-4]}}}\\\\\n".replace("$","\$"))
        output_file.write(f"\icode{{{y_array[j][:-4]}}}\n".replace("$","\$"))
        output_file.write(trow2)
        for k in range(0,pngs[j][1]):
            fname = f"src/patterns/pixels/pixel_pattern{i}_{pngs[j][0]+k}.png"
            if not os.path.isfile("../"+fname):
                break
            pngrow = f"""\includegraphics[width=1.3cm]{{{fname}}}%\n"""
            output_file.write(pngrow)
        output_file.write(trow3)
    output_file.write(tfooter)
    output_file.close()
