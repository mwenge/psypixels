# %% [markdown]
# # Colorspace - Create Colourflow Chapter Diagrams

# %%
import gzip
log_file = "colorspace_colourflow_volumetric.txt.gz"
input_file = gzip.open(log_file,'rt')

flatten = lambda l: [e for sublist in l for e in sublist]

ram_history = []
lines = input_file.readlines()
for i in range(1, len(lines), 132):
    # Screen RAM (7000-8000)
    raw_ram = [l[6:126].split() for l in lines[i:i+104]]
    pixel_ram = [int(v,16) for l in raw_ram for v in l][:0x1000]
    # Display list (8000-9000)
    raw_ram = [l[6:126].split() for l in lines[i+103:i+127]]
    display_list = [int(v,16) for l in raw_ram for v in l]
    # Color Registers
    color_registers = [int(i,16) for i in lines[i+129].split()[1:10]]
    # Color and Ooze data
    ooze_registers = [int(i,16) for i in lines[i+130].split()[1:30]]
    ram_history += [(pixel_ram, color_registers, display_list, ooze_registers)]

# %%
patterns = []
pcol = []
#selected = [ram_history[x] for x in [188,236]]
for j, (scr, col_register, display_list, ooze) in enumerate(ram_history):
    col = col_register[:-1]
    if pcol and col != pcol:
        patterns += [pcol]
    pcol = col
patterns += [pcol]

len(patterns)
# Out:
# 251

# %%
page_template = """\\begin{minipage}[b]{0.15\linewidth}
\\begin{figure}[H]                                                          
  \centering                                                             
  \\begin{adjustbox}{width=1.5cm,center}                                   
  \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_%COLOR_INDEX%-45.png}%           
  \end{adjustbox}                                                        
\caption*{%COLOR_NAMES%}                                           
\end{figure}                                                               
\end{minipage}
\hspace{0.1cm}"""

# %%
import colorspace_colors as cc
import os

for i, pid_array in enumerate(sorted(patterns,key=lambda x: x[1])):
    for azim in [-45]:
        p1 = pid_array[1]
        if not os.path.isfile(f'colorspace_colourflow/colourflow_{p1}-45.png'):
            continue
        color_names = [cc.color_value_to_name[c].replace('_','\_') for c in pid_array]
        color_names_str = (','.join(color_names[:4]) 
                       + '\\\\\\hspace{\\textwidth}'
                       + ','.join(color_names[4:]))
        pt = page_template
        pt = pt.replace("%COLOR_INDEX%",str(p1))
        pt = pt.replace("%COLOR_NAMES%",color_names[1])
        print(pt)
# Out:
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_0-45.png}%
#   \end{adjustbox}
# \caption*{BLACK0}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_1-45.png}%
#   \end{adjustbox}
# \caption*{BLACK1}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_2-45.png}%
#   \end{adjustbox}
# \caption*{BLACK2}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_3-45.png}%
#   \end{adjustbox}
# \caption*{BLACK3}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_4-45.png}%
#   \end{adjustbox}
# \caption*{BLACK4}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_5-45.png}%
#   \end{adjustbox}
# \caption*{BLACK5}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_6-45.png}%
#   \end{adjustbox}
# \caption*{BLACK6}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_7-45.png}%
#   \end{adjustbox}
# \caption*{BLACK7}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_8-45.png}%
#   \end{adjustbox}
# \caption*{BLACK8}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_9-45.png}%
#   \end{adjustbox}
# \caption*{BLACK9}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_10-45.png}%
#   \end{adjustbox}
# \caption*{BLACK10}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_11-45.png}%
#   \end{adjustbox}
# \caption*{BLACK11}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_12-45.png}%
#   \end{adjustbox}
# \caption*{BLACK12}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_13-45.png}%
#   \end{adjustbox}
# \caption*{BLACK13}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_14-45.png}%
#   \end{adjustbox}
# \caption*{BLACK14}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_15-45.png}%
#   \end{adjustbox}
# \caption*{BLACK15}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_16-45.png}%
#   \end{adjustbox}
# \caption*{RUST0}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_17-45.png}%
#   \end{adjustbox}
# \caption*{RUST1}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_18-45.png}%
#   \end{adjustbox}
# \caption*{RUST2}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_19-45.png}%
#   \end{adjustbox}
# \caption*{RUST3}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_20-45.png}%
#   \end{adjustbox}
# \caption*{RUST4}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_21-45.png}%
#   \end{adjustbox}
# \caption*{RUST5}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_22-45.png}%
#   \end{adjustbox}
# \caption*{RUST6}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_23-45.png}%
#   \end{adjustbox}
# \caption*{RUST7}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_24-45.png}%
#   \end{adjustbox}
# \caption*{RUST8}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_25-45.png}%
#   \end{adjustbox}
# \caption*{RUST9}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_26-45.png}%
#   \end{adjustbox}
# \caption*{RUST10}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_27-45.png}%
#   \end{adjustbox}
# \caption*{RUST11}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_28-45.png}%
#   \end{adjustbox}
# \caption*{RUST12}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_29-45.png}%
#   \end{adjustbox}
# \caption*{RUST13}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_30-45.png}%
#   \end{adjustbox}
# \caption*{RUST14}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_31-45.png}%
#   \end{adjustbox}
# \caption*{RUST15}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_32-45.png}%
#   \end{adjustbox}
# \caption*{RED\_ORANGE0}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_33-45.png}%
#   \end{adjustbox}
# \caption*{RED\_ORANGE1}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_34-45.png}%
#   \end{adjustbox}
# \caption*{RED\_ORANGE2}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_35-45.png}%
#   \end{adjustbox}
# \caption*{RED\_ORANGE3}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_36-45.png}%
#   \end{adjustbox}
# \caption*{RED\_ORANGE4}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_37-45.png}%
#   \end{adjustbox}
# \caption*{RED\_ORANGE5}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_38-45.png}%
#   \end{adjustbox}
# \caption*{RED\_ORANGE6}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_39-45.png}%
#   \end{adjustbox}
# \caption*{RED\_ORANGE7}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_40-45.png}%
#   \end{adjustbox}
# \caption*{RED\_ORANGE8}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_41-45.png}%
#   \end{adjustbox}
# \caption*{RED\_ORANGE9}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_42-45.png}%
#   \end{adjustbox}
# \caption*{RED\_ORANGE10}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_43-45.png}%
#   \end{adjustbox}
# \caption*{RED\_ORANGE11}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_44-45.png}%
#   \end{adjustbox}
# \caption*{RED\_ORANGE12}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_49-45.png}%
#   \end{adjustbox}
# \caption*{DARK\_ORANGE1}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_50-45.png}%
#   \end{adjustbox}
# \caption*{DARK\_ORANGE2}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_51-45.png}%
#   \end{adjustbox}
# \caption*{DARK\_ORANGE3}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_52-45.png}%
#   \end{adjustbox}
# \caption*{DARK\_ORANGE4}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_53-45.png}%
#   \end{adjustbox}
# \caption*{DARK\_ORANGE5}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_54-45.png}%
#   \end{adjustbox}
# \caption*{DARK\_ORANGE6}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_55-45.png}%
#   \end{adjustbox}
# \caption*{DARK\_ORANGE7}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_56-45.png}%
#   \end{adjustbox}
# \caption*{DARK\_ORANGE8}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_57-45.png}%
#   \end{adjustbox}
# \caption*{DARK\_ORANGE9}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_58-45.png}%
#   \end{adjustbox}
# \caption*{DARK\_ORANGE10}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_59-45.png}%
#   \end{adjustbox}
# \caption*{DARK\_ORANGE11}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_60-45.png}%
#   \end{adjustbox}
# \caption*{DARK\_ORANGE12}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_61-45.png}%
#   \end{adjustbox}
# \caption*{DARK\_ORANGE13}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_62-45.png}%
#   \end{adjustbox}
# \caption*{DARK\_ORANGE14}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_63-45.png}%
#   \end{adjustbox}
# \caption*{DARK\_ORANGE15}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_64-45.png}%
#   \end{adjustbox}
# \caption*{RED0}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_65-45.png}%
#   \end{adjustbox}
# \caption*{RED1}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_66-45.png}%
#   \end{adjustbox}
# \caption*{RED2}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_67-45.png}%
#   \end{adjustbox}
# \caption*{RED3}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_68-45.png}%
#   \end{adjustbox}
# \caption*{RED4}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_69-45.png}%
#   \end{adjustbox}
# \caption*{RED5}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_70-45.png}%
#   \end{adjustbox}
# \caption*{RED6}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_71-45.png}%
#   \end{adjustbox}
# \caption*{RED7}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_72-45.png}%
#   \end{adjustbox}
# \caption*{RED8}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_73-45.png}%
#   \end{adjustbox}
# \caption*{RED9}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_74-45.png}%
#   \end{adjustbox}
# \caption*{RED10}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_75-45.png}%
#   \end{adjustbox}
# \caption*{RED11}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_76-45.png}%
#   \end{adjustbox}
# \caption*{RED12}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_77-45.png}%
#   \end{adjustbox}
# \caption*{RED13}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_78-45.png}%
#   \end{adjustbox}
# \caption*{RED14}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_79-45.png}%
#   \end{adjustbox}
# \caption*{RED15}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_80-45.png}%
#   \end{adjustbox}
# \caption*{DARK\_LAVENDER0}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_81-45.png}%
#   \end{adjustbox}
# \caption*{DARK\_LAVENDER1}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_82-45.png}%
#   \end{adjustbox}
# \caption*{DARK\_LAVENDER2}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_83-45.png}%
#   \end{adjustbox}
# \caption*{DARK\_LAVENDER3}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
# ...
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_229-45.png}%
#   \end{adjustbox}
# \caption*{ORANGE\_GREEN5}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_230-45.png}%
#   \end{adjustbox}
# \caption*{ORANGE\_GREEN6}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_231-45.png}%
#   \end{adjustbox}
# \caption*{ORANGE\_GREEN7}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_232-45.png}%
#   \end{adjustbox}
# \caption*{ORANGE\_GREEN8}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_233-45.png}%
#   \end{adjustbox}
# \caption*{ORANGE\_GREEN9}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_234-45.png}%
#   \end{adjustbox}
# \caption*{ORANGE\_GREEN10}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_235-45.png}%
#   \end{adjustbox}
# \caption*{ORANGE\_GREEN11}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_236-45.png}%
#   \end{adjustbox}
# \caption*{ORANGE\_GREEN12}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_237-45.png}%
#   \end{adjustbox}
# \caption*{ORANGE\_GREEN13}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_238-45.png}%
#   \end{adjustbox}
# \caption*{ORANGE\_GREEN14}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_239-45.png}%
#   \end{adjustbox}
# \caption*{ORANGE\_GREEN15}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_240-45.png}%
#   \end{adjustbox}
# \caption*{ORANGE0}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_241-45.png}%
#   \end{adjustbox}
# \caption*{ORANGE1}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_242-45.png}%
#   \end{adjustbox}
# \caption*{ORANGE2}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_243-45.png}%
#   \end{adjustbox}
# \caption*{ORANGE3}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_244-45.png}%
#   \end{adjustbox}
# \caption*{ORANGE4}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_245-45.png}%
#   \end{adjustbox}
# \caption*{ORANGE5}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_246-45.png}%
#   \end{adjustbox}
# \caption*{ORANGE6}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_247-45.png}%
#   \end{adjustbox}
# \caption*{ORANGE7}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_248-45.png}%
#   \end{adjustbox}
# \caption*{ORANGE8}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_249-45.png}%
#   \end{adjustbox}
# \caption*{ORANGE9}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_250-45.png}%
#   \end{adjustbox}
# \caption*{ORANGE10}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_251-45.png}%
#   \end{adjustbox}
# \caption*{ORANGE11}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_252-45.png}%
#   \end{adjustbox}
# \caption*{ORANGE12}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_253-45.png}%
#   \end{adjustbox}
# \caption*{ORANGE13}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_254-45.png}%
#   \end{adjustbox}
# \caption*{ORANGE14}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
# \begin{minipage}[b]{0.15\linewidth}
# \begin{figure}[H]
#   \centering
#   \begin{adjustbox}{width=1.5cm,center}
#   \includegraphics[width=1.5cm]{src/colorspace_colourflow/colourflow_255-45.png}%
#   \end{adjustbox}
# \caption*{ORANGE15}
# \end{figure}
# \end{minipage}
# \hspace{0.1cm}
