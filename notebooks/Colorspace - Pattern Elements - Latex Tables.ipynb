# %% [markdown]
# # Generate Latex Tables of Pattern Progressions

# %%
patterns = [
    ("""
theTwistXPosArray
        .BYTE $00,$55
        .BYTE $01,$02,$55
        .BYTE $01,$02,$03,$55
        .BYTE $01,$02,$03,$04,$55
        .BYTE $00,$00,$00,$55
        .BYTE $FF,$FE,$55
        .BYTE $55
""".split('\n')[1:-1]
    ,"""
theTwistYPosArray
        .BYTE $FF,$55
        .BYTE $FF,$FE,$55
        .BYTE $00,$00,$00,$55
        .BYTE $01,$02,$03,$04,$55
        .BYTE $01,$02,$03,$55
        .BYTE $01,$02,$55
        .BYTE $55
""".split('\n')[1:-1]
      ),
    ("""
smoothCrossflowXPosArray
        .BYTE $FF,$01,$55
        .BYTE $FE,$02,$55
        .BYTE $FD,$03,$55
        .BYTE $FC,$04,$55
        .BYTE $FB,$05,$55
        .BYTE $FA,$06,$55
        .BYTE $55
""".split('\n')[1:-1]
    ,"""
smoothCrossflowYPosArray
        .BYTE $02,$FE,$55
        .BYTE $FF,$01,$55
        .BYTE $04,$FC,$55
        .BYTE $FE,$02,$55
        .BYTE $06,$FA,$55
        .BYTE $FD,$03,$55
        .BYTE $55
""".split('\n')[1:-1]
      ),
    ("""
denturesXPosArray
        .BYTE $01,$55
        .BYTE $02,$55
        .BYTE $03,$55
        .BYTE $04,$55
        .BYTE $05,$55
        .BYTE $06,$55
        .BYTE $55
""".split('\n')[1:-1]
    ,"""
denturesYPosArray
        .BYTE $FE,$55
        .BYTE $02,$55
        .BYTE $FD,$55
        .BYTE $03,$55
        .BYTE $FC,$55
        .BYTE $04,$55
        .BYTE $55
""".split('\n')[1:-1]
      ),
    ("""
deltoidsXPosArray
        .BYTE $FF,$00,$01,$55
        .BYTE $55
        .BYTE $FE,$FF,$00,$01,$02,$55
        .BYTE $FD,$00,$03,$55
        .BYTE $FC,$00,$04,$55
        .BYTE $FA,$00,$06,$55
        .BYTE $55
""".split('\n')[1:-1]
    ,"""
deltoidsYPosArray
        .BYTE $00,$FF,$00,$55
        .BYTE $55
        .BYTE $00,$FF,$FE,$FF,$00,$55
        .BYTE $01,$FD,$01,$55
        .BYTE $02,$FC,$02,$55
        .BYTE $04,$FA,$04,$55
        .BYTE $55
""".split('\n')[1:-1]
      ),
    ("""
pulsarCrossXPosArray
        .BYTE $00,$01,$00,$FF,$55
        .BYTE $00,$02,$00,$FE,$55
        .BYTE $00,$03,$00,$FD,$55
        .BYTE $00,$04,$00,$FC,$55
        .BYTE $00,$05,$00,$FB,$55
        .BYTE $00,$06,$00,$FA,$55
        .BYTE $55
""".split('\n')[1:-1]
    ,"""
pulsarCrossYPosArray
        .BYTE $FF,$00,$01,$00,$55
        .BYTE $FE,$00,$02,$00,$55
        .BYTE $FD,$00,$03,$00,$55
        .BYTE $FC,$00,$04,$00,$55
        .BYTE $FB,$00,$05,$00,$55
        .BYTE $FA,$00,$06,$00,$55
        .BYTE $55
""".split('\n')[1:-1]
      ),
    ("""
slothMultiCrossXPosArray
        .BYTE $FF,$01,$01,$FF,$55
        .BYTE $FE,$02,$02,$FE,$55
        .BYTE $FD,$FF,$01,$03,$03,$01,$FF,$FD,$55
        .BYTE $FD,$03,$03,$FD,$55
        .BYTE $FC,$04,$04,$FC,$55
        .BYTE $FB,$FD,$03,$05,$05,$03,$FD,$FB,$55
        .BYTE $55
""".split('\n')[1:-1]
    ,"""
slothMultiCrossYPosArray
        .BYTE $FF,$FF,$01,$01,$55
        .BYTE $FE,$FE,$02,$02,$55
        .BYTE $FF,$FD,$FD,$FF,$01,$03,$03,$01,$55
        .BYTE $FD,$FD,$03,$03,$55
        .BYTE $FC,$FC,$04,$04,$55
        .BYTE $FD,$FB,$FB,$FD,$03,$05,$05,$03,$55
        .BYTE $55
""".split('\n')[1:-1]
      ),
    ("""
crossAndABitXPosArray
        .BYTE $FF,$01,$55
        .BYTE $FD,$03,$55
        .BYTE $FE,$02,$55
        .BYTE $FB,$05,$55
        .BYTE $08,$08,$55
        .BYTE $08,$08,$55
        .BYTE $55
""".split('\n')[1:-1]
    ,"""
crossAndABitYPosArray
        .BYTE $FF,$01,$55
        .BYTE $FD,$03,$55
        .BYTE $01,$FF,$55
        .BYTE $02,$FE,$55
        .BYTE $0B,$0F,$55
        .BYTE $0C,$0E,$55
        .BYTE $55
""".split('\n')[1:-1]
      ),
    ("""
star2XPosArray
        .BYTE $FF,$55
        .BYTE $01,$55
        .BYTE $FE,$55
        .BYTE $02,$55
        .BYTE $01,$55
        .BYTE $FF,$55
        .BYTE $55
""".split('\n')[1:-1]
    ,"""
star2YPosArray
        .BYTE $FD,$55
        .BYTE $FE,$55
        .BYTE $FF,$55
        .BYTE $00,$55
        .BYTE $02,$55
        .BYTE $02,$55
        .BYTE $55
""".split('\n')[1:-1]
      ),
    ("""
userLightform0XPosArray
        .BYTE $00,$00,$00,$00,$00,$00,$00,$55
        .BYTE $04,$04,$04,$04,$04,$FC,$FC,$FC,$FC,$FC,$55
        .BYTE $FC,$FC,$FB,$FB,$FA,$F9,$F8,$F6,$04,$04,$05,$05,$06,$07,$08,$0A,$55
        .BYTE $00,$00,$00,$55
        .BYTE $00,$55
        .BYTE $F7,$09,$55
        .BYTE $55
""".split('\n')[1:-1]
    ,"""
userLightform0YPosArray
        .BYTE $01,$03,$02,$05,$07,$09,$0B,$55
        .BYTE $00,$01,$02,$03,$04,$00,$01,$02,$03,$04,$55
        .BYTE $05,$06,$07,$08,$09,$0A,$0B,$0B,$05,$06,$07,$08,$09,$0A,$0B,$0B,$55
        .BYTE $0A,$08,$06,$55
        .BYTE $04,$55
        .BYTE $0B,$0B,$55,
        .BYTE $55
""".split('\n')[1:-1]
      ),
    ("""
userLightform1XPosArray
        .BYTE $02,$04,$07,$55
        .BYTE $0A,$0C,$55
        .BYTE $0F,$12,$15,$55
        .BYTE $19,$1C,$20,$55
        .BYTE $EC,$EC,$55
        .BYTE $E9,$EF,$55
        .BYTE $55
""".split('\n')[1:-1]
    ,"""
userLightform1YPosArray
        .BYTE $FE,$FD,$FC,$FC,$FB,$FB,$FB,$FA,$FA,$FA,$55
        .BYTE $F9,$F9,$F9,$55
        .BYTE $0D,$0F,$55
        .BYTE $0E,$0E,$55
        .BYTE $55
        .BYTE $55
        .BYTE $55
""".split('\n')[1:-1]
      ),
    ("""
userLightform2XPosArray
        .BYTE $FF,$FE,$FD,$55
        .BYTE $01,$02,$02,$02,$02,$02,$55
        .BYTE $02,$02,$02,$02,$01,$55
        .BYTE $00,$FF,$FE,$FD,$FB,$FC,$55
        .BYTE $FA,$F9,$55
        .BYTE $F8,$55
        .BYTE $55
""".split('\n')[1:-1]
    ,"""
userLightform2YPosArray
        .BYTE $01,$02,$03,$55
        .BYTE $FF,$FF,$00,$01,$02,$03,$55
        .BYTE $04,$05,$06,$07,$08,$55
        .BYTE $09,$09,$0A,$0A,$0A,$0A,$55
        .BYTE $09,$09,$55
        .BYTE $08,$55
        .BYTE $55
""".split('\n')[1:-1]
      ),
    ("""
userLightform3XPosArray
        .BYTE $FD,$03,$55
        .BYTE $FA,$06,$55
        .BYTE $F8,$07,$55
        .BYTE $F4,$0C,$55
        .BYTE $F3,$F1,$0D,$0F,$55
        .BYTE $00,$00,$00,$55
        .BYTE $55
""".split('\n')[1:-1]
    ,"""
userLightform3YPosArray
        .BYTE $FF,$FF,$55
        .BYTE $01,$01,$55
        .BYTE $FC,$FC,$55
        .BYTE $02,$02,$55
        .BYTE $04,$04,$04,$04,$55
        .BYTE $FB,$0A,$11,$55
        .BYTE $55
""".split('\n')[1:-1]
      ),
    ("""
userLightform4XPosArray
        .BYTE $FF,$00,$01,$55
        .BYTE $FF,$00,$01,$55
        .BYTE $04,$04,$04,$55
        .BYTE $FC,$FC,$FC,$55
        .BYTE $00,$00,$55
        .BYTE $F8,$08,$55
        .BYTE $55
""".split('\n')[1:-1]
    ,"""
userLightform4YPosArray
        .BYTE $FD,$FD,$FD,$55
        .BYTE $03,$03,$03,$55
        .BYTE $FF,$00,$01,$55
        .BYTE $FF,$00,$01,$55
        .BYTE $FA,$06,$55
        .BYTE $00,$00,$55
        .BYTE $55
""".split('\n')[1:-1]
      ),
    ("""
userLightform5XPosArray
        .BYTE $FE,$FF,$00,$01,$02,$FD,$FC,$55
        .BYTE $03,$04,$05,$06,$FC,$FC,$FD,$FF,$FE,$55
        .BYTE $07,$08,$09,$04,$03,$55
        .BYTE $00,$01,$02,$FB,$FC,$FD,$FE,$FF,$00,$01,$02,$03,$55
        .BYTE $04,$05,$06,$07,$08,$09,$55
        .BYTE $00,$55
        .BYTE $55
""".split('\n')[1:-1]
    ,"""
userLightform5YPosArray
        .BYTE $FD,$FD,$FD,$FD,$FD,$FE,$FF,$55
        .BYTE $FE,$FE,$FF,$FF,$00,$01,$02,$02,$02,$55
        .BYTE $FF,$FF,$FE,$00,$01,$55
        .BYTE $02,$02,$02,$FA,$F9,$F8,$F8,$F8,$F8,$F8,$F9,$F9,$55
        .BYTE $FA,$FA,$FA,$FA,$FA,$F9,$55
        .BYTE $00,$55
        .BYTE $55
""".split('\n')[1:-1]
      ),
    ("""
userLightform6XPosArray
        .BYTE $FF,$FE,$01,$02,$01,$00,$FF,$FE,$FF,$00,$01,$02,$55
        .BYTE $05,$05,$05,$05,$06,$07,$08,$09,$09,$09,$09,$06,$07,$08,$55
        .BYTE $0C,$0C,$0C,$0C,$0C,$0D,$0E,$0F,$0D,$0E,$55
        .BYTE $55
        .BYTE $55
        .BYTE $FD,$FE,$FF,$00,$FF,$FE,$FD,$FC,$FD,$FE,$FF,$00,$01,$55
        .BYTE $55
""".split('\n')[1:-1]
    ,"""
userLightform6YPosArray
        .BYTE $00,$00,$00,$00,$01,$02,$03,$04,$04,$04,$04,$04,$55
        .BYTE $04,$03,$02,$01,$00,$00,$00,$01,$02,$03,$04,$02,$02,$02,$55
        .BYTE $04,$03,$02,$00,$01,$00,$00,$01,$02,$02,$55
        .BYTE $55
        .BYTE $55
        .BYTE $01,$01,$01,$01,$02,$03,$04,$05,$05,$05,$05,$05,$05,$55
        .BYTE $55
""".split('\n')[1:-1]
      ),
    ("""
userLightform7XPosArray
        .BYTE $00,$00,$00,$FE,$55
        .BYTE $00,$02,$05,$07,$0A,$03,$05,$08,$0A,$55
        .BYTE $0C,$0E,$00,$02,$05,$07,$0A,$55
        .BYTE $00,$00,$00,$FD,$55
        .BYTE $0A,$0A,$0A,$08,$55
        .BYTE $00,$55
        .BYTE $55
""".split('\n')[1:-1]
    ,"""
userLightform7YPosArray
        .BYTE $FE,$FC,$FA,$FC,$55
        .BYTE $02,$02,$02,$02,$02,$00,$00,$00,$00,$55
        .BYTE $FF,$00,$04,$04,$04,$04,$04,$55
        .BYTE $06,$08,$0A,$0A,$55
        .BYTE $06,$08,$0A,$0A,$55
        .BYTE $FC,$55
        .BYTE $55
""".split('\n')[1:-1]
      ),
    ("""
userLightform8XPosArray
        .BYTE $FE,$FC,$FA,$55
        .BYTE $0D,$0F,$11,$55
        .BYTE $06,$05,$07,$06,$55
        .BYTE $DF,$E1,$55
        .BYTE $E5,$E5,$E5,$55
        .BYTE $1A,$1C,$1C,$1A,$55
        .BYTE $55
""".split('\n')[1:-1]
    ,"""
userLightform8YPosArray
        .BYTE $02,$04,$06,$55
        .BYTE $06,$06,$06,$55
        .BYTE $0D,$0E,$0E,$0F,$55
        .BYTE $0E,$0E,$55
        .BYTE $FA,$FC,$FE,$55
        .BYTE $F7,$FA,$F7,$FA,$55
        .BYTE $55
""".split('\n')[1:-1]
      ),
    ("""
userLightform9XPosArray
        .BYTE $FF,$01,$55
        .BYTE $FD,$03,$55
        .BYTE $FB,$05,$55
        .BYTE $F8,$08,$55
        .BYTE $F5,$0B,$55
        .BYTE $00,$00,$00,$55
        .BYTE $55
""".split('\n')[1:-1]
    ,"""
userLightform9YPosArray
        .BYTE $02,$02,$55
        .BYTE $04,$04,$55
        .BYTE $06,$06,$55
        .BYTE $08,$08,$55
        .BYTE $0A,$0A,$55
        .BYTE $04,$07,$0B,$55
        .BYTE $55
""".split('\n')[1:-1]
      ),
    ("""
userLightform10XPosArray
        .BYTE $EA,$E7,$E4,$55
        .BYTE $E7,$EA,$ED,$55
        .BYTE $E5,$E8,$EB,$55
        .BYTE $E2,$DE,$55
        .BYTE $F3,$F7,$55
        .BYTE $00,$55
        .BYTE $55
""".split('\n')[1:-1]
    ,"""
userLightform10YPosArray
        .BYTE $00,$00,$00,$55
        .BYTE $02,$02,$02,$55
        .BYTE $04,$04,$04,$55
        .BYTE $02,$02,$55
        .BYTE $02,$02,$55
        .BYTE $04,$55
        .BYTE $55
""".split('\n')[1:-1]
      ),
    ("""
userLightform11XPosArray
        .BYTE $01,$55
        .BYTE $00,$02,$04,$55
        .BYTE $00,$03,$06,$55
        .BYTE $00,$04,$09,$55
        .BYTE $00,$05,$0D,$55
        .BYTE $00,$06,$13,$55
        .BYTE $55
""".split('\n')[1:-1]
    ,"""
userLightform11YPosArray
        .BYTE $00,$55
        .BYTE $01,$01,$01,$55
        .BYTE $02,$02,$02,$55
        .BYTE $03,$03,$03,$55
        .BYTE $04,$04,$04,$55
        .BYTE $05,$05,$05,$55
        .BYTE $55
""".split('\n')[1:-1]
      ),
    ("""
userLightform12XPosArray
        .BYTE $01,$02,$55
        .BYTE $01,$00,$FF,$55
        .BYTE $00,$FF,$FE,$55
        .BYTE $FF,$FE,$FD,$55
        .BYTE $FE,$FD,$FC,$55
        .BYTE $FD,$FC,$FB,$55
        .BYTE $55
""".split('\n')[1:-1]
    ,"""
userLightform12YPosArray
        .BYTE $FF,$FE,$55
        .BYTE $00,$01,$02,$55
        .BYTE $02,$03,$04,$55
        .BYTE $04,$05,$06,$55
        .BYTE $06,$07,$08,$55
        .BYTE $08,$09,$0A,$55
        .BYTE $55
""".split('\n')[1:-1]
      ),
    ("""
userLightform13XPosArray
        .BYTE $00,$FF,$01,$FE,$02,$55
        .BYTE $FD,$03,$FC,$04,$FB,$05,$55
        .BYTE $FA,$06,$F9,$07,$F8,$08,$55
        .BYTE $F9,$FA,$FB,$FC,$FD,$07,$06,$05,$55
        .BYTE $04,$03,$02,$01,$55
        .BYTE $00,$FF,$FE,$55
        .BYTE $55
""".split('\n')[1:-1]
    ,"""
userLightform13YPosArray
        .BYTE $FB,$FC,$FC,$FD,$FD,$55
        .BYTE $FE,$FE,$FF,$FF,$00,$00,$55
        .BYTE $01,$01,$02,$02,$03,$03,$55
        .BYTE $03,$03,$03,$03,$03,$03,$03,$03,$55
        .BYTE $03,$03,$03,$03,$55
        .BYTE $03,$03,$03,$55
        .BYTE $55
""".split('\n')[1:-1]
      ),
    ("""
userLightform14XPosArray
        .BYTE $FC,$FC,$FC,$FD,$FE,$FF,$00,$01,$02,$FC,$FD,$FE,$FF,$00,$01,$03,$03,$02,$04,$05,$06,$06,$06,$06,$05,$04,$01,$55
        .BYTE $01,$01,$01,$01,$01,$01,$01,$55
        .BYTE $55
        .BYTE $FF,$FE,$02,$03,$04,$55
        .BYTE $55
""".split('\n')[1:-1]
    ,"""
userLightform14YPosArray
        .BYTE $00,$01,$02,$03,$04,$05,$05,$05,$05,$FF,$FE,$FD,$FC,$FC,$FC,$FC,$05,$FC,$FD,$FE,$FF,$00,$01,$02,$03,$04,$FD,$FE,$FE,$FF,$00,$01,$02,$03,$04,$55
        .BYTE $55
        .BYTE $01,$02,$00,$01,$02,$55
        .BYTE $55
        .BYTE $55
""".split('\n')[1:-1]
      ),
    ("""
userLightform15XPosArray
        .BYTE $F5,$F8,$FA,$55
        .BYTE $FA,$FD,$00,$55
        .BYTE $F5,$F8,$FA,$55
        .BYTE $FF,$02,$04,$55
        .BYTE $08,$08,$08,$55
        .BYTE $10,$12,$14,$55
        .BYTE $55
""".split('\n')[1:-1]
    ,"""
userLightform15YPosArray
        .BYTE $00,$00,$00,$55
        .BYTE $02,$02,$02,$55
        .BYTE $03,$03,$03,$55
        .BYTE $04,$04,$04,$55
        .BYTE $FF,$02,$04,$55
        .BYTE $0B,$09,$07,$55
        .BYTE $55
""".split('\n')[1:-1]
      ),
]

# %%
import re
theader = """
\\begin{figure}[H]
  {
    \setlength{\\tabcolsep}{3.0pt}
    \setlength\cmidrulewidth{\heavyrulewidth} % Make cmidrule = 
    \\begin{adjustbox}{height=5cm,center}
      \\footnotesize
      \\begin{tabular}{ll}
"""

trow1 = """
        \makecell[l]{
"""
trow2 = """} & \makecell[l]{
"""

trow3 = """} \\\\
        \midrule
"""
tfooter = """
      \end{tabular}
    \end{adjustbox}
  }\caption{The purpose of each of the oscillator values.}
\end{figure}
"""

# %%
pattern_names = [
    "The Twist",
    "Smooth Crossflow",
    "Dentures",
    "Deltoids",
    "Pulsar Cross",
    "Sloth Multi-Cross",
    "Cross and A Bit",
    "Star Two",
    "User Lightform 0",
    "User Lightform 1",
    "User Lightform 2",
    "User Lightform 3",
    "User Lightform 4",
    "User Lightform 5",
    "User Lightform 6",
    "User Lightform 7",
    "User Lightform 8",
    "User Lightform 9",
    "User Lightform 10",
    "User Lightform 11",
    "User Lightform 12",
    "User Lightform 13",
    "User Lightform 14",
    "User Lightform 15",
]

# %%
import os
patterns[0]
trimmedPattern = lambda p: [l[l.find(".BYTE"):].strip() for l in p[1:]]
pngs = [(0,1),(1,2),(3,3),(6,4),(10,5),(15,5),(20,5),(25,5),(30,5),
       (35,5),(40,5),(45,5),]
for i,(x_p,y_p) in enumerate(patterns):
    output_file = open(f"../src/colorspace_patterns/tables/pattern{i}.tex",'w')
    x_array, y_array =  trimmedPattern(x_p), trimmedPattern(y_p)
    output_file.write(theader)
    print(i, len(x_array), len(y_array))
    for j,x in enumerate(x_array):
        output_file.write(trow1)
        output_file.write(f"\icode{{{x[:-4]}}}\\\\\n".replace("$","\$"))
        output_file.write(f"\icode{{{y_array[j][:-4]}}}\n".replace("$","\$"))
        output_file.write(trow2)
        for k in range(0,pngs[j][1]):
            fname = f"src/colorspace_patterns/pixels/pixel_pattern{i}_{pngs[j][0]+k}.png"
            if not os.path.isfile("../"+fname):
                break
            pngrow = f"""\includegraphics[width=1.3cm]{{{fname}}}%\n"""
            output_file.write(pngrow)
        output_file.write(trow3)
    tfooter = f"""
          \end{{tabular}}
        \end{{adjustbox}}
      }}\caption{{Pattern Progression for '{pattern_names[i]}'}}
    \end{{figure}}
    """
    output_file.write(tfooter)
    output_file.close()
# Out:
# 0 7 7
# 1 7 7
# 2 7 7
# 3 7 7
# 4 7 7
# 5 7 7
# 6 7 7
# 7 7 7
# 8 7 7
# 9 7 7
# 10 7 7
# 11 7 7
# 12 7 7
# 13 7 7
# 14 7 7
# 15 7 7
# 16 7 7
# 17 7 7
# 18 7 7
# 19 7 7
# 20 7 7
# 21 7 7
# 22 5 5
# 23 7 7
