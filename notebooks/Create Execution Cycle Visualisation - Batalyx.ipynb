# %%
def show_im(img):  # for showing data as image
    list_image = [item for sublist in img for item in sublist]
    new_image = Image.new("RGBA", (len(img[0]), len(img)))
    new_image.putdata(list_image)
    return new_image

def drawCycleDiagram(pixels, width, height):
    Ro = 1000.0
    Ri = 380.0
    # img = [[1 for x in range(int(width))] for y in range(int(height))]
    cir = [[0 for x in range(int(Ro * 2))] for y in range(int(Ro * 2))]

    for i in range(int(Ro)):
        # outer_radius = Ro*m.cos(m.asin(i/Ro))
        outer_radius = m.sqrt(Ro*Ro - i*i)
        for j in range(-int(outer_radius),int(outer_radius)):
            if i < Ri:
                # inner_radius = Ri*m.cos(m.asin(i/Ri))
                inner_radius = m.sqrt(Ri*Ri - i*i)
            else:
                inner_radius = -1
            if j < -inner_radius or j > inner_radius:
                # this is the destination
                # solid:
                # cir[int(Ro-i)][int(Ro+j)] = (255,255,255)
                # cir[int(Ro+i)][int(Ro+j)] = (255,255,255)
                # textured:

                x = Ro+j
                y = Ro-i
                # calculate source
                angle = m.atan2(y-Ro,x-Ro)/2
                distance = m.sqrt((y-Ro)*(y-Ro) + (x-Ro)*(x-Ro))
                distance = m.floor((distance-Ri+1)*(height-1)/(Ro-Ri))
                cir[int(y)][int(x)] = pixels[int(width*angle/m.pi) % width, height-distance-1]
                y = Ro+i
                # calculate source
                angle = m.atan2(y-Ro,x-Ro)/2
                distance = m.sqrt((y-Ro)*(y-Ro) + (x-Ro)*(x-Ro))
                distance = m.floor((distance-Ri+1)*(height-1)/(Ro-Ri))
                cir[int(y)][int(x)] = pixels[int(width*angle/m.pi) % width, height-distance-1]

    return cir

# %%
syms = {
    "082a": "PsychedeliaLoop-Enter",
    "0830": "PsychedeliaLoop-Exit",
    "0dbf": "MaybeUpdateFromBuffersAndPaint-Enter",
    "0e04": "MaybeUpdateFromBuffersAndPaint-Exit",
    "0b7a": "PaintStructureAtCurrentPosition-Enter",
    "0b96": "PaintStructureAtCurrentPosition-Exit",
    "0bc9": "PaintStructureAtCurrentPosition-Exit",
    "0aef": "PaintPixelForCurrentSymmetry-Enter",
    "0af6": "PaintPixelForCurrentSymmetry-Exit",
    "0b21": "PaintPixelForCurrentSymmetry-Exit",
    "0b55": "PaintPixelForCurrentSymmetry-Exit",
    "0b62": "PaintPixelForCurrentSymmetry-Exit",
    "0aac": "PaintPixel-Enter",
    "0ad3": "PaintPixel-Exit",
    "0ad9": "PaintPixel-Exit",
}
import os
log_file = "PsyIIExecutionTrace.txt"
traces = '\n'.join(["tr exec "+k for k in syms])
open('executiontrace.txt','w').write(f"""log on
logname "{log_file}"
{traces}
""")
# Out:
# 236

# %%
os.chdir('../../psyII')
! git checkout execution_cycle
! make psyII.prg
os.chdir('../psypixels/notebooks')
! rm PsyIIExecutionTrace.txt
#! ~/Dev/vice-emu-code/vice/src/x64sc -directory ~/Dev/vice-emu-code/vice/data/ -moncommands trackingtrace.txt ../psychedelia/bin/psychedelia.prg 
! x64  -moncommands executiontrace.txt ../../psyII/bin/psyII.prg
# Out:
# Already on 'execution_cycle'
# 64tass -Wall -Wno-implied-reg --cbm-prg -o bin/psyII.prg -L bin/list-co1.txt -l bin/labels.txt src/psyII.asm
# 64tass Turbo Assembler Macro V1.56.2625
# 64TASS comes with ABSOLUTELY NO WARRANTY; This is free software, and you
# are welcome to redistribute it under certain conditions; See LICENSE!
#
# Assembling file:   src/psyII.asm
# Assembling file:   src/constants.asm
# Assembling file:   src/charset.asm
# Error messages:    None
# Warning messages:  None
# Passes:            3
# Memory range:      $0801-$1046   $0846
# Memory range:      $2000-$27ff   $0800
# echo "65d265c4a55235508353668b5c61b1dd  bin/psyII.prg" | md5sum -c
# bin/psyII.prg: FAILED
# md5sum: WARNING: 1 computed checksum did NOT match
# make: *** [Makefile:13: psyII.prg] Error 1
# Hotkeys: Initializing.
# Hotkeys: Parsing C64 hotkeys file:
# Hotkeys: OK.
# ffmpeg avformat lib has version 3a4c64, VICE expects 3a4c64: full match
# ffmpeg  avcodec lib has version 3a8664, VICE expects 3a8664: full match
# ffmpeg   avutil lib has version 384664, VICE expects 384664: full match
# ffmpeg  swscale lib has version 050964, VICE expects 050964: full match
# ffmpeg swresample lib has version 030964, VICE expects 030964: full match
# Detecting ISA HardSID boards.
# Could not open '/dev/port'.
# Cannot get permission to access $300.
# Detecting PCI HardSID boards.
# No PCI HardSID boards found.
# Detecting PCI CatWeasel boards.
# No PCI CatWeasel found.
# Detecting direct I/O ISA SSI2001.
# Could not open '/dev/port'.
# Cannot get permission to access $280.
# Hotkeys: parsing '/home/robert/.config/vice/gtk3-hotkeys-C64.vhk':
# Reading configuration file `/home/robert/.config/vice/vicerc'.
# Opening monitor command playback file: executiontrace.txt
#
# *** VICE Version 3.6.1 ***
#
# Welcome to x64, the free portable C64 Emulator.
#
# Current VICE team members:
# Martin Pottendorfer, Marco van den Heuvel, Fabrizio Gennari, Groepaz,
# Errol Smith, Ingo Korb, Olaf Seibert, Marcus Sutton, Kajtar Zsolt, AreaScout,
# Bas Wassink, Michael C. Martin, Christopher Phillips, David Hogan,
# Empathic Qubit, Roberto Muscedere, June Tate-Gans, Pablo Roldan.
#
# This is free software with ABSOLUTELY NO WARRANTY.
# See the "About VICE" command for more info.
#
# random seed was: 0x660c64c6
# command line was: x64 -moncommands executiontrace.txt ../../psyII/bin/psyII.prg
# Loading system file `/usr/share/vice/C64/kernal'.
# Loading system file `/usr/share/vice/C64/basic'.
# Loading system file `/usr/share/vice/C64/chargen'.
# Loading system file `/usr/share/vice/PRINTER/mps803'.
# Palette: Loading palette `/usr/share/vice/PRINTER/mps803.vpl'.
# Palette: Warning - mps803.vpl, 9: garbage at end of line.
# Palette: Warning - mps803.vpl, 12: garbage at end of line.
# Loading system file `/usr/share/vice/PRINTER/nl10-cbm'.
# Palette: Loading palette `/usr/share/vice/PRINTER/nl10.vpl'.
# Palette: Warning - nl10.vpl, 9: garbage at end of line.
# Palette: Warning - nl10.vpl, 12: garbage at end of line.
# NL10: Printer driver initialized.
# Palette: Loading palette `/usr/share/vice/PRINTER/1520.vpl'.
# Palette: Warning - 1520.vpl, 9: garbage at end of line.
# Palette: Warning - 1520.vpl, 12: garbage at end of line.
# Palette: Warning - 1520.vpl, 15: garbage at end of line.
# Palette: Warning - 1520.vpl, 18: garbage at end of line.
# Palette: Warning - 1520.vpl, 21: garbage at end of line.
# Loading system file `/usr/share/vice/DRIVES/dos1540'.
# Loading system file `/usr/share/vice/DRIVES/dos1541'.
# Loading system file `/usr/share/vice/DRIVES/d1541II'.
# Loading system file `/usr/share/vice/DRIVES/dos1570'.
# Loading system file `/usr/share/vice/DRIVES/dos1571'.
# Loading system file `/usr/share/vice/DRIVES/dos1581'.
# DriveROM: Error - 2000 ROM image not found. Hardware-level 2000 emulation is not available.
# DriveROM: Error - 4000 ROM image not found. Hardware-level 4000 emulation is not available.
# DriveROM: Error - CMDHD ROM image not found. Hardware-level CMDHD emulation is not available.
# Loading system file `/usr/share/vice/DRIVES/dos2031'.
# Loading system file `/usr/share/vice/DRIVES/dos2040'.
# Loading system file `/usr/share/vice/DRIVES/dos3040'.
# Loading system file `/usr/share/vice/DRIVES/dos4040'.
# Loading system file `/usr/share/vice/DRIVES/dos1001'.
# Loading system file `/usr/share/vice/DRIVES/dos9000'.
# Drive: Finished loading ROM images.
# using GTK3 backend: OpenGL
# GLX version: 1.4
# Getting matching framebuffer configs
# Found 112 matching FB configs.
# Obtained OpenGL 4.6 context
# 	  Vendor: Intel
# 	Renderer: Mesa Intel(R) Graphics (ADL GT2)
# 	 Version: 4.6 (Core Profile) Mesa 23.2.1-1ubuntu3.1~22.04.2
# 	  Legacy: no
# Direct GLX rendering context obtained
# Swap control support. glXSwapIntervalMESA: 1 glXSwapIntervalEXT: 1 glXSwapIntervalSGI: 1
# Loading vertex shader: /usr/share/vice/GLSL/viewport.vert
# Loading fragment shader: /usr/share/vice/GLSL/builtin.frag
# Loading vertex shader: /usr/share/vice/GLSL/viewport.vert
# Loading fragment shader: /usr/share/vice/GLSL/builtin-interlaced.frag
# Loading vertex shader: /usr/share/vice/GLSL/viewport.vert
# Loading fragment shader: /usr/share/vice/GLSL/bicubic.frag
# Loading vertex shader: /usr/share/vice/GLSL/viewport.vert
# Loading fragment shader: /usr/share/vice/GLSL/bicubic-interlaced.frag
# Created render thread 0
# Render thread initialised
# opening dynamic library libmp3lame.so failed!
# ERROR setting up dynamic lame lib!
# Sound: Available sound devices: pulse alsa dummy fs dump wav voc iff aiff mp3 soundmovie
# Joystick: Linux joystick interface initialization...
# Joystick: Warning - Cannot open joystick device `/dev/input/js0'.
# Joystick: Warning - Cannot open joystick device `/dev/input/js1'.
# Joystick: Warning - Cannot open joystick device `/dev/input/js2'.
# Joystick: Warning - Cannot open joystick device `/dev/input/js3'.
# Joystick: Warning - Cannot open joystick device `/dev/input/js4'.
# Joystick: Warning - Cannot open joystick device `/dev/input/js5'.
# Joystick: Warning - Cannot open joystick device `/dev/input/js6'.
# Joystick: Warning - Cannot open joystick device `/dev/input/js7'.
# Keyboard: Loading keymap `/usr/share/vice/C64/gtk3_sym.vkm'.
# Keyboard: Warning - gtk3_sym.vkm: !LCBM !VCBM !LCTRL !VCTRL not defined.
# AUTOSTART: Autodetecting image type of `../../psyII/bin/psyII.prg'.
# Filesystem Image Probe: Error - Import GCR: Unknown GCR image version 48.
# Filesystem Image: Unknown disk image `../../psyII/bin/psyII.prg'.
# Tape: Error - Cannot open file `../../psyII/bin/psyII.prg'
# Error - CRT header invalid.
# CART: '/home/robert/Dev/psypixels/notebooks/../../psyII/bin/psyII.prg' is not a valid CRT file.
# AUTOSTART: Loading PRG file `../../psyII/bin/psyII.prg' with autostart disk image.
# AUTOSTART: Resetting drive 8
# AUTOSTART: Resetting the machine to autostart 'PSYII'
# AUTOSTART: Turning Warp mode on.
# AUTOSTART: `../../psyII/bin/psyII.prg' recognized as program/p00 file.
# Main CPU: starting at ($FFFC).
# Main CPU: RESET.
# Increasing trap_func array size to 1 with 1 to run
# Monitor playback command: log on
# Unit 8: RESET.
# Monitor playback command: logname "PsyIIExecutionTrace.txt"
# Monitor playback command: tr exec 082a
# Monitor playback command: tr exec 0830
# Monitor playback command: tr exec 0dbf
# Monitor playback command: tr exec 0e04
# Monitor playback command: tr exec 0b7a
# Monitor playback command: tr exec 0b96
# Monitor playback command: tr exec 0bc9
# Monitor playback command: tr exec 0aef
# Monitor playback command: tr exec 0af6
# Monitor playback command: tr exec 0b21
# Monitor playback command: tr exec 0b55
# Monitor playback command: tr exec 0b62
# Monitor playback command: tr exec 0aac
# Monitor playback command: tr exec 0ad3
# Monitor playback command: tr exec 0ad9
# Closed monitor command playback file: executiontrace.txt
# Sound: Opened device `pulse', speed 48000Hz, fragment size 2.67ms, buffer size 32.00ms
# reSID: MOS8580, filter on, sampling rate 48000Hz - resampling, pass to 21600Hz
# Sync reset
# AUTOSTART: Loading program 'PSYII'
# AUTOSTART: Entered ROM at $e5d1
# AUTOSTART: Searching for ...
# AUTOSTART: Loading
# AUTOSTART: Entered ROM at $ea21
# AUTOSTART: Ready
# AUTOSTART: Turning Warp mode off.
# AUTOSTART: Starting program.
# AUTOSTART: Restoring FileSystemDevice8 to 1.
# AUTOSTART: Restoring FSDevice8ConvertP00 to 1.
# AUTOSTART: Restoring FSDeviceLongNames to 0.
# AUTOSTART: Done.
# Sync reset
# Initiating render thread 0 shutdown
# Joining render thread 0 ...
# Joined render thread 0.
# Resources with non default values:
# Window0Height=1054
# Window0Width=1894
# Window0Xpos=26
# Window0Ypos=26
# KeySet1North=65362
# KeySet1East=65363
# KeySet1South=65364
# KeySet1West=65361
# KeySet1Fire=65507
# JoyDevice2=2
# MonitorLogFileName="PsyIIExecutionTrace.txt"
# MonitorLogEnabled=1
#
# reconstructed commandline options (might be incomplete):
# -default -monlogname "PsyIIExecutionTrace.txt" -monlog -joydev2 "2"
#
# VICE thread initiating shutdown
# VICE thread is exiting
# VICE thread has been joined.
# Sound: Closing device `pulse'

# %%
input_file = open(log_file,'r')

trace = []
lines = input_file.readlines()
for i in range(len(syms)+1, len(lines), 2):
    addr = lines[i][3:7]
    pc = int(lines[i][70:79].strip())
    trace += [(syms[addr],pc)]

pstart = min([pc for s,pc in trace if "PaintStructureAtCurrentPosition" in s])
pend = max([pc for s,pc in trace if "PaintStructureAtCurrentPosition" in s])
trace = [(s,pc) for s,pc in trace if pc >= pstart and pc <= pend+100]

bpc = trace[0][1]
trace = [(a,pc-bpc) for a,pc in trace]
trace
# Out:
# [('PaintStructureAtCurrentPosition-Enter', 0),
#  ('PaintPixelForCurrentSymmetry-Enter', 32),
#  ('PaintPixel-Enter', 91),
#  ('PaintPixel-Exit', 155),
#  ('PaintPixel-Enter', 194),
#  ('PaintPixel-Exit', 244),
#  ('PaintPixelForCurrentSymmetry-Exit', 259),
#  ('PaintStructureAtCurrentPosition-Exit', 271),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 293),
#  ('PsychedeliaLoop-Exit', 324),
#  ('PsychedeliaLoop-Enter', 327),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 333),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 371),
#  ('PsychedeliaLoop-Exit', 402),
#  ('PsychedeliaLoop-Enter', 405),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 411),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 440),
#  ('PsychedeliaLoop-Exit', 471),
#  ('PsychedeliaLoop-Enter', 474),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 480),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 509),
#  ('PsychedeliaLoop-Exit', 540),
#  ('PsychedeliaLoop-Enter', 543),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 549),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 578),
#  ('PsychedeliaLoop-Exit', 609),
#  ('PsychedeliaLoop-Enter', 612),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 618),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 647),
#  ('PsychedeliaLoop-Exit', 678),
#  ('PsychedeliaLoop-Enter', 681),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 687),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 716),
#  ('PsychedeliaLoop-Exit', 747),
#  ('PsychedeliaLoop-Enter', 750),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 756),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 785),
#  ('PsychedeliaLoop-Exit', 816),
#  ('PsychedeliaLoop-Enter', 819),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 825),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 854),
#  ('PsychedeliaLoop-Exit', 885),
#  ('PsychedeliaLoop-Enter', 888),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 894),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 923),
#  ('PsychedeliaLoop-Exit', 954),
#  ('PsychedeliaLoop-Enter', 957),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 963),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 992),
#  ('PsychedeliaLoop-Exit', 1023),
#  ('PsychedeliaLoop-Enter', 1026),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 1032),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 1061),
#  ('PsychedeliaLoop-Exit', 1092),
#  ('PsychedeliaLoop-Enter', 1095),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 1101),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 1130),
#  ('PsychedeliaLoop-Exit', 1161),
#  ('PsychedeliaLoop-Enter', 1164),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 1170),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 1199),
#  ('PsychedeliaLoop-Exit', 1230),
#  ('PsychedeliaLoop-Enter', 1233),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 1239),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 1268),
#  ('PsychedeliaLoop-Exit', 1299),
#  ('PsychedeliaLoop-Enter', 1302),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 1308),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 1337),
#  ('PsychedeliaLoop-Exit', 1368),
#  ('PsychedeliaLoop-Enter', 1371),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 1377),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 1406),
#  ('PsychedeliaLoop-Exit', 1437),
#  ('PsychedeliaLoop-Enter', 1440),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 1446),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 1475),
#  ('PsychedeliaLoop-Exit', 1506),
#  ('PsychedeliaLoop-Enter', 1509),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 1515),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 1544),
#  ('PsychedeliaLoop-Exit', 1575),
#  ('PsychedeliaLoop-Enter', 1578),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 1584),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 1613),
#  ('PsychedeliaLoop-Exit', 1644),
#  ('PsychedeliaLoop-Enter', 1647),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 1653),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 1682),
#  ('PsychedeliaLoop-Exit', 1713),
#  ('PsychedeliaLoop-Enter', 1716),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 1722),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 1751),
#  ('PsychedeliaLoop-Exit', 1782),
#  ('PsychedeliaLoop-Enter', 1785),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 1791),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 1820),
#  ('PsychedeliaLoop-Exit', 1851),
#  ('PsychedeliaLoop-Enter', 1854),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 1860),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 1889),
#  ('PsychedeliaLoop-Exit', 1920),
#  ('PsychedeliaLoop-Enter', 1923),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 1929),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 1958),
#  ('PsychedeliaLoop-Exit', 1989),
#  ('PsychedeliaLoop-Enter', 1992),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 1998),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 2027),
#  ('PsychedeliaLoop-Exit', 2058),
#  ('PsychedeliaLoop-Enter', 2061),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 2067),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 2096),
#  ('PsychedeliaLoop-Exit', 2127),
#  ('PsychedeliaLoop-Enter', 2130),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 2136),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 2165),
#  ('PsychedeliaLoop-Exit', 2196),
#  ('PsychedeliaLoop-Enter', 2199),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 2205),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 2234),
#  ('PsychedeliaLoop-Exit', 2265),
#  ('PsychedeliaLoop-Enter', 2268),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 2274),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 2303),
#  ('PsychedeliaLoop-Exit', 2334),
#  ('PsychedeliaLoop-Enter', 2337),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 2343),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 2372),
#  ('PsychedeliaLoop-Exit', 2403),
#  ('PsychedeliaLoop-Enter', 2406),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 2412),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 2441),
#  ('PsychedeliaLoop-Exit', 2472),
#  ('PsychedeliaLoop-Enter', 2475),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 2481),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 2510),
#  ('PsychedeliaLoop-Exit', 2541),
#  ('PsychedeliaLoop-Enter', 2544),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 2550),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 2579),
#  ('PsychedeliaLoop-Exit', 2610),
#  ('PsychedeliaLoop-Enter', 2613),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 2619),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 2648),
#  ('PsychedeliaLoop-Exit', 2679),
#  ('PsychedeliaLoop-Enter', 2682),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 2688),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 2717),
#  ('PsychedeliaLoop-Exit', 2748),
#  ('PsychedeliaLoop-Enter', 2751),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 2757),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 2786),
#  ('PsychedeliaLoop-Exit', 2817),
#  ('PsychedeliaLoop-Enter', 2820),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 2826),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 2855),
#  ('PsychedeliaLoop-Exit', 2886),
#  ('PsychedeliaLoop-Enter', 2889),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 2895),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 2924),
#  ('PsychedeliaLoop-Exit', 2955),
#  ('PsychedeliaLoop-Enter', 2958),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 2964),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 2993),
#  ('PsychedeliaLoop-Exit', 3024),
#  ('PsychedeliaLoop-Enter', 3027),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 3033),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 3062),
#  ('PsychedeliaLoop-Exit', 3093),
#  ('PsychedeliaLoop-Enter', 3096),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 3102),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 3131),
#  ('PsychedeliaLoop-Exit', 3162),
#  ('PsychedeliaLoop-Enter', 3165),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 3171),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 3200),
#  ('PsychedeliaLoop-Exit', 3231),
#  ('PsychedeliaLoop-Enter', 3234),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 3240),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 3269),
#  ('PsychedeliaLoop-Exit', 3300),
#  ('PsychedeliaLoop-Enter', 3303),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 3309),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 3338),
#  ('PsychedeliaLoop-Exit', 3369),
#  ('PsychedeliaLoop-Enter', 3372),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 3378),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 3407),
#  ('PsychedeliaLoop-Exit', 3438),
#  ('PsychedeliaLoop-Enter', 3441),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 3447),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 3476),
#  ('PsychedeliaLoop-Exit', 3507),
#  ('PsychedeliaLoop-Enter', 3510),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 3516),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 3545),
#  ('PsychedeliaLoop-Exit', 3576),
#  ('PsychedeliaLoop-Enter', 3579),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 3585),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 3614),
#  ('PsychedeliaLoop-Exit', 3645),
#  ('PsychedeliaLoop-Enter', 3648),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 3654),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 3683),
#  ('PsychedeliaLoop-Exit', 3714),
#  ('PsychedeliaLoop-Enter', 3717),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 3723),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 3752),
#  ('PsychedeliaLoop-Exit', 3783),
#  ('PsychedeliaLoop-Enter', 3786),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 3792),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 3821),
#  ('PsychedeliaLoop-Exit', 3852),
#  ('PsychedeliaLoop-Enter', 3855),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 3861),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 3890),
#  ('PsychedeliaLoop-Exit', 3921),
#  ('PsychedeliaLoop-Enter', 3924),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 3930),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 3959),
#  ('PsychedeliaLoop-Exit', 3990),
#  ('PsychedeliaLoop-Enter', 3993),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 3999),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 4028),
#  ('PsychedeliaLoop-Exit', 4059),
#  ('PsychedeliaLoop-Enter', 4062),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 4068),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 4097),
#  ('PsychedeliaLoop-Exit', 4128),
#  ('PsychedeliaLoop-Enter', 4131),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 4137),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 4166),
#  ('PsychedeliaLoop-Exit', 4197),
#  ('PsychedeliaLoop-Enter', 4200),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 4206),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 4235),
#  ('PsychedeliaLoop-Exit', 4266),
#  ('PsychedeliaLoop-Enter', 4269),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 4275),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 4304),
#  ('PsychedeliaLoop-Exit', 4335),
#  ('PsychedeliaLoop-Enter', 4338),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 4344),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 4416),
#  ('PsychedeliaLoop-Exit', 4447),
#  ('PsychedeliaLoop-Enter', 4450),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 4456),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 4485),
#  ('PsychedeliaLoop-Exit', 4516),
#  ('PsychedeliaLoop-Enter', 4519),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 4525),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 4554),
#  ('PsychedeliaLoop-Exit', 4585),
#  ('PsychedeliaLoop-Enter', 4588),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 4594),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 4623),
#  ('PsychedeliaLoop-Exit', 4654),
#  ('PsychedeliaLoop-Enter', 4657),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 4663),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 4692),
#  ('PsychedeliaLoop-Exit', 4723),
#  ('PsychedeliaLoop-Enter', 4726),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 4732),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 4770),
#  ('PsychedeliaLoop-Exit', 4801),
#  ('PsychedeliaLoop-Enter', 4804),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 4810),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 4848),
#  ('PsychedeliaLoop-Exit', 4922),
#  ('PsychedeliaLoop-Enter', 4925),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 4931),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 4960),
#  ('PsychedeliaLoop-Exit', 4991),
#  ('PsychedeliaLoop-Enter', 4994),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 5000),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 5029),
#  ('PsychedeliaLoop-Exit', 5060),
#  ('PsychedeliaLoop-Enter', 5063),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 5069),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 5098),
#  ('PsychedeliaLoop-Exit', 5129),
#  ('PsychedeliaLoop-Enter', 5132),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 5138),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 5167),
#  ('PsychedeliaLoop-Exit', 5198),
#  ('PsychedeliaLoop-Enter', 5201),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 5207),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 5236),
#  ('PsychedeliaLoop-Exit', 5267),
#  ('PsychedeliaLoop-Enter', 5270),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 5276),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 5305),
#  ('PsychedeliaLoop-Exit', 5336),
#  ('PsychedeliaLoop-Enter', 5339),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 5345),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 5374),
#  ('PsychedeliaLoop-Exit', 5448),
#  ('PsychedeliaLoop-Enter', 5451),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 5457),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 5486),
#  ('PsychedeliaLoop-Exit', 5517),
#  ('PsychedeliaLoop-Enter', 5520),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 5526),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 5555),
#  ('PsychedeliaLoop-Exit', 5586),
#  ('PsychedeliaLoop-Enter', 5589),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 5595),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 5624),
#  ('PsychedeliaLoop-Exit', 5655),
#  ('PsychedeliaLoop-Enter', 5658),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 5664),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 5693),
#  ('PsychedeliaLoop-Exit', 5724),
#  ('PsychedeliaLoop-Enter', 5727),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 5733),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 5762),
#  ('PsychedeliaLoop-Exit', 5793),
#  ('PsychedeliaLoop-Enter', 5796),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 5802),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 5831),
#  ('PsychedeliaLoop-Exit', 5862),
#  ('PsychedeliaLoop-Enter', 5865),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 5871),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 5943),
#  ('PsychedeliaLoop-Exit', 5974),
#  ('PsychedeliaLoop-Enter', 5977),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 5983),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 6012),
#  ('PsychedeliaLoop-Exit', 6043),
#  ('PsychedeliaLoop-Enter', 6046),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 6052),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 6081),
#  ('PsychedeliaLoop-Exit', 6112),
#  ('PsychedeliaLoop-Enter', 6115),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 6121),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 6150),
#  ('PsychedeliaLoop-Exit', 6181),
#  ('PsychedeliaLoop-Enter', 6184),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 6190),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 6219),
#  ('PsychedeliaLoop-Exit', 6250),
#  ('PsychedeliaLoop-Enter', 6253),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 6259),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 6288),
#  ('PsychedeliaLoop-Exit', 6319),
#  ('PsychedeliaLoop-Enter', 6322),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 6328),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 6357),
#  ('PsychedeliaLoop-Exit', 6431),
#  ('PsychedeliaLoop-Enter', 6434),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 6440),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 6469),
#  ('PsychedeliaLoop-Exit', 6500),
#  ('PsychedeliaLoop-Enter', 6503),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 6509),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 6538),
#  ('PsychedeliaLoop-Exit', 6569),
#  ('PsychedeliaLoop-Enter', 6572),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 6578),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 6607),
#  ('PsychedeliaLoop-Exit', 6638),
#  ('PsychedeliaLoop-Enter', 6641),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 6647),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 6676),
#  ('PsychedeliaLoop-Exit', 6707),
#  ('PsychedeliaLoop-Enter', 6710),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 6716),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 6745),
#  ('PsychedeliaLoop-Exit', 6776),
#  ('PsychedeliaLoop-Enter', 6779),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 6785),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 6814),
#  ('PsychedeliaLoop-Exit', 6845),
#  ('PsychedeliaLoop-Enter', 6848),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 6854),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 6883),
#  ('PsychedeliaLoop-Exit', 6955),
#  ('PsychedeliaLoop-Enter', 6958),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 6964),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 6993),
#  ('PsychedeliaLoop-Exit', 7024),
#  ('PsychedeliaLoop-Enter', 7027),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 7033),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 7062),
#  ('PsychedeliaLoop-Exit', 7093),
#  ('PsychedeliaLoop-Enter', 7096),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 7102),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 7131),
#  ('PsychedeliaLoop-Exit', 7162),
#  ('PsychedeliaLoop-Enter', 7165),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 7171),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 7200),
#  ('PsychedeliaLoop-Exit', 7231),
#  ('PsychedeliaLoop-Enter', 7234),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 7240),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 7269),
#  ('PsychedeliaLoop-Exit', 7300),
#  ('PsychedeliaLoop-Enter', 7303),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 7309),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 7338),
#  ('PsychedeliaLoop-Exit', 7369),
#  ('PsychedeliaLoop-Enter', 7372),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 7378),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 7448),
#  ('PsychedeliaLoop-Exit', 7479),
#  ('PsychedeliaLoop-Enter', 7482),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 7488),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 7517),
#  ('PsychedeliaLoop-Exit', 7548),
#  ('PsychedeliaLoop-Enter', 7551),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 7557),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 7586),
#  ('PsychedeliaLoop-Exit', 7617),
#  ('PsychedeliaLoop-Enter', 7620),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 7626),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 7655),
#  ('PsychedeliaLoop-Exit', 7686),
#  ('PsychedeliaLoop-Enter', 7689),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 7695),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 7724),
#  ('PsychedeliaLoop-Exit', 7755),
#  ('PsychedeliaLoop-Enter', 7758),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 7764),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 7793),
#  ('PsychedeliaLoop-Exit', 7824),
#  ('PsychedeliaLoop-Enter', 7827),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 7833),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 7862),
#  ('PsychedeliaLoop-Exit', 7893),
#  ('PsychedeliaLoop-Enter', 7896),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 7944),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 7973),
#  ('PsychedeliaLoop-Exit', 8004),
#  ('PsychedeliaLoop-Enter', 8007),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 8013),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 8042),
#  ('PsychedeliaLoop-Exit', 8073),
#  ('PsychedeliaLoop-Enter', 8076),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 8082),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 8111),
#  ('PsychedeliaLoop-Exit', 8142),
#  ('PsychedeliaLoop-Enter', 8145),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 8151),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 8180),
#  ('PsychedeliaLoop-Exit', 8211),
#  ('PsychedeliaLoop-Enter', 8214),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 8220),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 8249),
#  ('PsychedeliaLoop-Exit', 8280),
#  ('PsychedeliaLoop-Enter', 8283),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 8289),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 8318),
#  ('PsychedeliaLoop-Exit', 8349),
#  ('PsychedeliaLoop-Enter', 8352),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 8358),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 8387),
#  ('PsychedeliaLoop-Exit', 8461),
#  ('PsychedeliaLoop-Enter', 8464),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 8470),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 8499),
#  ('PsychedeliaLoop-Exit', 8530),
#  ('PsychedeliaLoop-Enter', 8533),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 8539),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 8568),
#  ('PsychedeliaLoop-Exit', 8599),
#  ('PsychedeliaLoop-Enter', 8602),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 8608),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 8637),
#  ('PsychedeliaLoop-Exit', 8668),
#  ('PsychedeliaLoop-Enter', 8671),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 8677),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 8706),
#  ('PsychedeliaLoop-Exit', 8737),
#  ('PsychedeliaLoop-Enter', 8740),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 8746),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 8775),
#  ('PsychedeliaLoop-Exit', 8806),
#  ('PsychedeliaLoop-Enter', 8809),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 8815),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 8844),
#  ('PsychedeliaLoop-Exit', 8875),
#  ('PsychedeliaLoop-Enter', 8878),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 8884),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 8956),
#  ('PsychedeliaLoop-Exit', 8987),
#  ('PsychedeliaLoop-Enter', 8990),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 8996),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 9025),
#  ('PsychedeliaLoop-Exit', 9056),
#  ('PsychedeliaLoop-Enter', 9059),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 9065),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 9094),
#  ('PsychedeliaLoop-Exit', 9125),
#  ('PsychedeliaLoop-Enter', 9128),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 9134),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 9163),
#  ('PsychedeliaLoop-Exit', 9194),
#  ('PsychedeliaLoop-Enter', 9197),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 9203),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 9232),
#  ('PsychedeliaLoop-Exit', 9263),
#  ('PsychedeliaLoop-Enter', 9266),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 9272),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 9301),
#  ('PsychedeliaLoop-Exit', 9332),
#  ('PsychedeliaLoop-Enter', 9335),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 9341),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 9370),
#  ('PsychedeliaLoop-Exit', 9401),
#  ('PsychedeliaLoop-Enter', 9404),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 9410),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 9482),
#  ('PsychedeliaLoop-Exit', 9513),
#  ('PsychedeliaLoop-Enter', 9516),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 9522),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 9551),
#  ('PsychedeliaLoop-Exit', 9582),
#  ('PsychedeliaLoop-Enter', 9585),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 9591),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 9629),
#  ('PsychedeliaLoop-Exit', 9660),
#  ('PsychedeliaLoop-Enter', 9663),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 9669),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 9707),
#  ('PsychedeliaLoop-Exit', 9738),
#  ('PsychedeliaLoop-Enter', 9741),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 9747),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 9776),
#  ('PsychedeliaLoop-Exit', 9807),
#  ('PsychedeliaLoop-Enter', 9810),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 9816),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 9845),
#  ('PsychedeliaLoop-Exit', 9876),
#  ('PsychedeliaLoop-Enter', 9879),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 9885),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 9914),
#  ('PsychedeliaLoop-Exit', 9988),
#  ('PsychedeliaLoop-Enter', 9991),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 9997),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 10026),
#  ('PsychedeliaLoop-Exit', 10057),
#  ('PsychedeliaLoop-Enter', 10060),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 10066),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 10095),
#  ('PsychedeliaLoop-Exit', 10126),
#  ('PsychedeliaLoop-Enter', 10129),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 10135),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 10164),
#  ('PsychedeliaLoop-Exit', 10195),
#  ('PsychedeliaLoop-Enter', 10198),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 10204),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 10233),
#  ('PsychedeliaLoop-Exit', 10264),
#  ('PsychedeliaLoop-Enter', 10267),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 10273),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 10302),
#  ('PsychedeliaLoop-Exit', 10333),
#  ('PsychedeliaLoop-Enter', 10336),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 10342),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 10371),
#  ('PsychedeliaLoop-Exit', 10402),
#  ('PsychedeliaLoop-Enter', 10405),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 10411),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 10483),
#  ('PsychedeliaLoop-Exit', 10514),
#  ('PsychedeliaLoop-Enter', 10517),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 10523),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 10552),
#  ('PsychedeliaLoop-Exit', 10583),
#  ('PsychedeliaLoop-Enter', 10586),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 10592),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 10621),
#  ('PsychedeliaLoop-Exit', 10652),
#  ('PsychedeliaLoop-Enter', 10655),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 10661),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 10690),
#  ('PsychedeliaLoop-Exit', 10721),
#  ('PsychedeliaLoop-Enter', 10724),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 10730),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 10759),
#  ('PsychedeliaLoop-Exit', 10790),
#  ('PsychedeliaLoop-Enter', 10793),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 10799),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 10828),
#  ('PsychedeliaLoop-Exit', 10859),
#  ('PsychedeliaLoop-Enter', 10862),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 10868),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 10897),
#  ('PsychedeliaLoop-Exit', 10971),
#  ('PsychedeliaLoop-Enter', 10974),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 10980),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 11009),
#  ('PsychedeliaLoop-Exit', 11040),
#  ('PsychedeliaLoop-Enter', 11043),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 11049),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 11078),
#  ('PsychedeliaLoop-Exit', 11109),
#  ('PsychedeliaLoop-Enter', 11112),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 11118),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 11147),
#  ('PsychedeliaLoop-Exit', 11178),
#  ('PsychedeliaLoop-Enter', 11181),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 11187),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 11216),
#  ('PsychedeliaLoop-Exit', 11247),
#  ('PsychedeliaLoop-Enter', 11250),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 11256),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 11285),
#  ('PsychedeliaLoop-Exit', 11316),
#  ('PsychedeliaLoop-Enter', 11319),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 11325),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 11354),
#  ('PsychedeliaLoop-Exit', 11385),
#  ('PsychedeliaLoop-Enter', 11388),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 11394),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 11423),
#  ('PsychedeliaLoop-Exit', 11497),
#  ('PsychedeliaLoop-Enter', 11500),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 11506),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 11535),
#  ('PsychedeliaLoop-Exit', 11566),
#  ('PsychedeliaLoop-Enter', 11569),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 11575),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 11604),
#  ('PsychedeliaLoop-Exit', 11635),
#  ('PsychedeliaLoop-Enter', 11638),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 11644),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 11673),
#  ('PsychedeliaLoop-Exit', 11704),
#  ('PsychedeliaLoop-Enter', 11707),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 11713),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 11742),
#  ('PsychedeliaLoop-Exit', 11773),
#  ('PsychedeliaLoop-Enter', 11776),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 11782),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 11811),
#  ('PsychedeliaLoop-Exit', 11842),
#  ('PsychedeliaLoop-Enter', 11845),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 11851),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 11880),
#  ('PsychedeliaLoop-Exit', 11911),
#  ('PsychedeliaLoop-Enter', 11914),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 11920),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 11992),
#  ('PsychedeliaLoop-Exit', 12023),
#  ('PsychedeliaLoop-Enter', 12026),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 12032),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 12061),
#  ('PsychedeliaLoop-Exit', 12092),
#  ('PsychedeliaLoop-Enter', 12095),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 12101),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 12130),
#  ('PsychedeliaLoop-Exit', 12161),
#  ('PsychedeliaLoop-Enter', 12164),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 12170),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 12199),
#  ('PsychedeliaLoop-Exit', 12230),
#  ('PsychedeliaLoop-Enter', 12233),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 12239),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 12268),
#  ('PsychedeliaLoop-Exit', 12299),
#  ('PsychedeliaLoop-Enter', 12302),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 12308),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 12337),
#  ('PsychedeliaLoop-Exit', 12368),
#  ('PsychedeliaLoop-Enter', 12371),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 12377),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 12406),
#  ('PsychedeliaLoop-Exit', 12480),
#  ('PsychedeliaLoop-Enter', 12483),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 12489),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 12518),
#  ('PsychedeliaLoop-Exit', 12549),
#  ('PsychedeliaLoop-Enter', 12552),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 12558),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 12587),
#  ('PsychedeliaLoop-Exit', 12618),
#  ('PsychedeliaLoop-Enter', 12621),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 12627),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 12656),
#  ('PsychedeliaLoop-Exit', 12687),
#  ('PsychedeliaLoop-Enter', 12690),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 12696),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 12725),
#  ('PsychedeliaLoop-Exit', 12756),
#  ('PsychedeliaLoop-Enter', 12759),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 12765),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 12794),
#  ('PsychedeliaLoop-Exit', 12825),
#  ('PsychedeliaLoop-Enter', 12828),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 12834),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 12863),
#  ('PsychedeliaLoop-Exit', 12894),
#  ('PsychedeliaLoop-Enter', 12897),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 12903),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 12932),
#  ('PsychedeliaLoop-Exit', 13006),
#  ('PsychedeliaLoop-Enter', 13009),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 13015),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 13044),
#  ('PsychedeliaLoop-Exit', 13075),
#  ('PsychedeliaLoop-Enter', 13078),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 13084),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 13113),
#  ('PsychedeliaLoop-Exit', 13144),
#  ('PsychedeliaLoop-Enter', 13147),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 13153),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 13182),
#  ('PsychedeliaLoop-Exit', 13213),
#  ('PsychedeliaLoop-Enter', 13216),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 13222),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 15653),
#  ('PsychedeliaLoop-Exit', 15684),
#  ('PsychedeliaLoop-Enter', 15687),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 15693),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 15722),
#  ('PsychedeliaLoop-Exit', 15753),
#  ('PsychedeliaLoop-Enter', 15756),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 15762),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 15791),
#  ('PsychedeliaLoop-Exit', 15822),
#  ('PsychedeliaLoop-Enter', 15825),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 15831),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 15860),
#  ('PsychedeliaLoop-Exit', 15891),
#  ('PsychedeliaLoop-Enter', 15894),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 15900),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 15929),
#  ('PsychedeliaLoop-Exit', 15960),
#  ('PsychedeliaLoop-Enter', 16006),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 16012),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 16041),
#  ('PsychedeliaLoop-Exit', 16072),
#  ('PsychedeliaLoop-Enter', 16075),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 16081),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 16110),
#  ('PsychedeliaLoop-Exit', 16141),
#  ('PsychedeliaLoop-Enter', 16144),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 16150),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 16179),
#  ('PsychedeliaLoop-Exit', 16210),
#  ('PsychedeliaLoop-Enter', 16213),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 16219),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 16248),
#  ('PsychedeliaLoop-Exit', 16279),
#  ('PsychedeliaLoop-Enter', 16282),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 16288),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 16317),
#  ('PsychedeliaLoop-Exit', 16348),
#  ('PsychedeliaLoop-Enter', 16351),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 16357),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 16386),
#  ('PsychedeliaLoop-Exit', 16417),
#  ('PsychedeliaLoop-Enter', 16420),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 16426),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 16455),
#  ('PsychedeliaLoop-Exit', 16529),
#  ('PsychedeliaLoop-Enter', 16532),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 16538),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 16567),
#  ('PsychedeliaLoop-Exit', 16598),
#  ('PsychedeliaLoop-Enter', 16601),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 16607),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 16636),
#  ('PsychedeliaLoop-Exit', 16667),
#  ('PsychedeliaLoop-Enter', 16670),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 16676),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 16705),
#  ('PsychedeliaLoop-Exit', 16736),
#  ('PsychedeliaLoop-Enter', 16739),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 16745),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 16774),
#  ('PsychedeliaLoop-Exit', 16805),
#  ('PsychedeliaLoop-Enter', 16808),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 16814),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 16852),
#  ('PsychedeliaLoop-Exit', 16883),
#  ('PsychedeliaLoop-Enter', 16886),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 16892),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 16930),
#  ('PsychedeliaLoop-Exit', 16961),
#  ('PsychedeliaLoop-Enter', 16964),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 16970),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 17008),
#  ('PsychedeliaLoop-Exit', 17039),
#  ('PsychedeliaLoop-Enter', 17042),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 17048),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 17077),
#  ('PsychedeliaLoop-Exit', 17108),
#  ('PsychedeliaLoop-Enter', 17111),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 17117),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 17146),
#  ('PsychedeliaLoop-Exit', 17177),
#  ('PsychedeliaLoop-Enter', 17180),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 17186),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 17215),
#  ('PsychedeliaLoop-Exit', 17246),
#  ('PsychedeliaLoop-Enter', 17249),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 17255),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 17284),
#  ('PsychedeliaLoop-Exit', 17315),
#  ('PsychedeliaLoop-Enter', 17318),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 17324),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 17353),
#  ('PsychedeliaLoop-Exit', 17384),
#  ('PsychedeliaLoop-Enter', 17387),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 17393),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 17422),
#  ('PsychedeliaLoop-Exit', 17453),
#  ('PsychedeliaLoop-Enter', 17456),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 17462),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 17491),
#  ('PsychedeliaLoop-Exit', 17522),
#  ('PsychedeliaLoop-Enter', 17525),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 17531),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 17560),
#  ('PsychedeliaLoop-Exit', 17591),
#  ('PsychedeliaLoop-Enter', 17594),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 17600),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 17629),
#  ('PsychedeliaLoop-Exit', 17660),
#  ('PsychedeliaLoop-Enter', 17663),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 17669),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 17698),
#  ('PsychedeliaLoop-Exit', 17729),
#  ('PsychedeliaLoop-Enter', 17732),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 17738),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 17767),
#  ('PsychedeliaLoop-Exit', 17798),
#  ('PsychedeliaLoop-Enter', 17801),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 17807),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 17836),
#  ('PsychedeliaLoop-Exit', 17867),
#  ('PsychedeliaLoop-Enter', 17870),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 17876),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 17905),
#  ('PsychedeliaLoop-Exit', 17936),
#  ('PsychedeliaLoop-Enter', 17939),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 17945),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 17974),
#  ('PsychedeliaLoop-Exit', 18005),
#  ('PsychedeliaLoop-Enter', 18008),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 18014),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 18043),
#  ('PsychedeliaLoop-Exit', 18074),
#  ('PsychedeliaLoop-Enter', 18077),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 18083),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 18112),
#  ('PsychedeliaLoop-Exit', 18143),
#  ('PsychedeliaLoop-Enter', 18146),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 18152),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 18181),
#  ('PsychedeliaLoop-Exit', 18212),
#  ('PsychedeliaLoop-Enter', 18215),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 18221),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 18250),
#  ('PsychedeliaLoop-Exit', 18281),
#  ('PsychedeliaLoop-Enter', 18284),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 18290),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 18319),
#  ('PsychedeliaLoop-Exit', 18350),
#  ('PsychedeliaLoop-Enter', 18353),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 18359),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 18388),
#  ('PsychedeliaLoop-Exit', 18419),
#  ('PsychedeliaLoop-Enter', 18422),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 18428),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 18457),
#  ('PsychedeliaLoop-Exit', 18488),
#  ('PsychedeliaLoop-Enter', 18491),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 18497),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 18526),
#  ('PsychedeliaLoop-Exit', 18557),
#  ('PsychedeliaLoop-Enter', 18560),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 18566),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 18595),
#  ('PsychedeliaLoop-Exit', 18626),
#  ('PsychedeliaLoop-Enter', 18629),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 18635),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 18664),
#  ('PsychedeliaLoop-Exit', 18695),
#  ('PsychedeliaLoop-Enter', 18698),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 18704),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 18733),
#  ('PsychedeliaLoop-Exit', 18764),
#  ('PsychedeliaLoop-Enter', 18767),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 18773),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 18802),
#  ('PsychedeliaLoop-Exit', 18833),
#  ('PsychedeliaLoop-Enter', 18836),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 18842),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 18871),
#  ('PsychedeliaLoop-Exit', 18902),
#  ('PsychedeliaLoop-Enter', 18905),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 18911),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 18940),
#  ('PsychedeliaLoop-Exit', 18971),
#  ('PsychedeliaLoop-Enter', 18974),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 18980),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 19009),
#  ('PsychedeliaLoop-Exit', 19040),
#  ('PsychedeliaLoop-Enter', 19043),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 19049),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 19078),
#  ('PsychedeliaLoop-Exit', 19109),
#  ('PsychedeliaLoop-Enter', 19112),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 19118),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 19147),
#  ('PsychedeliaLoop-Exit', 19178),
#  ('PsychedeliaLoop-Enter', 19181),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 19187),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 19216),
#  ('PsychedeliaLoop-Exit', 19247),
#  ('PsychedeliaLoop-Enter', 19250),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 19256),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 19285),
#  ('PsychedeliaLoop-Exit', 19316),
#  ('PsychedeliaLoop-Enter', 19319),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 19325),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 19354),
#  ('PsychedeliaLoop-Exit', 19385),
#  ('PsychedeliaLoop-Enter', 19388),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 19394),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 19423),
#  ('PsychedeliaLoop-Exit', 19454),
#  ('PsychedeliaLoop-Enter', 19457),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 19463),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 19492),
#  ('PsychedeliaLoop-Exit', 19523),
#  ('PsychedeliaLoop-Enter', 19526),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 19532),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 19561),
#  ('PsychedeliaLoop-Exit', 19592),
#  ('PsychedeliaLoop-Enter', 19595),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 19601),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 19630),
#  ('PsychedeliaLoop-Exit', 19661),
#  ('PsychedeliaLoop-Enter', 19664),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 19670),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 19699),
#  ('PsychedeliaLoop-Exit', 19730),
#  ('PsychedeliaLoop-Enter', 19733),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 19739),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 19768),
#  ('PsychedeliaLoop-Exit', 19799),
#  ('PsychedeliaLoop-Enter', 19802),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 19808),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 19837),
#  ('PsychedeliaLoop-Exit', 19868),
#  ('PsychedeliaLoop-Enter', 19871),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 19877),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 19906),
#  ('PsychedeliaLoop-Exit', 19937),
#  ('PsychedeliaLoop-Enter', 19940),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 19946),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 19975),
#  ('PsychedeliaLoop-Exit', 20006),
#  ('PsychedeliaLoop-Enter', 20009),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 20015),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 20044),
#  ('PsychedeliaLoop-Exit', 20075),
#  ('PsychedeliaLoop-Enter', 20078),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 20084),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 20113),
#  ('PsychedeliaLoop-Exit', 20144),
#  ('PsychedeliaLoop-Enter', 20147),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 20153),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 20182),
#  ('PsychedeliaLoop-Exit', 20213),
#  ('PsychedeliaLoop-Enter', 20216),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 20222),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 20251),
#  ('PsychedeliaLoop-Exit', 20282),
#  ('PsychedeliaLoop-Enter', 20285),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 20291),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 20320),
#  ('PsychedeliaLoop-Exit', 20351),
#  ('PsychedeliaLoop-Enter', 20354),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 20360),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 20389),
#  ('PsychedeliaLoop-Exit', 20420),
#  ('PsychedeliaLoop-Enter', 20423),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 20429),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 20458),
#  ('PsychedeliaLoop-Exit', 20489),
#  ('PsychedeliaLoop-Enter', 20492),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 20498),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 20527),
#  ('PsychedeliaLoop-Exit', 20558),
#  ('PsychedeliaLoop-Enter', 20561),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 20567),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 20596),
#  ('PsychedeliaLoop-Exit', 20627),
#  ('PsychedeliaLoop-Enter', 20630),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 20636),
#  ('MaybeUpdateFromBuffersAndPaint-Exit', 20665),
#  ('PsychedeliaLoop-Exit', 20696),
#  ('PsychedeliaLoop-Enter', 20699),
#  ('MaybeUpdateFromBuffersAndPaint-Enter', 20705),
#  ...]

# %%
import math as m
from PIL import Image, ImageDraw,ImageFont

levels = [
    ("PsychedeliaLoop-", "pink", 0),
    ("MaybeUpdateFromBuffersAndPaint-", "blue", 20),
    ("PaintStructureAtCurrentPosition-", "green", 40),
    ("PaintPixelForCurrentSymmetry-", "yellow", 60),
    ("PaintPixel-", "red", 80),
]

trunc_trace = trace
width = max([pc for _,pc in trunc_trace])
height = max([y for _,_,y in levels])+20
image = Image.new('RGBA', (width, height))
draw = ImageDraw.Draw(image)

for l,color,y in levels:
    bpc=0
    for s,pc in trunc_trace:
        if l not in s:
            continue
        if "Exit" in s:
            draw.rectangle((bpc, y, pc, y+20), fill=color, outline=(0,0,0))
        bpc = pc

pixels = image.load()
width, height = image.size

font_name = "/home/robert/.local/lib/python3.10/site-packages/jupyterthemes/fonts/monospace/roboto/roboto.ttf"
font = ImageFont.truetype(font_name, 26)

im = drawCycleDiagram(pixels, width, height)
img = show_im(im)
draw = ImageDraw.Draw(img)

x=670
y=870
bw = 200
bh = 20
for l,color,_ in levels:
    draw.rectangle((x,y,x+bw,y+bh), fill=color, outline=(0,0,0))
    draw.text((x+bw+20, y-5),l[:-1],(0,0,0),font=font)
    y+=50
img
# Out:
# <PIL.Image.Image image mode=RGBA size=2000x2000 at 0x72CC182AFDF0>
