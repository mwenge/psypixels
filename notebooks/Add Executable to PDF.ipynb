# %% [markdown]
# # Embed an executable in the final PDF

# %% [markdown]
# For now it's just a 'hello world' but hopefully I can get an executable with the C64 edition of Psychedelia embedded in the PDF. That way you can both read the PDF and also use it run and play the game like so:
#
# ```bash
# ./psychedelia_syndrome_exe.pdf
# ```

# %% [markdown]
# Download libcosmo to create an `ape` executable:

# %%
import os
# !mkdir -p cosmocc
os.chdir('cosmocc')
# !wget https://cosmo.zip/pub/cosmocc/cosmocc.zip
# !unzip cosmocc.zip
os.chdir('..')
# Out:
# --2024-06-03 10:30:43--  https://cosmo.zip/pub/cosmocc/cosmocc.zip
# Resolving cosmo.zip (cosmo.zip)... 34.136.86.162
# Connecting to cosmo.zip (cosmo.zip)|34.136.86.162|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 187344708 (179M) [application/zip]
# Saving to: ‘cosmocc.zip’
#
# cosmocc.zip         100%[===================>] 178.67M  6.01MB/s    in 32s
#
# 2024-06-03 10:31:16 (5.54 MB/s) - ‘cosmocc.zip’ saved [187344708/187344708]
#
# Archive:  cosmocc.zip
#    creating: bin/
#   inflating: bin/ape-x86_64.elf
#     linking: bin/x86_64-unknown-cosmo-c++filt  -> x86_64-linux-cosmo-c++filt
#     linking: bin/aarch64-unknown-cosmo-objdump  -> aarch64-linux-cosmo-objdump
#     linking: bin/x86_64-unknown-cosmo-cc  -> cosmocross
#   inflating: bin/x86_64-linux-cosmo-readelf
#   inflating: bin/ape-m1.c
#   inflating: bin/aarch64-linux-cosmo-objdump
#   inflating: bin/apelink
#     linking: bin/aarch64-linux-cosmo-cpp  -> aarch64-linux-cosmo-gcc
#   inflating: bin/x86_64-linux-cosmo-ar
#     linking: bin/x86_64-linux-cosmo-cpp  -> x86_64-linux-cosmo-gcc
#   inflating: bin/aarch64-linux-cosmo-objcopy
#   inflating: bin/mktemper
#   inflating: bin/x86_64-linux-cosmo-c++filt
#     linking: bin/aarch64-linux-cosmo-as  -> ../libexec/gcc/aarch64-linux-cosmo/12.3.0/as
#   inflating: bin/zipobj
#   inflating: bin/x86_64-linux-cosmo-addr2line
#   inflating: bin/aarch64-linux-cosmo-addr2line
#   inflating: bin/make
#     linking: bin/aarch64-unknown-cosmo-as  -> aarch64-linux-cosmo-as
#   inflating: bin/aarch64-linux-cosmo-nm
#   inflating: bin/ape-x86_64.macho
#     linking: bin/aarch64-unknown-cosmo-readelf  -> aarch64-linux-cosmo-readelf
#   inflating: bin/aarch64-linux-cosmo-g++
#   inflating: bin/cosmocross
#     linking: bin/aarch64-unknown-cosmo-cc  -> cosmocross
#     linking: bin/unknown-unknown-cosmo-cc  -> cosmocc
#     linking: bin/x86_64-unknown-cosmo-as  -> x86_64-linux-cosmo-as
#     linking: bin/x86_64-linux-cosmo-ld.bfd  -> ../libexec/gcc/x86_64-linux-cosmo/12.3.0/ld.bfd
#   inflating: bin/mkdeps
#   inflating: bin/fixupobj
#   inflating: bin/cosmoar
#   inflating: bin/x86_64-linux-cosmo-elfedit
#   inflating: bin/x86_64-linux-cosmo-g++
#   inflating: bin/aarch64-linux-cosmo-size
#     linking: bin/aarch64-linux-cosmo-c++  -> aarch64-linux-cosmo-g++
#   inflating: bin/ctags
#     linking: bin/unknown-unknown-cosmo-ar  -> cosmoar
#   inflating: bin/assimilate
#     linking: bin/x86_64-unknown-cosmo-readelf  -> x86_64-linux-cosmo-readelf
#     linking: bin/x86_64-unknown-cosmo-objcopy  -> x86_64-linux-cosmo-objcopy
#     linking: bin/x86_64-linux-cosmo-cc  -> x86_64-linux-cosmo-gcc
#   inflating: bin/x86_64-linux-cosmo-strip
#     linking: bin/x86_64-unknown-cosmo-objdump  -> x86_64-linux-cosmo-objdump
#   inflating: bin/aarch64-linux-cosmo-elfedit
#   inflating: bin/pecheck
#   inflating: bin/x86_64-linux-cosmo-nm
#   inflating: bin/x86_64-linux-cosmo-size
#   inflating: bin/x86_64-unknown-cosmo-install
#   inflating: bin/aarch64-linux-cosmo-ranlib
#     linking: bin/aarch64-unknown-cosmo-objcopy  -> aarch64-linux-cosmo-objcopy
#     linking: bin/x86_64-linux-cosmo-c++  -> x86_64-linux-cosmo-g++
#     linking: bin/aarch64-linux-cosmo-cc  -> aarch64-linux-cosmo-gcc
#   inflating: bin/aarch64-linux-cosmo-c++filt
#     linking: bin/aarch64-linux-cosmo-ld.bfd  -> ../libexec/gcc/aarch64-linux-cosmo/12.3.0/ld.bfd
#   inflating: bin/cosmoaddr2line
#     linking: bin/aarch64-unknown-cosmo-c++  -> cosmocross
#   inflating: bin/x86_64-linux-cosmo-objcopy
#     linking: bin/aarch64-unknown-cosmo-nm  -> aarch64-linux-cosmo-nm
#     linking: bin/cosmoc++            -> cosmocc
#   inflating: bin/ape-aarch64.elf
#     linking: bin/aarch64-unknown-cosmo-strip  -> aarch64-linux-cosmo-strip
#     linking: bin/x86_64-unknown-cosmo-ar  -> x86_64-linux-cosmo-ar
#     linking: bin/x86_64-linux-cosmo-as  -> ../libexec/gcc/x86_64-linux-cosmo/12.3.0/as
#     linking: bin/x86_64-unknown-cosmo-addr2line  -> x86_64-linux-cosmo-addr2line
#   inflating: bin/aarch64-linux-cosmo-ar
#     linking: bin/x86_64-unknown-cosmo-nm  -> x86_64-linux-cosmo-nm
#     linking: bin/unknown-unknown-cosmo-install  -> cosmoinstall
#   inflating: bin/aarch64-unknown-cosmo-install
#     linking: bin/x86_64-linux-cosmo-ld  -> ../libexec/gcc/x86_64-linux-cosmo/12.3.0/ld.bfd
#   inflating: bin/x86_64-linux-cosmo-objdump
#     linking: bin/unknown-unknown-cosmo-c++  -> cosmocc
#     linking: bin/aarch64-unknown-cosmo-c++filt  -> aarch64-linux-cosmo-c++filt
#   inflating: bin/cosmoinstall
#     linking: bin/x86_64-unknown-cosmo-c++  -> cosmocross
#   inflating: bin/x86_64-linux-cosmo-ranlib
#   inflating: bin/aarch64-linux-cosmo-strip
#   inflating: bin/aarch64-linux-cosmo-readelf
#   inflating: bin/x86_64-linux-cosmo-gcc
#     linking: bin/aarch64-linux-cosmo-ld  -> ../libexec/gcc/aarch64-linux-cosmo/12.3.0/ld.bfd
#   inflating: bin/cosmocc
#     linking: bin/aarch64-unknown-cosmo-ar  -> aarch64-linux-cosmo-ar
#     linking: bin/aarch64-unknown-cosmo-addr2line  -> aarch64-linux-cosmo-addr2line
#   inflating: bin/zipcopy
#   inflating: bin/aarch64-linux-cosmo-gcc
#   inflating: bin/march-native
#     linking: bin/x86_64-unknown-cosmo-strip  -> x86_64-linux-cosmo-strip
#    creating: x86_64-linux-cosmo/
#    creating: x86_64-linux-cosmo/lib/
#  extracting: x86_64-linux-cosmo/lib/libm.a
#   inflating: x86_64-linux-cosmo/lib/libcosmo.a
#   inflating: x86_64-linux-cosmo/lib/ape.lds
#  extracting: x86_64-linux-cosmo/lib/libdl.a
#  extracting: x86_64-linux-cosmo/lib/libc.a
#   inflating: x86_64-linux-cosmo/lib/crt.o
#  extracting: x86_64-linux-cosmo/lib/libunwind.a
#   inflating: x86_64-linux-cosmo/lib/ape-no-modify-self.o
#   inflating: x86_64-linux-cosmo/lib/libcxx.a
#  extracting: x86_64-linux-cosmo/lib/libpthread.a
#  extracting: x86_64-linux-cosmo/lib/libcrypt.a
#  extracting: x86_64-linux-cosmo/lib/librt.a
#  extracting: x86_64-linux-cosmo/lib/libstdc++.a
#  extracting: x86_64-linux-cosmo/lib/libgomp.a
#  extracting: x86_64-linux-cosmo/lib/libgcc_s.a
#   inflating: x86_64-linux-cosmo/lib/ape.o
#  extracting: x86_64-linux-cosmo/lib/libresolv.a
#    creating: libexec/
#    creating: libexec/gcc/
#    creating: libexec/gcc/x86_64-linux-cosmo/
#    creating: libexec/gcc/x86_64-linux-cosmo/12.3.0/
#   inflating: libexec/gcc/x86_64-linux-cosmo/12.3.0/cc1
#   inflating: libexec/gcc/x86_64-linux-cosmo/12.3.0/as
#     linking: libexec/gcc/x86_64-linux-cosmo/12.3.0/ld  -> ld.bfd
#   inflating: libexec/gcc/x86_64-linux-cosmo/12.3.0/cc1plus
#    creating: libexec/gcc/x86_64-linux-cosmo/12.3.0/install-tools/
#   inflating: libexec/gcc/x86_64-linux-cosmo/12.3.0/ld.bfd
#   inflating: libexec/gcc/x86_64-linux-cosmo/12.3.0/collect2
#    creating: libexec/gcc/aarch64-linux-cosmo/
#    creating: libexec/gcc/aarch64-linux-cosmo/12.3.0/
#   inflating: libexec/gcc/aarch64-linux-cosmo/12.3.0/cc1
#   inflating: libexec/gcc/aarch64-linux-cosmo/12.3.0/as
#     linking: libexec/gcc/aarch64-linux-cosmo/12.3.0/ld  -> ld.bfd
#   inflating: libexec/gcc/aarch64-linux-cosmo/12.3.0/cc1plus
#    creating: libexec/gcc/aarch64-linux-cosmo/12.3.0/install-tools/
#   inflating: libexec/gcc/aarch64-linux-cosmo/12.3.0/ld.bfd
#   inflating: libexec/gcc/aarch64-linux-cosmo/12.3.0/collect2
#    creating: include/
#   inflating: include/nsync_once.h
#   inflating: include/netdb.h
#   inflating: include/uchar.h
#   inflating: include/search.h
#   inflating: include/shared_mutex
#   inflating: include/spawn.h
#   inflating: include/ucontext.h
#   inflating: include/alloca.h
#   inflating: include/type_traits
#   inflating: include/nsync_debug.h
#   inflating: include/version
#   inflating: include/clocale
#   inflating: include/cxxabi.h
#   inflating: include/cinttypes
#   inflating: include/typeinfo
#   inflating: include/regex
#   inflating: include/chrono
#   inflating: include/cstdlib
#   inflating: include/fcntl.h
#   inflating: include/smmintrin.h
#   inflating: include/deque
#   inflating: include/stdckdint.h
#   inflating: include/string.h
#    creating: include/ape/
#   inflating: include/ape/sections.internal.h
#   inflating: include/ape/ape.internal.h
#   inflating: include/ape/macros.internal.h
#   inflating: include/ape/ape.h
#   inflating: include/ape/relocations.h
#  extracting: include/ape/notice.inc
#   inflating: include/ape/idata.internal.h
#   inflating: include/syscall.h
#   inflating: include/stdbool.h
#   inflating: include/bitset
#   inflating: include/limits.h
#   inflating: include/stdio_ext.h
#   inflating: include/inttypes.h
#   inflating: include/ccomplex
#   inflating: include/locale.h
#    creating: include/libc/
#   inflating: include/libc/atomic.h
#    creating: include/libc/vga/
#   inflating: include/libc/vga/vga.internal.h
#   inflating: include/libc/vga/tty-graph.inc
#   inflating: include/libc/cxxabi.h
#   inflating: include/libc/macho.internal.h
#    creating: include/libc/dlopen/
#   inflating: include/libc/dlopen/dlfcn.h
#   inflating: include/libc/stdckdint.h
#    creating: include/libc/proc/
#   inflating: include/libc/proc/describefds.internal.h
#   inflating: include/libc/proc/execve.internal.h
#   inflating: include/libc/proc/posix_spawn.internal.h
#   inflating: include/libc/proc/posix_spawn.h
#   inflating: include/libc/proc/proc.internal.h
#   inflating: include/libc/proc/ntspawn.h
#   inflating: include/libc/stdbool.h
#   inflating: include/libc/lp64arg.inc
#   inflating: include/libc/limits.h
#   inflating: include/libc/inttypes.h
#   inflating: include/libc/macros.internal.h
#    creating: include/libc/sysv/
#   inflating: include/libc/sysv/macros.internal.h
#    creating: include/libc/sysv/consts/
#   inflating: include/libc/sysv/consts/ex.h
#   inflating: include/libc/sysv/consts/sock.h
#   inflating: include/libc/sysv/consts/prot.h
#   inflating: include/libc/sysv/consts/fan.h
#   inflating: include/libc/sysv/consts/futex.h
#   inflating: include/libc/sysv/consts/so.h
#   inflating: include/libc/sysv/consts/seek.h
#   inflating: include/libc/sysv/consts/io.h
#   inflating: include/libc/sysv/consts/st.h
#   inflating: include/libc/sysv/consts/reboot.h
#   inflating: include/libc/sysv/consts/posix.h
#   inflating: include/libc/sysv/consts/timer.h
#   inflating: include/libc/sysv/consts/l.h
#   inflating: include/libc/sysv/consts/audit.h
#   inflating: include/libc/sysv/consts/lio.h
#   inflating: include/libc/sysv/consts/mremap.h
#   inflating: include/libc/sysv/consts/pf.h
#   inflating: include/libc/sysv/consts/sf.h
#   inflating: include/libc/sysv/consts/fs.h
#   inflating: include/libc/sysv/consts/mlock.h
#   inflating: include/libc/sysv/consts/limits.h
#   inflating: include/libc/sysv/consts/kern.h
#   inflating: include/libc/sysv/consts/rlim.h
#   inflating: include/libc/sysv/consts/shm.h
#   inflating: include/libc/sysv/consts/madv.h
#   inflating: include/libc/sysv/consts/s.h
#   inflating: include/libc/sysv/consts/ipv6.h
#   inflating: include/libc/sysv/consts/prio.h
#   inflating: include/libc/sysv/consts/inet6.h
#   inflating: include/libc/sysv/consts/close.h
#   inflating: include/libc/sysv/consts/baud.internal.h
#   inflating: include/libc/sysv/consts/fbio.h
#   inflating: include/libc/sysv/consts/read.h
#   inflating: include/libc/sysv/consts/arp.h
#   inflating: include/libc/sysv/consts/map.h
#   inflating: include/libc/sysv/consts/c.h
#   inflating: include/libc/sysv/consts/epoll.h
#   inflating: include/libc/sysv/consts/fd.h
#   inflating: include/libc/sysv/consts/ok.h
#   inflating: include/libc/sysv/consts/ioprio.h
#   inflating: include/libc/sysv/consts/loglevel.h
#   inflating: include/libc/sysv/consts/utime.h
#   inflating: include/libc/sysv/consts/dt.h
#   inflating: include/libc/sysv/consts/pr.h
#   inflating: include/libc/sysv/consts/o.h
#   inflating: include/libc/sysv/consts/poll.h
#   inflating: include/libc/sysv/consts/ip.h
#   inflating: include/libc/sysv/consts/dn.h
#   inflating: include/libc/sysv/consts/nrlinux.h
#   inflating: include/libc/sysv/consts/at.h
#   inflating: include/libc/sysv/consts/itimer.h
#   inflating: include/libc/sysv/consts/clock.h
#   inflating: include/libc/sysv/consts/msg.h
#   inflating: include/libc/sysv/consts/in.h
#   inflating: include/libc/sysv/consts/ptrace.h
#   inflating: include/libc/sysv/consts/clone.h
#   inflating: include/libc/sysv/consts/sicode.h
#   inflating: include/libc/sysv/consts/lock.h
#   inflating: include/libc/sysv/consts/shut.h
#   inflating: include/libc/sysv/consts/fio.h
#   inflating: include/libc/sysv/consts/cap.h
#   inflating: include/libc/sysv/consts/fileno.h
#   inflating: include/libc/sysv/consts/ipproto.h
#   inflating: include/libc/sysv/consts/splice.h
#   inflating: include/libc/sysv/consts/f.h
#   inflating: include/libc/sysv/consts/falloc.h
#   inflating: include/libc/sysv/consts/ethernet.h
#   inflating: include/libc/sysv/consts/auxv.h
#   inflating: include/libc/sysv/consts/mount.h
#   inflating: include/libc/sysv/consts/syscon.internal.h
#   inflating: include/libc/sysv/consts/log.h
#   inflating: include/libc/sysv/consts/kd.h
#   inflating: include/libc/sysv/consts/xopen.h
#   inflating: include/libc/sysv/consts/inaddr.h
#   inflating: include/libc/sysv/consts/personality.h
#   inflating: include/libc/sysv/consts/grnd.h
#   inflating: include/libc/sysv/consts/rusage.h
#   inflating: include/libc/sysv/consts/rlimit.h
#   inflating: include/libc/sysv/consts/iov.h
#   inflating: include/libc/sysv/consts/exit.h
#   inflating: include/libc/sysv/consts/tcpopt.h
#   inflating: include/libc/sysv/consts/mfd.h
#   inflating: include/libc/sysv/consts/tcp.h
#   inflating: include/libc/sysv/consts/mcast.h
#   inflating: include/libc/sysv/consts/sched.h
#   inflating: include/libc/sysv/consts/sio.h
#   inflating: include/libc/sysv/consts/msync.h
#   inflating: include/libc/sysv/consts/unmount.h
#   inflating: include/libc/sysv/consts/uc.h
#   inflating: include/libc/sysv/consts/sa.h
#   inflating: include/libc/sysv/consts/ss.h
#   inflating: include/libc/sysv/consts/scm.h
#   inflating: include/libc/sysv/consts/pty.h
#   inflating: include/libc/sysv/consts/af.h
#   inflating: include/libc/sysv/consts/_posix.h
#   inflating: include/libc/sysv/consts/th.h
#   inflating: include/libc/sysv/consts/modem.h
#   inflating: include/libc/sysv/consts/pt.h
#   inflating: include/libc/sysv/consts/endian.h
#   inflating: include/libc/sysv/consts/sig.h
#   inflating: include/libc/sysv/consts/waitid.h
#   inflating: include/libc/sysv/consts/icmp6.h
#   inflating: include/libc/sysv/consts/w.h
#   inflating: include/libc/sysv/consts/nr.h
#   inflating: include/libc/sysv/consts/hwcap.h
#   inflating: include/libc/sysv/consts/arch.h
#   inflating: include/libc/sysv/consts/iff.h
#   inflating: include/libc/sysv/consts/ipport.h
#   inflating: include/libc/sysv/consts/sol.h
#   inflating: include/libc/sysv/consts/termios.h
#   inflating: include/libc/sysv/errfuns.h
#   inflating: include/libc/iso646.internal.h
#   inflating: include/libc/stdalign.internal.h
#   inflating: include/libc/zip.internal.h
#    creating: include/libc/log/
#   inflating: include/libc/log/color.internal.h
#   inflating: include/libc/log/gdb.h
#   inflating: include/libc/log/internal.h
#   inflating: include/libc/log/backtrace.internal.h
#   inflating: include/libc/log/rop.internal.h
#   inflating: include/libc/log/libfatal.internal.h
#   inflating: include/libc/log/bsd.h
#   inflating: include/libc/log/log.h
#   inflating: include/libc/log/traceme.h
#   inflating: include/libc/log/check.h
#   inflating: include/libc/log/countexpr.h
#   inflating: include/libc/log/countbranch.h
#   inflating: include/libc/log/appendresourcereport.internal.h
#   inflating: include/libc/log/getcallername.internal.h
#   inflating: include/libc/temp.h
#   inflating: include/libc/mach.internal.h
#   inflating: include/libc/cxx.inc
#   inflating: include/libc/imag.internal.h
#   inflating: include/libc/unistd.h
#   inflating: include/libc/dos.internal.h
#   inflating: include/libc/complex.h
#    creating: include/libc/thread/
#   inflating: include/libc/thread/xnu.internal.h
#   inflating: include/libc/thread/freebsd.internal.h
#   inflating: include/libc/thread/openbsd.internal.h
#   inflating: include/libc/thread/semaphore.h
#   inflating: include/libc/thread/thread.h
#   inflating: include/libc/thread/posixthread.internal.h
#   inflating: include/libc/thread/threads.h
#   inflating: include/libc/thread/tls2.internal.h
#   inflating: include/libc/thread/thread2.h
#   inflating: include/libc/thread/itimer.internal.h
#   inflating: include/libc/thread/pt.internal.h
#   inflating: include/libc/thread/tls.h
#   inflating: include/libc/llp64.inc
#   inflating: include/libc/cosmo.h
#   inflating: include/libc/utime.h
#    creating: include/libc/elf/
#   inflating: include/libc/elf/tinyelf.internal.h
#    creating: include/libc/elf/struct/
#   inflating: include/libc/elf/struct/rel.h
#   inflating: include/libc/elf/struct/dyn.h
#   inflating: include/libc/elf/struct/verdaux.h
#   inflating: include/libc/elf/struct/verdef.h
#   inflating: include/libc/elf/struct/ehdr.h
#   inflating: include/libc/elf/struct/nhdr.h
#   inflating: include/libc/elf/struct/move.h
#   inflating: include/libc/elf/struct/sym.h
#   inflating: include/libc/elf/struct/vernaux.h
#   inflating: include/libc/elf/struct/auxv.h
#   inflating: include/libc/elf/struct/phdr.h
#   inflating: include/libc/elf/struct/chdr.h
#   inflating: include/libc/elf/struct/syminfo.h
#   inflating: include/libc/elf/struct/rela.h
#   inflating: include/libc/elf/struct/shdr.h
#   inflating: include/libc/elf/struct/lib.h
#   inflating: include/libc/elf/struct/verneed.h
#   inflating: include/libc/elf/elf.h
#   inflating: include/libc/elf/def.h
#   inflating: include/libc/elf/scalar.h
#   inflating: include/libc/elf/pf2prot.internal.h
#   inflating: include/libc/elf/link.h
#   inflating: include/libc/lp64.inc
#    creating: include/libc/calls/
#   inflating: include/libc/calls/cp.internal.h
#   inflating: include/libc/calls/ucontext.h
#   inflating: include/libc/calls/sched-sysv.internal.h
#   inflating: include/libc/calls/sigtimedwait.internal.h
#   inflating: include/libc/calls/calls.h
#   inflating: include/libc/calls/sigtimedwait.h
#   inflating: include/libc/calls/openbsd.internal.h
#   inflating: include/libc/calls/pledge.h
#    creating: include/libc/calls/typedef/
#   inflating: include/libc/calls/typedef/u.h
#   inflating: include/libc/calls/syscall-nt.internal.h
#   inflating: include/libc/calls/wincrash.internal.h
#   inflating: include/libc/calls/makedev.h
#   inflating: include/libc/calls/weirdtypes.h
#   inflating: include/libc/calls/internal.h
#   inflating: include/libc/calls/groups.internal.h
#   inflating: include/libc/calls/syscall_support-nt.internal.h
#   inflating: include/libc/calls/blockcancel.internal.h
#   inflating: include/libc/calls/state.internal.h
#   inflating: include/libc/calls/pledge.internal.h
#   inflating: include/libc/calls/sysdir.internal.h
#   inflating: include/libc/calls/getcontext.inc
#   inflating: include/libc/calls/asan.internal.h
#   inflating: include/libc/calls/syscall_support-sysv.internal.h
#   inflating: include/libc/calls/cachestat.h
#   inflating: include/libc/calls/termios.internal.h
#    creating: include/libc/calls/struct/
#   inflating: include/libc/calls/struct/utsname.h
#   inflating: include/libc/calls/struct/sigval.h
#   inflating: include/libc/calls/struct/stat.h
#   inflating: include/libc/calls/struct/sysinfo.internal.h
#   inflating: include/libc/calls/struct/iovec.internal.h
#   inflating: include/libc/calls/struct/statfs-xnu.internal.h
#   inflating: include/libc/calls/struct/framebufferfixedscreeninfo.h
#   inflating: include/libc/calls/struct/tms.h
#   inflating: include/libc/calls/struct/iovec.h
#   inflating: include/libc/calls/struct/sigval.internal.h
#   inflating: include/libc/calls/struct/flock.internal.h
#   inflating: include/libc/calls/struct/flock.h
#   inflating: include/libc/calls/struct/sigaltstack.h
#   inflating: include/libc/calls/struct/dirent.h
#   inflating: include/libc/calls/struct/winsize.h
#   inflating: include/libc/calls/struct/timespec.h
#   inflating: include/libc/calls/struct/sched_param.internal.h
#   inflating: include/libc/calls/struct/cpuset.h
#   inflating: include/libc/calls/struct/siginfo-xnu.internal.h
#   inflating: include/libc/calls/struct/utsname-linux.internal.h
#   inflating: include/libc/calls/struct/sigaction.internal.h
#   inflating: include/libc/calls/struct/ucontext-netbsd.internal.h
#   inflating: include/libc/calls/struct/metatermios.internal.h
#   inflating: include/libc/calls/struct/filter.internal.h
#   inflating: include/libc/calls/struct/aarch64.internal.h
#   inflating: include/libc/calls/struct/sigset.internal.h
#   inflating: include/libc/calls/struct/siginfo-meta.internal.h
#   inflating: include/libc/calls/struct/statfs-freebsd.internal.h
#   inflating: include/libc/calls/struct/stat.internal.h
#   inflating: include/libc/calls/struct/framebuffervirtualscreeninfo.h
#   inflating: include/libc/calls/struct/ucontext-openbsd.internal.h
#   inflating: include/libc/calls/struct/fd.internal.h
#   inflating: include/libc/calls/struct/ucontext-freebsd.internal.h
#   inflating: include/libc/calls/struct/statfs-linux.internal.h
#   inflating: include/libc/calls/struct/statfs-openbsd.internal.h
#   inflating: include/libc/calls/struct/bpf.internal.h
#   inflating: include/libc/calls/struct/termios.internal.h
#   inflating: include/libc/calls/struct/ucontext.internal.h
#   inflating: include/libc/calls/struct/siginfo-openbsd.internal.h
#   inflating: include/libc/calls/struct/siginfo.h
#   inflating: include/libc/calls/struct/rlimit.internal.h
#   inflating: include/libc/calls/struct/rusage.internal.h
#   inflating: include/libc/calls/struct/siginfo.internal.h
#   inflating: include/libc/calls/struct/winsize.internal.h
#   inflating: include/libc/calls/struct/siginfo-freebsd.internal.h
#   inflating: include/libc/calls/struct/user_regs_struct.h
#   inflating: include/libc/calls/struct/rusage.h
#   inflating: include/libc/calls/struct/statvfs.h
#   inflating: include/libc/calls/struct/rlimit.h
#   inflating: include/libc/calls/struct/timespec.internal.h
#   inflating: include/libc/calls/struct/siginfo-netbsd.internal.h
#   inflating: include/libc/calls/struct/statfs.h
#   inflating: include/libc/calls/struct/itimerval.h
#   inflating: include/libc/calls/struct/sched_param.h
#   inflating: include/libc/calls/struct/statfs-netbsd.internal.h
#   inflating: include/libc/calls/struct/stat.macros.h
#   inflating: include/libc/calls/struct/statfs-meta.internal.h
#   inflating: include/libc/calls/struct/sigaction.h
#   inflating: include/libc/calls/struct/seccomp.internal.h
#   inflating: include/libc/calls/struct/itimerval.internal.h
#   inflating: include/libc/calls/struct/framebuffercolormap.h
#   inflating: include/libc/calls/struct/metastat.internal.h
#   inflating: include/libc/calls/struct/sigset.h
#   inflating: include/libc/calls/struct/sigaltstack.internal.h
#   inflating: include/libc/calls/struct/metasigaltstack.h
#   inflating: include/libc/calls/struct/sysinfo.h
#   inflating: include/libc/calls/struct/fsid.h
#   inflating: include/libc/calls/struct/timeval.h
#   inflating: include/libc/calls/struct/timeval.internal.h
#   inflating: include/libc/calls/struct/termios.h
#   inflating: include/libc/calls/struct/statfs.internal.h
#   inflating: include/libc/calls/syscall-sysv.internal.h
#   inflating: include/libc/calls/mount.h
#   inflating: include/libc/calls/ttydefaults.h
#   inflating: include/libc/calls/createfileflags.internal.h
#   inflating: include/libc/calls/ipc.h
#   inflating: include/libc/calls/metalfile.internal.h
#   inflating: include/libc/calls/landlock.h
#   inflating: include/libc/calls/prctl.internal.h
#   inflating: include/libc/calls/termios.h
#   inflating: include/libc/calls/sig.internal.h
#   inflating: include/libc/stdlib.h
#    creating: include/libc/tinymath/
#   inflating: include/libc/tinymath/freebsd.internal.h
#   inflating: include/libc/tinymath/invtrigl.internal.h
#   inflating: include/libc/tinymath/expo.internal.h
#   inflating: include/libc/tinymath/hornerf.internal.h
#   inflating: include/libc/tinymath/estrin_wrap.internal.h
#   inflating: include/libc/tinymath/complex.internal.h
#   inflating: include/libc/tinymath/internal.h
#   inflating: include/libc/tinymath/magicu.h
#   inflating: include/libc/tinymath/feval.internal.h
#   inflating: include/libc/tinymath/emod.h
#   inflating: include/libc/tinymath/sincosf.internal.h
#   inflating: include/libc/tinymath/ldshape.internal.h
#   inflating: include/libc/tinymath/arm.internal.h
#   inflating: include/libc/tinymath/horner_wrap.internal.h
#   inflating: include/libc/tinymath/horner.internal.h
#   inflating: include/libc/tinymath/emodl.h
#   inflating: include/libc/tinymath/kernel.internal.h
#    creating: include/libc/nexgen32e/
#   inflating: include/libc/nexgen32e/kompressor.h
#   inflating: include/libc/nexgen32e/crc32.h
#   inflating: include/libc/nexgen32e/rdtsc.h
#   inflating: include/libc/nexgen32e/uart.internal.h
#   inflating: include/libc/nexgen32e/kcpuids.h
#   inflating: include/libc/nexgen32e/trampoline.h
#   inflating: include/libc/nexgen32e/nt2sysv.h
#   inflating: include/libc/nexgen32e/x86compiler.h
#   inflating: include/libc/nexgen32e/vendor.internal.h
#   inflating: include/libc/nexgen32e/bench.h
#   inflating: include/libc/nexgen32e/sha.h
#   inflating: include/libc/nexgen32e/ffs.h
#   inflating: include/libc/nexgen32e/hascharacter.internal.h
#   inflating: include/libc/nexgen32e/lz4.h
#   inflating: include/libc/nexgen32e/nexgen32e.h
#   inflating: include/libc/nexgen32e/x86info.h
#   inflating: include/libc/nexgen32e/gc.internal.h
#   inflating: include/libc/nexgen32e/stackframe.h
#   inflating: include/libc/nexgen32e/msr.internal.h
#   inflating: include/libc/nexgen32e/rdtscp.h
#   inflating: include/libc/nexgen32e/cachesize.h
#   inflating: include/libc/nexgen32e/x86feature.h
#   inflating: include/libc/nexgen32e/cpuid4.internal.h
#   inflating: include/libc/ar.h
#   inflating: include/libc/c.inc
#   inflating: include/libc/paths.h
#   inflating: include/libc/assert.h
#   inflating: include/libc/normalize.inc
#    creating: include/libc/sock/
#   inflating: include/libc/sock/sock.h
#   inflating: include/libc/sock/yoink.inc
#   inflating: include/libc/sock/ifaddrs.h
#   inflating: include/libc/sock/wsaid.internal.h
#   inflating: include/libc/sock/ipclassify.internal.h
#   inflating: include/libc/sock/select.internal.h
#   inflating: include/libc/sock/syslog.h
#   inflating: include/libc/sock/epoll.h
#   inflating: include/libc/sock/internal.h
#   inflating: include/libc/sock/alg.h
#   inflating: include/libc/sock/in.h
#    creating: include/libc/sock/struct/
#   inflating: include/libc/sock/struct/sockaddr6-bsd.internal.h
#   inflating: include/libc/sock/struct/arpreq.h
#   inflating: include/libc/sock/struct/cmsghdr.h
#   inflating: include/libc/sock/struct/cmsghdr.internal.h
#   inflating: include/libc/sock/struct/in6_pktinfo.h
#   inflating: include/libc/sock/struct/in_pktinfo.h
#   inflating: include/libc/sock/struct/msghdr.internal.h
#   inflating: include/libc/sock/struct/sockaddr6.h
#   inflating: include/libc/sock/struct/sockaddr.h
#   inflating: include/libc/sock/struct/ifconf.h
#   inflating: include/libc/sock/struct/ipv6_mreq.h
#   inflating: include/libc/sock/struct/ether_header.h
#   inflating: include/libc/sock/struct/linger.h
#   inflating: include/libc/sock/struct/ifreq.h
#   inflating: include/libc/sock/struct/sockaddr.internal.h
#   inflating: include/libc/sock/struct/pollfd.h
#   inflating: include/libc/sock/struct/pollfd.internal.h
#   inflating: include/libc/sock/struct/msghdr.h
#   inflating: include/libc/sock/struct/arphdr.h
#   inflating: include/libc/sock/struct/ip_mreq.h
#   inflating: include/libc/sock/sendfile.internal.h
#   inflating: include/libc/sock/goodsocket.internal.h
#   inflating: include/libc/sock/syscall_fd.internal.h
#   inflating: include/libc/sock/select.h
#    creating: include/libc/runtime/
#   inflating: include/libc/runtime/e820.internal.h
#   inflating: include/libc/runtime/metalprintf.internal.h
#   inflating: include/libc/runtime/symbols.internal.h
#   inflating: include/libc/runtime/runtime.h
#   inflating: include/libc/runtime/pc.internal.h
#   inflating: include/libc/runtime/internal.h
#   inflating: include/libc/runtime/mman.internal.h
#   inflating: include/libc/runtime/winargs.internal.h
#   inflating: include/libc/runtime/stack.h
#   inflating: include/libc/runtime/utmpx.h
#   inflating: include/libc/runtime/sysconf.h
#   inflating: include/libc/runtime/zipos.internal.h
#   inflating: include/libc/runtime/clktck.h
#   inflating: include/libc/runtime/memtrack.internal.h
#   inflating: include/libc/runtime/utmp.h
#   inflating: include/libc/runtime/pathconf.h
#   inflating: include/libc/runtime/syslib.internal.h
#   inflating: include/libc/runtime/fenv.h
#   inflating: include/libc/type2str.h
#    creating: include/libc/isystem/
#   inflating: include/libc/isystem/nsync_once.h
#   inflating: include/libc/isystem/netdb.h
#   inflating: include/libc/isystem/uchar.h
#   inflating: include/libc/isystem/search.h
#   inflating: include/libc/isystem/shared_mutex
#   inflating: include/libc/isystem/spawn.h
#   inflating: include/libc/isystem/ucontext.h
#   inflating: include/libc/isystem/alloca.h
#   inflating: include/libc/isystem/type_traits
#   inflating: include/libc/isystem/nsync_debug.h
#   inflating: include/libc/isystem/version
#   inflating: include/libc/isystem/clocale
#   inflating: include/libc/isystem/cxxabi.h
#   inflating: include/libc/isystem/cinttypes
#   inflating: include/libc/isystem/typeinfo
#   inflating: include/libc/isystem/regex
#   inflating: include/libc/isystem/chrono
#   inflating: include/libc/isystem/cstdlib
#   inflating: include/libc/isystem/fcntl.h
#   inflating: include/libc/isystem/smmintrin.h
#   inflating: include/libc/isystem/deque
#   inflating: include/libc/isystem/stdckdint.h
#   inflating: include/libc/isystem/string.h
#   inflating: include/libc/isystem/stdbool.h
#   inflating: include/libc/isystem/bitset
#   inflating: include/libc/isystem/limits.h
#   inflating: include/libc/isystem/stdio_ext.h
#   inflating: include/libc/isystem/inttypes.h
#   inflating: include/libc/isystem/ccomplex
#   inflating: include/libc/isystem/locale.h
#   inflating: include/libc/isystem/arm_neon.h
#   inflating: include/libc/isystem/ifaddrs.h
#   inflating: include/libc/isystem/sgxintrin.h
#   inflating: include/libc/isystem/istream
#   inflating: include/libc/isystem/string
#   inflating: include/libc/isystem/cfloat
#   inflating: include/libc/isystem/charconv
#   inflating: include/libc/isystem/monetary.h
#   inflating: include/libc/isystem/random
#   inflating: include/libc/isystem/popcntintrin.h
#   inflating: include/libc/isystem/ftw.h
#   inflating: include/libc/isystem/float.h
#   inflating: include/libc/isystem/nsync_atomic.h
#   inflating: include/libc/isystem/byteswap.h
#   inflating: include/libc/isystem/typeindex
#   inflating: include/libc/isystem/signal.h
#   inflating: include/libc/isystem/cwchar
#   inflating: include/libc/isystem/limits
#   inflating: include/libc/isystem/mm3dnow.h
#   inflating: include/libc/isystem/new
#   inflating: include/libc/isystem/wchar.h
#   inflating: include/libc/isystem/dirent.h
#   inflating: include/libc/isystem/iconv.h
#   inflating: include/libc/isystem/mutex
#   inflating: include/libc/isystem/immintrin.h
#   inflating: include/libc/isystem/err.h
#   inflating: include/libc/isystem/system_error
#   inflating: include/libc/isystem/bit
#   inflating: include/libc/isystem/filesystem
#   inflating: include/libc/isystem/langinfo.h
#   inflating: include/libc/isystem/stddef.h
#   inflating: include/libc/isystem/cctype
#   inflating: include/libc/isystem/cstdio
#   inflating: include/libc/isystem/nsync_mu.h
#   inflating: include/libc/isystem/xmmintrin.h
#   inflating: include/libc/isystem/semaphore.h
#   inflating: include/libc/isystem/unistd.h
#   inflating: include/libc/isystem/syslog.h
#    creating: include/libc/isystem/linux/
#   inflating: include/libc/isystem/linux/futex.h
#   inflating: include/libc/isystem/linux/types.h
#   inflating: include/libc/isystem/linux/limits.h
#   inflating: include/libc/isystem/linux/param.h
#   inflating: include/libc/isystem/complex.h
#   inflating: include/libc/isystem/tmmintrin.h
#   inflating: include/libc/isystem/string_view
#   inflating: include/libc/isystem/pthread.h
#   inflating: include/libc/isystem/mwaitxintrin.h
#   inflating: include/libc/isystem/thread
#   inflating: include/libc/isystem/cmath
#   inflating: include/libc/isystem/ciso646
#   inflating: include/libc/isystem/nsync_time.h
#   inflating: include/libc/isystem/cosmo.h
#   inflating: include/libc/isystem/list
#   inflating: include/libc/isystem/algorithm
#   inflating: include/libc/isystem/utime.h
#   inflating: include/libc/isystem/cstdarg
#   inflating: include/libc/isystem/pwd.h
#   inflating: include/libc/isystem/winternl.h
#   inflating: include/libc/isystem/iomanip
#    creating: include/libc/isystem/netinet/
#   inflating: include/libc/isystem/netinet/ip.h
#   inflating: include/libc/isystem/netinet/udp.h
#   inflating: include/libc/isystem/netinet/in.h
#   inflating: include/libc/isystem/netinet/tcp.h
#   inflating: include/libc/isystem/wmmintrin.h
#   inflating: include/libc/isystem/poll.h
#   inflating: include/libc/isystem/cassert
#   inflating: include/libc/isystem/mntent.h
#   inflating: include/libc/isystem/variant
#   inflating: include/libc/isystem/atomic
#   inflating: include/libc/isystem/ios
#   inflating: include/libc/isystem/nsync_waiter.h
#   inflating: include/libc/isystem/stdlib.h
#   inflating: include/libc/isystem/ctgmath
#   inflating: include/libc/isystem/wctype.h
#   inflating: include/libc/isystem/emmintrin.h
#   inflating: include/libc/isystem/mm_malloc.h
#   inflating: include/libc/isystem/shadow.h
#   inflating: include/libc/isystem/stdatomic.h
#   inflating: include/libc/isystem/resolv.h
#   inflating: include/libc/isystem/grp.h
#   inflating: include/libc/isystem/ctime
#    creating: include/libc/isystem/net/
#   inflating: include/libc/isystem/net/if_arp.h
#   inflating: include/libc/isystem/net/if.h
#   inflating: include/libc/isystem/net/ethernet.h
#   inflating: include/libc/isystem/dlfcn.h
#   inflating: include/libc/isystem/utmpx.h
#   inflating: include/libc/isystem/threads.h
#   inflating: include/libc/isystem/ar.h
#   inflating: include/libc/isystem/stdalign.h
#   inflating: include/libc/isystem/execution
#   inflating: include/libc/isystem/scoped_allocator
#   inflating: include/libc/isystem/ompx.h
#   inflating: include/libc/isystem/paths.h
#  extracting: include/libc/isystem/assert.h
#   inflating: include/libc/isystem/cpuid.h
#   inflating: include/libc/isystem/streambuf
#   inflating: include/libc/isystem/setjmp.h
#   inflating: include/libc/isystem/optional
#   inflating: include/libc/isystem/cstring
#   inflating: include/libc/isystem/unwind.h
#   inflating: include/libc/isystem/nsync.h
#   inflating: include/libc/isystem/nsync_note.h
#   inflating: include/libc/isystem/mmintrin.h
#   inflating: include/libc/isystem/valarray
#   inflating: include/libc/isystem/cerrno
#   inflating: include/libc/isystem/sysexits.h
#   inflating: include/libc/isystem/arm_bf16.h
#   inflating: include/libc/isystem/locale
#   inflating: include/libc/isystem/nl_types.h
#   inflating: include/libc/isystem/x86intrin.h
#   inflating: include/libc/isystem/forward_list
#   inflating: include/libc/isystem/strstream
#   inflating: include/libc/isystem/fstream
#   inflating: include/libc/isystem/fnmatch.h
#   inflating: include/libc/isystem/condition_variable
#   inflating: include/libc/isystem/numeric
#   inflating: include/libc/isystem/errno.h
#   inflating: include/libc/isystem/csignal
#   inflating: include/libc/isystem/crypt.h
#   inflating: include/libc/isystem/tuple
#   inflating: include/libc/isystem/ostream
#   inflating: include/libc/isystem/iosfwd
#   inflating: include/libc/isystem/tgmath.h
#   inflating: include/libc/isystem/cstdbool
#   inflating: include/libc/isystem/exception
#   inflating: include/libc/isystem/ammintrin.h
#   inflating: include/libc/isystem/iso646.h
#   inflating: include/libc/isystem/pmmintrin.h
#   inflating: include/libc/isystem/arm_acle.h
#   inflating: include/libc/isystem/clzerointrin.h
#   inflating: include/libc/isystem/initializer_list
#   inflating: include/libc/isystem/ctype.h
#   inflating: include/libc/isystem/memory.h
#    creating: include/libc/isystem/sys/
#  extracting: include/libc/isystem/sys/cdefs.h
#   inflating: include/libc/isystem/sys/utsname.h
#   inflating: include/libc/isystem/sys/random.h
#   inflating: include/libc/isystem/sys/stat.h
#   inflating: include/libc/isystem/sys/ucontext.h
#   inflating: include/libc/isystem/sys/reboot.h
#   inflating: include/libc/isystem/sys/event.h
#   inflating: include/libc/isystem/sys/types.h
#   inflating: include/libc/isystem/sys/resource.h
#   inflating: include/libc/isystem/sys/fcntl.h
#   inflating: include/libc/isystem/sys/syscall.h
#   inflating: include/libc/isystem/sys/ioctl.h
#   inflating: include/libc/isystem/sys/signal.h
#   inflating: include/libc/isystem/sys/prctl.h
#   inflating: include/libc/isystem/sys/sysmacros.h
#   inflating: include/libc/isystem/sys/procfs.h
#   inflating: include/libc/isystem/sys/user.h
#   inflating: include/libc/isystem/sys/poll.h
#   inflating: include/libc/isystem/sys/msg.h
#   inflating: include/libc/isystem/sys/ptrace.h
#   inflating: include/libc/isystem/sys/un.h
#   inflating: include/libc/isystem/sys/param.h
#   inflating: include/libc/isystem/sys/times.h
#   inflating: include/libc/isystem/sys/dir.h
#   inflating: include/libc/isystem/sys/sendfile.h
#   inflating: include/libc/isystem/sys/auxv.h
#   inflating: include/libc/isystem/sys/mount.h
#   inflating: include/libc/isystem/sys/errno.h
#   inflating: include/libc/isystem/sys/vfs.h
#   inflating: include/libc/isystem/sys/statvfs.h
#   inflating: include/libc/isystem/sys/ttydefaults.h
#   inflating: include/libc/isystem/sys/uio.h
#   inflating: include/libc/isystem/sys/mman.h
#   inflating: include/libc/isystem/sys/statfs.h
#   inflating: include/libc/isystem/sys/select.h
#   inflating: include/libc/isystem/sys/socket.h
#   inflating: include/libc/isystem/sys/file.h
#   inflating: include/libc/isystem/sys/ipc.h
#   inflating: include/libc/isystem/sys/wait.h
#   inflating: include/libc/isystem/sys/sysinfo.h
#   inflating: include/libc/isystem/sys/time.h
#   inflating: include/libc/isystem/sys/termios.h
#   inflating: include/libc/isystem/map
#   inflating: include/libc/isystem/nsync_mu_wait.h
#   inflating: include/libc/isystem/sched.h
#   inflating: include/libc/isystem/complex
#   inflating: include/libc/isystem/uio.h
#   inflating: include/libc/isystem/omp-tools.h
#   inflating: include/libc/isystem/span
#   inflating: include/libc/isystem/elf.h
#   inflating: include/libc/isystem/iostream
#   inflating: include/libc/isystem/getopt.h
#   inflating: include/libc/isystem/stack
#   inflating: include/libc/isystem/malloc.h
#   inflating: include/libc/isystem/omp.h
#   inflating: include/libc/isystem/unordered_set
#   inflating: include/libc/isystem/pty.h
#   inflating: include/libc/isystem/cfenv
#   inflating: include/libc/isystem/sstream
#   inflating: include/libc/isystem/csetjmp
#   inflating: include/libc/isystem/endian.h
#   inflating: include/libc/isystem/climits
#   inflating: include/libc/isystem/future
#   inflating: include/libc/isystem/codecvt
#  extracting: include/libc/isystem/stdc-predef.h
#   inflating: include/libc/isystem/features.h
#   inflating: include/libc/isystem/set
#   inflating: include/libc/isystem/cpio.h
#   inflating: include/libc/isystem/compare
#   inflating: include/libc/isystem/utility
#   inflating: include/libc/isystem/glob.h
#   inflating: include/libc/isystem/wait.h
#   inflating: include/libc/isystem/stdint.h
#   inflating: include/libc/isystem/ratio
#   inflating: include/libc/isystem/stdio.h
#   inflating: include/libc/isystem/vector
#   inflating: include/libc/isystem/nmmintrin.h
#   inflating: include/libc/isystem/arm_fp16.h
#    creating: include/libc/isystem/arpa/
#   inflating: include/libc/isystem/arpa/inet.h
#   inflating: include/libc/isystem/arpa/nameser.h
#   inflating: include/libc/isystem/cstdint
#   inflating: include/libc/isystem/stdexcept
#   inflating: include/libc/isystem/math.h
#   inflating: include/libc/isystem/stdnoreturn.h
#   inflating: include/libc/isystem/memory
#   inflating: include/libc/isystem/utmp.h
#   inflating: include/libc/isystem/strings.h
#   inflating: include/libc/isystem/regex.h
#   inflating: include/libc/isystem/any
#   inflating: include/libc/isystem/functional
#   inflating: include/libc/isystem/cstddef
#   inflating: include/libc/isystem/iterator
#   inflating: include/libc/isystem/link.h
#   inflating: include/libc/isystem/time.h
#   inflating: include/libc/isystem/unordered_map
#   inflating: include/libc/isystem/stdarg.h
#   inflating: include/libc/isystem/queue
#   inflating: include/libc/isystem/fenv.h
#   inflating: include/libc/isystem/libgen.h
#   inflating: include/libc/isystem/array
#   inflating: include/libc/isystem/nsync_counter.h
#   inflating: include/libc/isystem/termios.h
#   inflating: include/libc/isystem/nsync_cv.h
#   inflating: include/libc/isystem/cwctype
#   inflating: include/libc/errno.h
#    creating: include/libc/mem/
#   inflating: include/libc/mem/alloca.h
#   inflating: include/libc/mem/tinymalloc.inc
#   inflating: include/libc/mem/hook.internal.h
#   inflating: include/libc/mem/sortedints.internal.h
#   inflating: include/libc/mem/internal.h
#   inflating: include/libc/mem/gc.h
#   inflating: include/libc/mem/bisect.internal.h
#   inflating: include/libc/mem/critbit0.h
#   inflating: include/libc/mem/alg.h
#   inflating: include/libc/mem/reverse.internal.h
#   inflating: include/libc/mem/mem.h
#   inflating: include/libc/mem/arraylist.internal.h
#   inflating: include/libc/mem/shuffle.internal.h
#   inflating: include/libc/mem/arraylist2.internal.h
#    creating: include/libc/x/
#   inflating: include/libc/x/x.h
#   inflating: include/libc/x/xsigaction.h
#   inflating: include/libc/x/xasprintf.h
#   inflating: include/libc/x/xspawn.h
#   inflating: include/libc/x/xgetline.h
#    creating: include/libc/fmt/
#   inflating: include/libc/fmt/wintime.internal.h
#   inflating: include/libc/fmt/magnumstrs.internal.h
#   inflating: include/libc/fmt/internal.h
#   inflating: include/libc/fmt/bing.internal.h
#   inflating: include/libc/fmt/conv.h
#   inflating: include/libc/fmt/itoa.h
#   inflating: include/libc/fmt/divmod10.internal.h
#   inflating: include/libc/fmt/leb128.h
#   inflating: include/libc/fmt/libgen.h
#    creating: include/libc/str/
#   inflating: include/libc/str/slice.h
#   inflating: include/libc/str/locale.h
#   inflating: include/libc/str/str.h
#   inflating: include/libc/str/thompike.h
#   inflating: include/libc/str/highwayhash64.h
#   inflating: include/libc/str/unicode.h
#   inflating: include/libc/str/langinfo.h
#   inflating: include/libc/str/blake2.h
#   inflating: include/libc/str/mb.internal.h
#   inflating: include/libc/str/wcwidth_osx.internal.h
#   inflating: include/libc/str/utf16.h
#   inflating: include/libc/str/strwidth.h
#   inflating: include/libc/str/tab.internal.h
#   inflating: include/libc/str/tpdecodecb.internal.h
#   inflating: include/libc/str/nltypes.h
#   inflating: include/libc/dce.h
#    creating: include/libc/intrin/
#   inflating: include/libc/intrin/atomic.h
#   inflating: include/libc/intrin/pmulhrsw.h
#   inflating: include/libc/intrin/repstosb.h
#   inflating: include/libc/intrin/cxaatexit.internal.h
#   inflating: include/libc/intrin/pushpop.internal.h
#   inflating: include/libc/intrin/hilbert.h
#   inflating: include/libc/intrin/nomultics.internal.h
#   inflating: include/libc/intrin/punpckhwd.h
#   inflating: include/libc/intrin/popcnt.h
#   inflating: include/libc/intrin/x86.h
#   inflating: include/libc/intrin/psraw.h
#   inflating: include/libc/intrin/palignr.h
#   inflating: include/libc/intrin/pcmpgtw.h
#   inflating: include/libc/intrin/strace.internal.h
#   inflating: include/libc/intrin/pmovmskb.h
#   inflating: include/libc/intrin/macros.h
#   inflating: include/libc/intrin/punpcklbw.h
#   inflating: include/libc/intrin/ubsan.h
#   inflating: include/libc/intrin/pcmpgtb.h
#   inflating: include/libc/intrin/punpcklwd.h
#   inflating: include/libc/intrin/pandn.h
#   inflating: include/libc/intrin/extend.internal.h
#   inflating: include/libc/intrin/xchg.internal.h
#   inflating: include/libc/intrin/weaken.h
#   inflating: include/libc/intrin/repmovsb.h
#   inflating: include/libc/intrin/describentoverlapped.internal.h
#   inflating: include/libc/intrin/asmflag.h
#   inflating: include/libc/intrin/paddw.h
#   inflating: include/libc/intrin/newbie.h
#   inflating: include/libc/intrin/leaky.internal.h
#   inflating: include/libc/intrin/asan.internal.h
#   inflating: include/libc/intrin/ulock.h
#   inflating: include/libc/intrin/describeflags.internal.h
#   inflating: include/libc/intrin/cmpxchg.h
#   inflating: include/libc/intrin/asancodes.h
#   inflating: include/libc/intrin/promises.internal.h
#   inflating: include/libc/intrin/bsf.h
#   inflating: include/libc/intrin/describebacktrace.internal.h
#   inflating: include/libc/intrin/punpckhbw.h
#   inflating: include/libc/intrin/likely.h
#   inflating: include/libc/intrin/setjmp.internal.h
#   inflating: include/libc/intrin/directmap.internal.h
#   inflating: include/libc/intrin/kprintf.h
#   inflating: include/libc/intrin/pmaddubsw.h
#   inflating: include/libc/intrin/packuswb.h
#   inflating: include/libc/intrin/dos2errno.internal.h
#   inflating: include/libc/intrin/getauxval.internal.h
#   inflating: include/libc/intrin/bswap.h
#   inflating: include/libc/intrin/bsr.h
#   inflating: include/libc/intrin/packsswb.h
#   inflating: include/libc/intrin/dll.h
#   inflating: include/libc/intrin/getenv.internal.h
#   inflating: include/libc/intrin/safemacros.internal.h
#   inflating: include/libc/cxxtypescompat.inc
#    creating: include/libc/stdio/
#   inflating: include/libc/stdio/ksc.inc
#   inflating: include/libc/stdio/syscall.h
#   inflating: include/libc/stdio/stdio_ext.h
#   inflating: include/libc/stdio/big5.inc
#   inflating: include/libc/stdio/ftw.h
#   inflating: include/libc/stdio/hkscs.inc
#   inflating: include/libc/stdio/codepages.inc
#   inflating: include/libc/stdio/iconv.h
#   inflating: include/libc/stdio/legacychars.inc
#   inflating: include/libc/stdio/rand.h
#   inflating: include/libc/stdio/readpassphrase.h
#   inflating: include/libc/stdio/strlist.internal.h
#   inflating: include/libc/stdio/internal.h
#   inflating: include/libc/stdio/dprintf.h
#   inflating: include/libc/stdio/sysparam.h
#   inflating: include/libc/stdio/revjis.inc
#   inflating: include/libc/stdio/lcg.internal.h
#   inflating: include/libc/stdio/jis0208.inc
#   inflating: include/libc/stdio/hex.internal.h
#   inflating: include/libc/stdio/fflush.internal.h
#   inflating: include/libc/stdio/append.h
#   inflating: include/libc/stdio/stdio.h
#   inflating: include/libc/stdio/gb18030.inc
#   inflating: include/libc/math.h
#   inflating: include/libc/serialize.h
#   inflating: include/libc/literal.h
#    creating: include/libc/nt/
#   inflating: include/libc/nt/registry.h
#    creating: include/libc/nt/thunk/
#   inflating: include/libc/nt/thunk/process.inc
#   inflating: include/libc/nt/thunk/runtime.inc
# ...
#   inflating: include/third_party/libcxx/complex
#   inflating: include/third_party/libcxx/span
#   inflating: include/third_party/libcxx/iostream
#   inflating: include/third_party/libcxx/stack
#   inflating: include/third_party/libcxx/unordered_set
#   inflating: include/third_party/libcxx/cfenv
#   inflating: include/third_party/libcxx/sstream
#   inflating: include/third_party/libcxx/csetjmp
#   inflating: include/third_party/libcxx/atomic_support.hh
#   inflating: include/third_party/libcxx/__tuple
#   inflating: include/third_party/libcxx/climits
#   inflating: include/third_party/libcxx/future
#   inflating: include/third_party/libcxx/codecvt
#   inflating: include/third_party/libcxx/set
#   inflating: include/third_party/libcxx/compare
#   inflating: include/third_party/libcxx/__nullptr
#   inflating: include/third_party/libcxx/utility
#   inflating: include/third_party/libcxx/ratio
#   inflating: include/third_party/libcxx/stdio.h
#   inflating: include/third_party/libcxx/vector
#   inflating: include/third_party/libcxx/cstdint
#   inflating: include/third_party/libcxx/stdexcept
#   inflating: include/third_party/libcxx/math.h
#   inflating: include/third_party/libcxx/memory
#   inflating: include/third_party/libcxx/any
#   inflating: include/third_party/libcxx/functional
#   inflating: include/third_party/libcxx/cstddef
#   inflating: include/third_party/libcxx/iterator
#   inflating: include/third_party/libcxx/unordered_map
#   inflating: include/third_party/libcxx/queue
#   inflating: include/third_party/libcxx/array
#   inflating: include/third_party/libcxx/cwctype
#    creating: include/third_party/libunwind/
#   inflating: include/third_party/libunwind/FrameHeaderCache.hpp
#   inflating: include/third_party/libunwind/CompactUnwinder.hpp
#   inflating: include/third_party/libunwind/DwarfInstructions.hpp
#   inflating: include/third_party/libunwind/Registers.hpp
#   inflating: include/third_party/libunwind/dwarf2.h
#    creating: include/third_party/libunwind/include/
#   inflating: include/third_party/libunwind/include/unwind_itanium.h
#   inflating: include/third_party/libunwind/include/__libunwind_config.h
#   inflating: include/third_party/libunwind/include/unwind_arm_ehabi.h
#    creating: include/third_party/libunwind/include/mach-o/
#   inflating: include/third_party/libunwind/include/mach-o/compact_unwind_encoding.h
#   inflating: include/third_party/libunwind/include/unwind.h
#   inflating: include/third_party/libunwind/include/libunwind.h
#   inflating: include/third_party/libunwind/DwarfParser.hpp
#   inflating: include/third_party/libunwind/config.h
#   inflating: include/third_party/libunwind/AddressSpace.hpp
#   inflating: include/third_party/libunwind/EHHeaderParser.hpp
#   inflating: include/third_party/libunwind/RWMutex.hpp
#   inflating: include/third_party/libunwind/cet_unwind.h
#   inflating: include/third_party/libunwind/libunwind_ext.h
#   inflating: include/third_party/libunwind/UnwindCursor.hpp
#   inflating: include/third_party/libunwind/Unwind-EHABI.h
#    creating: include/third_party/dlmalloc/
#   inflating: include/third_party/dlmalloc/system.inc
#   inflating: include/third_party/dlmalloc/hooks.inc
#   inflating: include/third_party/dlmalloc/directmap.inc
#   inflating: include/third_party/dlmalloc/management.inc
#   inflating: include/third_party/dlmalloc/global.inc
#   inflating: include/third_party/dlmalloc/debuglib.inc
#   inflating: include/third_party/dlmalloc/debugging.inc
#   inflating: include/third_party/dlmalloc/mspaces.inc
#   inflating: include/third_party/dlmalloc/binmaps.inc
#   inflating: include/third_party/dlmalloc/dlmalloc.h
#   inflating: include/third_party/dlmalloc/runtimechecks.inc
#   inflating: include/third_party/dlmalloc/headfoot.inc
#   inflating: include/third_party/dlmalloc/platform.inc
#   inflating: include/third_party/dlmalloc/statistics.inc
#   inflating: include/third_party/dlmalloc/locks.inc
#   inflating: include/third_party/dlmalloc/init.inc
#   inflating: include/third_party/dlmalloc/trees.inc
#   inflating: include/third_party/dlmalloc/chunks.inc
#   inflating: include/third_party/dlmalloc/indexing.inc
#   inflating: include/third_party/dlmalloc/smallbins.inc
#   inflating: include/third_party/dlmalloc/vespene.internal.h
#    creating: include/third_party/nsync/
#   inflating: include/third_party/nsync/note.h
#   inflating: include/third_party/nsync/atomic.h
#   inflating: include/third_party/nsync/array.internal.h
#   inflating: include/third_party/nsync/mu.h
#   inflating: include/third_party/nsync/waiter.h
#   inflating: include/third_party/nsync/common.internal.h
#   inflating: include/third_party/nsync/mu_wait.h
#   inflating: include/third_party/nsync/wait_s.internal.h
#   inflating: include/third_party/nsync/once.h
#   inflating: include/third_party/nsync/races.internal.h
#   inflating: include/third_party/nsync/debug.h
#   inflating: include/third_party/nsync/atomic.internal.h
#   inflating: include/third_party/nsync/futex.internal.h
#   inflating: include/third_party/nsync/heap.internal.h
#   inflating: include/third_party/nsync/mu_semaphore.h
#   inflating: include/third_party/nsync/counter.h
#   inflating: include/third_party/nsync/cv.h
#   inflating: include/third_party/nsync/mu_semaphore.internal.h
#   inflating: include/third_party/nsync/time.h
#    creating: include/third_party/xed/
#   inflating: include/third_party/xed/x86.h
#   inflating: include/third_party/xed/private.h
#   inflating: include/third_party/xed/avx512.h
#   inflating: include/third_party/xed/x86isa.h
#   inflating: include/atomic
#   inflating: include/ios
#   inflating: include/nsync_waiter.h
#   inflating: include/stdlib.h
#   inflating: include/ctgmath
#   inflating: include/wctype.h
#   inflating: include/emmintrin.h
#   inflating: include/mm_malloc.h
#   inflating: include/shadow.h
#   inflating: include/stdatomic.h
#   inflating: include/resolv.h
#   inflating: include/grp.h
#   inflating: include/ctime
#    creating: include/net/
#   inflating: include/net/if_arp.h
#   inflating: include/net/if.h
#    creating: include/net/http/
#   inflating: include/net/http/tokenbucket.h
#   inflating: include/net/http/gethttpheader.inc
#   inflating: include/net/http/url.h
#   inflating: include/net/http/ip.h
#   inflating: include/net/http/http.h
#   inflating: include/net/http/csscolor.h
#   inflating: include/net/http/escape.h
#   inflating: include/net/ethernet.h
#   inflating: include/dlfcn.h
#   inflating: include/utmpx.h
#   inflating: include/threads.h
#   inflating: include/ar.h
#   inflating: include/stdalign.h
#   inflating: include/execution
#   inflating: include/scoped_allocator
#   inflating: include/ompx.h
#   inflating: include/paths.h
#  extracting: include/assert.h
#   inflating: include/cpuid.h
#   inflating: include/streambuf
#   inflating: include/setjmp.h
#   inflating: include/optional
#   inflating: include/cstring
#   inflating: include/unwind.h
#   inflating: include/nsync.h
#   inflating: include/nsync_note.h
#   inflating: include/mmintrin.h
#   inflating: include/valarray
#   inflating: include/cerrno
#   inflating: include/sysexits.h
#   inflating: include/arm_bf16.h
#   inflating: include/locale
#   inflating: include/nl_types.h
#   inflating: include/x86intrin.h
#   inflating: include/forward_list
#   inflating: include/strstream
#   inflating: include/fstream
#   inflating: include/fnmatch.h
#   inflating: include/condition_variable
#   inflating: include/numeric
#   inflating: include/errno.h
#   inflating: include/csignal
#   inflating: include/crypt.h
#   inflating: include/tuple
#   inflating: include/ostream
#   inflating: include/iosfwd
#   inflating: include/tgmath.h
#   inflating: include/cstdbool
#   inflating: include/exception
#   inflating: include/ammintrin.h
#   inflating: include/iso646.h
#   inflating: include/pmmintrin.h
#   inflating: include/arm_acle.h
#   inflating: include/clzerointrin.h
#   inflating: include/initializer_list
#   inflating: include/ctype.h
#   inflating: include/memory.h
#    creating: include/sys/
#  extracting: include/sys/cdefs.h
#   inflating: include/sys/utsname.h
#   inflating: include/sys/random.h
#   inflating: include/sys/stat.h
#   inflating: include/sys/ucontext.h
#   inflating: include/sys/reboot.h
#   inflating: include/sys/event.h
#   inflating: include/sys/types.h
#   inflating: include/sys/resource.h
#   inflating: include/sys/fcntl.h
#   inflating: include/sys/syscall.h
#   inflating: include/sys/ioctl.h
#   inflating: include/sys/signal.h
#   inflating: include/sys/prctl.h
#   inflating: include/sys/sysmacros.h
#   inflating: include/sys/procfs.h
#   inflating: include/sys/user.h
#   inflating: include/sys/poll.h
#   inflating: include/sys/msg.h
#   inflating: include/sys/ptrace.h
#   inflating: include/sys/un.h
#   inflating: include/sys/param.h
#   inflating: include/sys/times.h
#   inflating: include/sys/dir.h
#   inflating: include/sys/sendfile.h
#   inflating: include/sys/auxv.h
#   inflating: include/sys/mount.h
#   inflating: include/sys/errno.h
#   inflating: include/sys/vfs.h
#   inflating: include/sys/statvfs.h
#   inflating: include/sys/ttydefaults.h
#   inflating: include/sys/uio.h
#   inflating: include/sys/mman.h
#   inflating: include/sys/statfs.h
#   inflating: include/sys/select.h
#   inflating: include/sys/socket.h
#   inflating: include/sys/file.h
#   inflating: include/sys/ipc.h
#   inflating: include/sys/wait.h
#   inflating: include/sys/sysinfo.h
#   inflating: include/sys/time.h
#   inflating: include/sys/termios.h
#   inflating: include/map
#   inflating: include/nsync_mu_wait.h
#   inflating: include/sched.h
#   inflating: include/windowsesque.h
#   inflating: include/complex
#   inflating: include/uio.h
#   inflating: include/omp-tools.h
#   inflating: include/span
#   inflating: include/elf.h
#   inflating: include/iostream
#   inflating: include/getopt.h
#   inflating: include/stack
#   inflating: include/malloc.h
#   inflating: include/omp.h
#   inflating: include/unordered_set
#   inflating: include/pty.h
#   inflating: include/cfenv
#   inflating: include/sstream
#   inflating: include/csetjmp
#   inflating: include/endian.h
#   inflating: include/climits
#   inflating: include/future
#   inflating: include/codecvt
#  extracting: include/stdc-predef.h
#   inflating: include/features.h
#   inflating: include/set
#   inflating: include/cpio.h
#   inflating: include/compare
#   inflating: include/utility
#   inflating: include/glob.h
#   inflating: include/wait.h
#   inflating: include/stdint.h
#   inflating: include/ratio
#   inflating: include/stdio.h
#   inflating: include/vector
#   inflating: include/nmmintrin.h
#   inflating: include/arm_fp16.h
#    creating: include/arpa/
#   inflating: include/arpa/inet.h
#   inflating: include/arpa/nameser.h
#   inflating: include/cstdint
#   inflating: include/stdexcept
#   inflating: include/math.h
#   inflating: include/stdnoreturn.h
#   inflating: include/memory
#   inflating: include/utmp.h
#   inflating: include/strings.h
#   inflating: include/regex.h
#   inflating: include/any
#   inflating: include/functional
#   inflating: include/cstddef
#   inflating: include/iterator
#   inflating: include/link.h
#   inflating: include/time.h
#   inflating: include/unordered_map
#   inflating: include/stdarg.h
#   inflating: include/queue
#   inflating: include/fenv.h
#   inflating: include/libgen.h
#   inflating: include/array
#   inflating: include/nsync_counter.h
#   inflating: include/termios.h
#   inflating: include/nsync_cv.h
#   inflating: include/cwctype
#    creating: lib/
#    creating: lib/gcc/
#  extracting: lib/gcc/libgomp.spec
#   inflating: LICENSE.gpl2
#   inflating: LICENSE.lgpl2
#   inflating: README.md
#   inflating: LICENSE.lgpl3
#    creating: aarch64-linux-cosmo/
#    creating: aarch64-linux-cosmo/lib/
#   inflating: aarch64-linux-cosmo/lib/aarch64.lds
#  extracting: aarch64-linux-cosmo/lib/libm.a
#   inflating: aarch64-linux-cosmo/lib/libcosmo.a
#  extracting: aarch64-linux-cosmo/lib/libdl.a
#  extracting: aarch64-linux-cosmo/lib/libc.a
#   inflating: aarch64-linux-cosmo/lib/crt.o
#  extracting: aarch64-linux-cosmo/lib/libunwind.a
#   inflating: aarch64-linux-cosmo/lib/libcxx.a
#  extracting: aarch64-linux-cosmo/lib/libpthread.a
#  extracting: aarch64-linux-cosmo/lib/libcrypt.a
#  extracting: aarch64-linux-cosmo/lib/librt.a
#  extracting: aarch64-linux-cosmo/lib/libstdc++.a
#  extracting: aarch64-linux-cosmo/lib/libgomp.a
#  extracting: aarch64-linux-cosmo/lib/libgcc_s.a
#  extracting: aarch64-linux-cosmo/lib/libresolv.a
#   inflating: LICENSE.gpl3
# finishing deferred symbolic links:
#   bin/x86_64-unknown-cosmo-c++filt -> x86_64-linux-cosmo-c++filt
#   bin/aarch64-unknown-cosmo-objdump -> aarch64-linux-cosmo-objdump
#   bin/x86_64-unknown-cosmo-cc -> cosmocross
#   bin/aarch64-linux-cosmo-cpp -> aarch64-linux-cosmo-gcc
#   bin/x86_64-linux-cosmo-cpp -> x86_64-linux-cosmo-gcc
#   bin/aarch64-linux-cosmo-as -> ../libexec/gcc/aarch64-linux-cosmo/12.3.0/as
#   bin/aarch64-unknown-cosmo-as -> aarch64-linux-cosmo-as
#   bin/aarch64-unknown-cosmo-readelf -> aarch64-linux-cosmo-readelf
#   bin/aarch64-unknown-cosmo-cc -> cosmocross
#   bin/unknown-unknown-cosmo-cc -> cosmocc
#   bin/x86_64-unknown-cosmo-as -> x86_64-linux-cosmo-as
#   bin/x86_64-linux-cosmo-ld.bfd -> ../libexec/gcc/x86_64-linux-cosmo/12.3.0/ld.bfd
#   bin/aarch64-linux-cosmo-c++ -> aarch64-linux-cosmo-g++
#   bin/unknown-unknown-cosmo-ar -> cosmoar
#   bin/x86_64-unknown-cosmo-readelf -> x86_64-linux-cosmo-readelf
#   bin/x86_64-unknown-cosmo-objcopy -> x86_64-linux-cosmo-objcopy
#   bin/x86_64-linux-cosmo-cc -> x86_64-linux-cosmo-gcc
#   bin/x86_64-unknown-cosmo-objdump -> x86_64-linux-cosmo-objdump
#   bin/aarch64-unknown-cosmo-objcopy -> aarch64-linux-cosmo-objcopy
#   bin/x86_64-linux-cosmo-c++ -> x86_64-linux-cosmo-g++
#   bin/aarch64-linux-cosmo-cc -> aarch64-linux-cosmo-gcc
#   bin/aarch64-linux-cosmo-ld.bfd -> ../libexec/gcc/aarch64-linux-cosmo/12.3.0/ld.bfd
#   bin/aarch64-unknown-cosmo-c++ -> cosmocross
#   bin/aarch64-unknown-cosmo-nm -> aarch64-linux-cosmo-nm
#   bin/cosmoc++           -> cosmocc
#   bin/aarch64-unknown-cosmo-strip -> aarch64-linux-cosmo-strip
#   bin/x86_64-unknown-cosmo-ar -> x86_64-linux-cosmo-ar
#   bin/x86_64-linux-cosmo-as -> ../libexec/gcc/x86_64-linux-cosmo/12.3.0/as
#   bin/x86_64-unknown-cosmo-addr2line -> x86_64-linux-cosmo-addr2line
#   bin/x86_64-unknown-cosmo-nm -> x86_64-linux-cosmo-nm
#   bin/unknown-unknown-cosmo-install -> cosmoinstall
#   bin/x86_64-linux-cosmo-ld -> ../libexec/gcc/x86_64-linux-cosmo/12.3.0/ld.bfd
#   bin/unknown-unknown-cosmo-c++ -> cosmocc
#   bin/aarch64-unknown-cosmo-c++filt -> aarch64-linux-cosmo-c++filt
#   bin/x86_64-unknown-cosmo-c++ -> cosmocross
#   bin/aarch64-linux-cosmo-ld -> ../libexec/gcc/aarch64-linux-cosmo/12.3.0/ld.bfd
#   bin/aarch64-unknown-cosmo-ar -> aarch64-linux-cosmo-ar
#   bin/aarch64-unknown-cosmo-addr2line -> aarch64-linux-cosmo-addr2line
#   bin/x86_64-unknown-cosmo-strip -> x86_64-linux-cosmo-strip
#   libexec/gcc/x86_64-linux-cosmo/12.3.0/ld -> ld.bfd
#   libexec/gcc/aarch64-linux-cosmo/12.3.0/ld -> ld.bfd

# %%
c = """// hello.c
#include <stdio.h>

int main() {
  printf("I'm also a little Computer Program!\\n");
}
"""
outfile = open("hello.c",'w')
outfile.write(c)
outfile.flush()

# %%
# !./cosmocc/bin/cosmocc -o hello hello.c

# %% [markdown]
# Create a placeholder file called `src/include_exe.tex` for the xetex build. This will reserve the bytes at the top of the PDF where we will inject our executable directly into the PDF file it builds.

# %%
EXE_OFFSET = 0x40
LINE_WIDTH = 80
stream_len = os.stat("hello").st_size - EXE_OFFSET
length_len = len(str(stream_len))

TEX = """\pdfobjcompresslevel=0
\immediate
\pdfobj
{{
<<
/Length {}
>>
stream
{}
{}
endstream
}}%
"""

# Hardcoded unfortunately, so inspect the pdf file in case it changes.
PDF_PREFIX = """%PDF-1.5
%ÐÔÅØ
1 0 obj
 << /Length {} >> stream"""

texfile = open('../src/include_exe.tex','w')

prefix_size = (len(PDF_PREFIX) - 2) + length_len
stream_len_for_prefix = stream_len - prefix_size

texfile.write(TEX.format(stream_len_for_prefix,
                        '\n'.join(["0" * (LINE_WIDTH-1)] * int(stream_len/LINE_WIDTH)),
                         "0" * (stream_len % LINE_WIDTH)
                        ))
texfile.close()

# %% [markdown]
# Inject our binary into the final pdf. The first 0x40 bytes are the important bit of the `ape` binary header, then we use some reserved space in the `ape` header to inject our PDF stream object containing the rest of the binary file, and then we write out the rest of the PDF file.

# %%
exefile = open('hello','rb')
exefile.seek(0, 0)
exe_prefix =  exefile.read(EXE_OFFSET)
exefile.seek(EXE_OFFSET + prefix_size, 0)
exe_suffix = exefile.read()

pdffile = open('../out/psychedelia_syndrome.pdf','rb')

start_offset = pdffile.read().index('stream'.encode('utf-8')) + 6
pdffile.seek(0, 0)
pdf_prefix = pdffile.read(start_offset)
end_offset = pdffile.read().index('endstream'.encode('utf-8'))
pdffile.seek(end_offset, 0)
pdf_suffix = pdffile.read()

exe_pdffile = open('../out/psychedelia_syndrome_exe.pdf','wb')
exe_pdffile.write(exe_prefix)
exe_pdffile.write(pdf_prefix)
exe_pdffile.write(exe_suffix)
exe_pdffile.write(pdf_suffix)
exe_pdffile.close()

# %% [markdown]
# Try it out to make sure it works!

# %%
# !evince ../out/psychedelia_syndrome_exe.pdf

# %%
# !chmod +x ../out/psychedelia_syndrome_exe.pdf
# !../out/psychedelia_syndrome_exe.pdf
# Out:
# I'm also a little Computer Program!
